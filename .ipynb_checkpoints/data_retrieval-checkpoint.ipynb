# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PUT-FUNCTION-INTO-.py-FILE" data-toc-modified-id="PUT-FUNCTION-INTO-.py-FILE-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PUT FUNCTION INTO <code>.py</code> FILE</a></span></li><li><span><a href="#Additional-Database" data-toc-modified-id="Additional-Database-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Additional Database</a></span></li><li><span><a href="#Link1" data-toc-modified-id="Link1-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Link1</a></span></li><li><span><a href="#Link2" data-toc-modified-id="Link2-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Link2</a></span></li><li><span><a href="#Link3" data-toc-modified-id="Link3-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Link3</a></span></li><li><span><a href="#Link4" data-toc-modified-id="Link4-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Link4</a></span></li><li><span><a href="#Link5" data-toc-modified-id="Link5-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Link5</a></span></li></ul></div>

# %% [markdown]
# Going to practice ripping text from PDFs enable to put them into a database.

# %%
import PyPDF2
import glob
import re
import os
import pandas as pd
import numpy as np
import missingno as msno
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## PUT FUNCTION INTO `.py` FILE

# %% [markdown]
# So there is a head to this document and we need to remove it. Since it will not be standard slice (every state has a different length of a name), we will have to see if there are patterns between the documents that we can exploit.

# %%
# pdf file object
# you can find find the pdf file with complete code in below
pdfFileObj = open('data/state_pdfs/al-alpha.pdf', 'rb')
# pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
# number of pages in pdf
pages = pdfReader.numPages
pages
# Out:
# 81

# %%
pageObj = pdfReader.getPage(0)
al = pageObj.extractText()

# %%
al
# Out:
# 'U.S. Military Fatal Casualties of the Vietnam War for \nHome-State-of-Record: Alabama\nName\nService\nRank / \nRate\n   Birthdate \n(YYYYMMDD)\nIncident or \nDeath Date \n(YYYYMMDD)\nRemains \nRecovered\nHome of Record:\nCity                  County\nABRAMS TIMOTHY C JR\nARMY\nPFC\n19461104\nTUSCALOOSA\nTUSCALOOSA\n19670103\nY\nABSTON JAMES ESTUS JR\nARMY\nPFC\n19441102\nCOTTONDALE\nTUSCALOOSA\n19670227\nY\nACTON MARION \nFRANKLIN\nARMY\nPFC\n19470901\nHUNTSVILLE\nMADISON\n19660411\nY\nADAMS JAMES CONRAD\nARMY\nMAJ\n19381025\nPHENIX CITY\nRUSSELL\n19700501\nY\nADAMS SPENCER\nARMY\nSSG\n19340506\nMOBILE\nMOBILE\n19680215\nY\nADAMS WALTER LEE\nARMY\nPFC\n19461227\nMCINTOSH\nWASHINGTON\n19670610\nY\nADAMSON LARRY ONEAL\nARMY\nSP4\n19460910\nFAIRFAX\nCHAMBERS\n19691003\nY\nADDISON ONEAL\nARMY\nSP5\n19270506\nWEST ENSLEY\nJEFFERSON\n19660504\nY\nADKISON CARL ELMUS\nARMY\nSP4\n19490531\nGADSDEN\nETOWAH\n19690812\nY\nAKINS ADRIAN ALAN\nARMY\nSP5\n19490404\nCORDOVA\nWALKER\n19691025\nY\nALEXANDER BOBBY RAY\nMARINE CORPS\nCPL\n19470213\nDECATUR\nMORGAN\n19671116\nY\nALEXANDER DAVID J JR\nARMY\nPFC\n19480228\nANNISTON\nCALHOUN\n19680718\nY\nALLEN GRANVILLE JOEL \nJR\nNAVY\nPO3\n19471102\nBIRMINGHAM\nJEFFERSON\n19680523\nY\nALLEN JOHNNY JR\nARMY\nSP4\n19470502\nBIRMINGHAM\nJEFFERSON\n19700702\nY\nALLEN ROBERT WARREN\nMARINE CORPS\nPFC\n19471005\nBIRMINGHAM\nJEFFERSON\n19651003\nY\nALLEN WILLIAM TERRY\nARMY\n1LT\n19450317\nENTERPRISE\nCOFFEE\n19671204\nY\nSource of data: the \nVietnam Conflict Extract Data File, as of April 29, 2008\n, of the \nDefense Casualty Analysis System (DCAS) Files\n, part of Record \nGroup 330: Records of the Office of the Secretary of Defense.\nYou can view the full \nDCAS\nrecord for an individual named in the list via the Access to Archival Databases resource, or AAD.  The link to the AAD main \npage is as follows:\nhttp://www.archives.gov/aad\nPage 1 of 81\n'

# %% [markdown]
# Now let pull another one and compare the results.

# %%
# pdf file object
# you can find find the pdf file with complete code in below
pdfFileObj = open('data/state_pdfs/ak-alpha.pdf', 'rb')
# pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
# number of pages in pdf
pages = pdfReader.numPages
pages
# Out:
# 5

# %%
pageObj = pdfReader.getPage(0)
ak = pageObj.extractText()

# %%
ak
# Out:
# 'U.S. Military Fatal Casualties of the Vietnam War for \nHome-State-of-Record: Alaska\nName\nService\nRank / \nRate\n   Birthdate \n(YYYYMMDD)\nIncident or \nDeath Date \n(YYYYMMDD)\nRemains \nRecovered\nHome of Record:\nCity                  County\nANDERSON THOMAS \nEDWARD\nMARINE CORPS\nCPL\n19390727\nSPENARD\nANCHORAGE\n19621006\nN\nBANTA MICHAEL DEAN\nARMY\nPFC\n19491005\nCORDOVA\nVALDEZ-\nCORDOVA\n19701002\nY\nBARR EDWARD \nNASUESAK\nNAVY\nSN\n19491022\nBREVIG \nMISSION\nNOME\n19690503\nY\nBARR THOMAS M\nARMY\nSP5\n19450701\nANCHORAGE\nANCHORAGE\n19690512\nY\nBAUER RICHARD GENE\nARMY\nSP5\n19500619\nANCHORAGE\nANCHORAGE\n19691104\nY\nBETTS LARRY LE ROY\nARMY\n2LT\n19461011\nEAGLE RIVER\nANCHORAGE\n19691121\nY\nBROWN CHARLES \nEDWARD\nARMY\nPFC\n19421003\nTHORNE BAY\nPRINCE OF \nWALES-OUTER \nKETCHIKAN\n19671206\nY\nBROWN DAVID DEE JR\nMARINE CORPS\nPFC\n19491010\nWRANGELL\nWRANGELL-\nPETERSBURG\n19680416\nY\nBULLOCK GARY EDWIN\nARMY\nSP4\n19420918\nANCHORAGE\nANCHORAGE\n19670131\nY\nCHILDERS WILLIAM \nSTEVEN\nARMY\nWO1\n19470523\nFAIRBANKS\nFAIRBANKS \nNORTH STAR\n19690103\nY\nCHMIEL DONALD GEORGE\nARMY\nSSG\n19440801\nCHUGIAK\nANCHORAGE\n19700825\nY\nCOOK CLINTON ARTHUR\nARMY\nSGT\n19481013\nHYDABURG\nPRINCE OF \nWALES-OUTER \nKETCHIKAN\n19700428\nY\nCOX DANIEL FRANKLIN\nARMY\nSP5\n19490904\nELMENDORF \nAFB\nANCHORAGE\n19710115\nY\nSource of data: the \nVietnam Conflict Extract Data File, as of April 29, 2008\n, of the \nDefense Casualty Analysis System (DCAS) Files\n, part of Record \nGroup 330: Records of the Office of the Secretary of Defense.\nYou can view the full \nDCAS\nrecord for an individual named in the list via the Access to Archival Databases resource, or AAD.  The link to the AAD main \npage is as follows:\nhttp://www.archives.gov/aad\nPage 1 of 5\n'

# %% [markdown]
# ___
# For both of these records, all the data exists between the words "County" and "Source". I will grab everything in between the two words.
# ___

# %%
m = re.search(r"(?<=County\n).*(?=Source)", ak, flags=re.DOTALL) #re.DOTALL - makes the '.' special character match any character at all, including a newline
m.group(0)
# Out:
# 'ANDERSON THOMAS \nEDWARD\nMARINE CORPS\nCPL\n19390727\nSPENARD\nANCHORAGE\n19621006\nN\nBANTA MICHAEL DEAN\nARMY\nPFC\n19491005\nCORDOVA\nVALDEZ-\nCORDOVA\n19701002\nY\nBARR EDWARD \nNASUESAK\nNAVY\nSN\n19491022\nBREVIG \nMISSION\nNOME\n19690503\nY\nBARR THOMAS M\nARMY\nSP5\n19450701\nANCHORAGE\nANCHORAGE\n19690512\nY\nBAUER RICHARD GENE\nARMY\nSP5\n19500619\nANCHORAGE\nANCHORAGE\n19691104\nY\nBETTS LARRY LE ROY\nARMY\n2LT\n19461011\nEAGLE RIVER\nANCHORAGE\n19691121\nY\nBROWN CHARLES \nEDWARD\nARMY\nPFC\n19421003\nTHORNE BAY\nPRINCE OF \nWALES-OUTER \nKETCHIKAN\n19671206\nY\nBROWN DAVID DEE JR\nMARINE CORPS\nPFC\n19491010\nWRANGELL\nWRANGELL-\nPETERSBURG\n19680416\nY\nBULLOCK GARY EDWIN\nARMY\nSP4\n19420918\nANCHORAGE\nANCHORAGE\n19670131\nY\nCHILDERS WILLIAM \nSTEVEN\nARMY\nWO1\n19470523\nFAIRBANKS\nFAIRBANKS \nNORTH STAR\n19690103\nY\nCHMIEL DONALD GEORGE\nARMY\nSSG\n19440801\nCHUGIAK\nANCHORAGE\n19700825\nY\nCOOK CLINTON ARTHUR\nARMY\nSGT\n19481013\nHYDABURG\nPRINCE OF \nWALES-OUTER \nKETCHIKAN\n19700428\nY\nCOX DANIEL FRANKLIN\nARMY\nSP5\n19490904\nELMENDORF \nAFB\nANCHORAGE\n19710115\nY\n'

# %%
m = re.search(r"(?<=County\n).*(?=Source)", al, flags=re.DOTALL) #re.DOTALL - makes the '.' special character match any character at all, including a newline
m.group(0)
# Out:
# 'ABRAMS TIMOTHY C JR\nARMY\nPFC\n19461104\nTUSCALOOSA\nTUSCALOOSA\n19670103\nY\nABSTON JAMES ESTUS JR\nARMY\nPFC\n19441102\nCOTTONDALE\nTUSCALOOSA\n19670227\nY\nACTON MARION \nFRANKLIN\nARMY\nPFC\n19470901\nHUNTSVILLE\nMADISON\n19660411\nY\nADAMS JAMES CONRAD\nARMY\nMAJ\n19381025\nPHENIX CITY\nRUSSELL\n19700501\nY\nADAMS SPENCER\nARMY\nSSG\n19340506\nMOBILE\nMOBILE\n19680215\nY\nADAMS WALTER LEE\nARMY\nPFC\n19461227\nMCINTOSH\nWASHINGTON\n19670610\nY\nADAMSON LARRY ONEAL\nARMY\nSP4\n19460910\nFAIRFAX\nCHAMBERS\n19691003\nY\nADDISON ONEAL\nARMY\nSP5\n19270506\nWEST ENSLEY\nJEFFERSON\n19660504\nY\nADKISON CARL ELMUS\nARMY\nSP4\n19490531\nGADSDEN\nETOWAH\n19690812\nY\nAKINS ADRIAN ALAN\nARMY\nSP5\n19490404\nCORDOVA\nWALKER\n19691025\nY\nALEXANDER BOBBY RAY\nMARINE CORPS\nCPL\n19470213\nDECATUR\nMORGAN\n19671116\nY\nALEXANDER DAVID J JR\nARMY\nPFC\n19480228\nANNISTON\nCALHOUN\n19680718\nY\nALLEN GRANVILLE JOEL \nJR\nNAVY\nPO3\n19471102\nBIRMINGHAM\nJEFFERSON\n19680523\nY\nALLEN JOHNNY JR\nARMY\nSP4\n19470502\nBIRMINGHAM\nJEFFERSON\n19700702\nY\nALLEN ROBERT WARREN\nMARINE CORPS\nPFC\n19471005\nBIRMINGHAM\nJEFFERSON\n19651003\nY\nALLEN WILLIAM TERRY\nARMY\n1LT\n19450317\nENTERPRISE\nCOFFEE\n19671204\nY\n'

# %%
m = re.search(r"(?<=County\n).*(?=Source)", al, flags=re.DOTALL) #re.DOTALL - makes the '.' special character match any character at all, including a newline
trial = m.group(0)
trial
# Out:
# 'ABRAMS TIMOTHY C JR\nARMY\nPFC\n19461104\nTUSCALOOSA\nTUSCALOOSA\n19670103\nY\nABSTON JAMES ESTUS JR\nARMY\nPFC\n19441102\nCOTTONDALE\nTUSCALOOSA\n19670227\nY\nACTON MARION \nFRANKLIN\nARMY\nPFC\n19470901\nHUNTSVILLE\nMADISON\n19660411\nY\nADAMS JAMES CONRAD\nARMY\nMAJ\n19381025\nPHENIX CITY\nRUSSELL\n19700501\nY\nADAMS SPENCER\nARMY\nSSG\n19340506\nMOBILE\nMOBILE\n19680215\nY\nADAMS WALTER LEE\nARMY\nPFC\n19461227\nMCINTOSH\nWASHINGTON\n19670610\nY\nADAMSON LARRY ONEAL\nARMY\nSP4\n19460910\nFAIRFAX\nCHAMBERS\n19691003\nY\nADDISON ONEAL\nARMY\nSP5\n19270506\nWEST ENSLEY\nJEFFERSON\n19660504\nY\nADKISON CARL ELMUS\nARMY\nSP4\n19490531\nGADSDEN\nETOWAH\n19690812\nY\nAKINS ADRIAN ALAN\nARMY\nSP5\n19490404\nCORDOVA\nWALKER\n19691025\nY\nALEXANDER BOBBY RAY\nMARINE CORPS\nCPL\n19470213\nDECATUR\nMORGAN\n19671116\nY\nALEXANDER DAVID J JR\nARMY\nPFC\n19480228\nANNISTON\nCALHOUN\n19680718\nY\nALLEN GRANVILLE JOEL \nJR\nNAVY\nPO3\n19471102\nBIRMINGHAM\nJEFFERSON\n19680523\nY\nALLEN JOHNNY JR\nARMY\nSP4\n19470502\nBIRMINGHAM\nJEFFERSON\n19700702\nY\nALLEN ROBERT WARREN\nMARINE CORPS\nPFC\n19471005\nBIRMINGHAM\nJEFFERSON\n19651003\nY\nALLEN WILLIAM TERRY\nARMY\n1LT\n19450317\nENTERPRISE\nCOFFEE\n19671204\nY\n'

# %%
state_list = trial.splitlines()  #breaks on the newline
print(len(state_list))
state_list[:10]
# Out:
# 130
# ['ABRAMS TIMOTHY C JR',
#  'ARMY',
#  'PFC',
#  '19461104',
#  'TUSCALOOSA',
#  'TUSCALOOSA',
#  '19670103',
#  'Y',
#  'ABSTON JAMES ESTUS JR',
#  'ARMY']

# %% [markdown]
# Great. Now that I can get the data into lists with an indiviual entries.
#
# OK, now lets make a function that goes through each PDF to scrape the data. I will use the function above to put the data into the proper column. Then I will embed that into a loop that will go through all the PDFs in the folder.

# %%
def scrape_pdf(pdf_file): #Accepts in a PDF and returns the text of the PDF broken at newlines.
    
    pdfFileObj = open(pdf_file, 'rb')               #Opens file
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)    #Reads the file
    pages = pdfReader.numPages                      #Gets the number of pages to cycle through
    
    counter = 0
    data_list = []
    
    while counter < pages:
        
        pageObj = pdfReader.getPage(counter)
        text = pageObj.extractText()
        
        m = re.search(r"(?<=County\n).*(?=Source)", text, flags=re.DOTALL) #re.DOTALL - makes the '.' special character match any character at all, including a newline
        data = m.group(0)
        data_list.extend(data.splitlines())
        
        counter += 1
        
    data_list.pop() #The last thing at the end of the PDF, on the last page, is some text. Removing it will make it easier to deal with the data.
    
    return (data_list)

# %% [markdown]
# Now lets check if my function worked.

# %%
temp = scrape_pdf('state_pdfs/al-alpha.pdf')
len(temp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-d43d49fd5d78> in <module>
# ----> 1 temp = scrape_pdf('state_pdfs/al-alpha.pdf')
#       2 len(temp)
#
# <ipython-input-13-8d65c24915c5> in scrape_pdf(pdf_file)
#       1 def scrape_pdf(pdf_file): #Accepts in a PDF and returns the text of the PDF broken at newlines.
#       2
# ----> 3     pdfFileObj = open(pdf_file, 'rb')               #Opens file
#       4     pdfReader = PyPDF2.PdfFileReader(pdfFileObj)    #Reads the file
#       5     pages = pdfReader.numPages                      #Gets the number of pages to cycle through
#
# FileNotFoundError: [Errno 2] No such file or directory: 'state_pdfs/al-alpha.pdf'

# %%
10043/7

# %% [markdown]
# There seems to be an issue. Had this worked properly, the above number should 1208 or at least a whole number. After reviewing the PDF, there is a newline character after some of the names. The following entry in the data is the `service` type.
#
# Since there is a limited number of military services, I will loop through the data checking the preceeding entires after the `name` column. If a name is broken into two lines, I will merge them into one. As long as the first entry is correct, this process will work for all the PDFs.

# %%
military = ['ARMY', 'NAVY', 'MARINE CORPS', 'AIR FORCE']

# %%
check = temp[:106]

counter = len(check)

while counter > 0:
    if check[1] not in military:
        
        print(check[1] + ' WHAT, WHAT?!')
        
        check[0] = check[0] + check[1]
        check.remove(check[1])
    
    print(check[:8])
    del check[:8]
    counter = len(check)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-19c9a3e7817c> in <module>
# ----> 1 check = temp[:106]
#       2
#       3 counter = len(check)
#       4
#       5 while counter > 0:
#
# NameError: name 'temp' is not defined

# %% [markdown]
# Fantastic, it works! now lets tweak this a bit and make a list of lists then I can throw into a `DataFrame` easily.

# %%
def prep_for_df(data_in_list, state):  #Takes in a list and the state, as a string. It will return a list of lists.
    
    big_long_list = data_in_list.copy()   #Making a deep copy, so I don't effect the underlying list. 
    output = []
    counter = len(big_long_list)

    while counter > 0:
        if big_long_list[1] not in military:

            big_long_list[0] = big_long_list[0] + ' ' + big_long_list[1]
            big_long_list.remove(big_long_list[1])

        place_holder = big_long_list[:8]
        place_holder.append(state)
        output.append(place_holder)
        del big_long_list[:8]
        counter = len(big_long_list)
    
    return(output)

# %%
bama = scrape_pdf('state_pdfs/al-alpha.pdf')
how_long = prep_for_df(bama, "AL")
len(how_long)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-cf160c754488> in <module>
# ----> 1 bama = scrape_pdf('state_pdfs/al-alpha.pdf')
#       2 how_long = prep_for_df(bama, "AL")
#       3 len(how_long)
#
# <ipython-input-13-8d65c24915c5> in scrape_pdf(pdf_file)
#       1 def scrape_pdf(pdf_file): #Accepts in a PDF and returns the text of the PDF broken at newlines.
#       2
# ----> 3     pdfFileObj = open(pdf_file, 'rb')               #Opens file
#       4     pdfReader = PyPDF2.PdfFileReader(pdfFileObj)    #Reads the file
#       5     pages = pdfReader.numPages                      #Gets the number of pages to cycle through
#
# FileNotFoundError: [Errno 2] No such file or directory: 'state_pdfs/al-alpha.pdf'

# %%
blerg = pd.DataFrame(how_long, columns = ['name', 'service', 'rank_rate', 'birthdate', 'home_city', 'home_county', 'incident_death', 'body_rec', 'state'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8b89d2594a4f> in <module>
# ----> 1 blerg = pd.DataFrame(how_long, columns = ['name', 'service', 'rank_rate', 'birthdate', 'home_city', 'home_county', 'incident_death', 'body_rec', 'state'])
#
# NameError: name 'how_long' is not defined

# %%
print(blerg.shape)
blerg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d3b23fbaaca9> in <module>
# ----> 1 print(blerg.shape)
#       2 blerg.head()
#
# NameError: name 'blerg' is not defined

# %% [markdown]
# Well it looks like I got everything all the peieces together. All that is is left to run through the folder of the PDFs, get the `state` from the file name, and let it go.

# %%
pdf_paths = glob.glob('data/state_pdfs/*.pdf')
pdf_paths
# Out:
# ['data/state_pdfs/me-alpha.pdf',
#  'data/state_pdfs/al-alpha.pdf',
#  'data/state_pdfs/la-alpha.pdf',
#  'data/state_pdfs/nm-alpha.pdf',
#  'data/state_pdfs/ks-alpha.pdf',
#  'data/state_pdfs/il-alpha.pdf',
#  'data/state_pdfs/sc-alpha.pdf',
#  'data/state_pdfs/wy-alpha.pdf',
#  'data/state_pdfs/mn-alpha.pdf',
#  'data/state_pdfs/wa-alpha.pdf',
#  'data/state_pdfs/ia-alpha.pdf',
#  'data/state_pdfs/ar-alpha.pdf',
#  'data/state_pdfs/tn-alpha.pdf',
#  'data/state_pdfs/sd-alpha.pdf',
#  'data/state_pdfs/pa-alpha.pdf',
#  'data/state_pdfs/md-alpha.pdf',
#  'data/state_pdfs/ca-alpha.pdf',
#  'data/state_pdfs/oh-alpha.pdf',
#  'data/state_pdfs/ct-alpha.pdf',
#  'data/state_pdfs/mi-alpha.pdf',
#  'data/state_pdfs/ny-alpha.pdf',
#  'data/state_pdfs/ak-alpha.pdf',
#  'data/state_pdfs/ky-alpha.pdf',
#  'data/state_pdfs/hi-alpha.pdf',
#  'data/state_pdfs/mo-alpha.pdf',
#  'data/state_pdfs/fl-alpha.pdf',
#  'data/state_pdfs/ut-alpha.pdf',
#  'data/state_pdfs/nj-alpha.pdf',
#  'data/state_pdfs/tx-alpha.pdf',
#  'data/state_pdfs/de-alpha.pdf',
#  'data/state_pdfs/co-alpha.pdf',
#  'data/state_pdfs/va-alpha.pdf',
#  'data/state_pdfs/vt-alpha.pdf',
#  'data/state_pdfs/ok-alpha.pdf',
#  'data/state_pdfs/in-alpha.pdf',
#  'data/state_pdfs/mt-alpha.pdf',
#  'data/state_pdfs/nd-alpha.pdf',
#  'data/state_pdfs/dc-alpha.pdf',
#  'data/state_pdfs/ma-alpha.pdf',
#  'data/state_pdfs/wv-alpha.pdf',
#  'data/state_pdfs/or-alpha.pdf',
#  'data/state_pdfs/ga-alpha.pdf',
#  'data/state_pdfs/wi-alpha.pdf',
#  'data/state_pdfs/nv-alpha.pdf',
#  'data/state_pdfs/az-alpha.pdf',
#  'data/state_pdfs/ms-alpha.pdf',
#  'data/state_pdfs/nc-alpha.pdf',
#  'data/state_pdfs/id-alpha.pdf',
#  'data/state_pdfs/ne-alpha.pdf',
#  'data/state_pdfs/nh-alpha.pdf',
#  'data/state_pdfs/ri-alpha.pdf']

# %% [markdown]
# Now lets throw it all together to test. I am going to verify it works for all the states and DC.

# %%
for pdf in pdf_paths:
    
    state = str(pdf[16:18].upper())
    
    print(pdf)
    print(state)
    
    place_holder = scrape_pdf(pdf)
    
    #print(place_holder)
    
    data = prep_for_df(place_holder, state)
    
    pd.DataFrame(data, columns = ['name', 'service', 'rank_rate', 'birthdate', 'home_city', 'home_county', 'incident_death', 'body_rec', 'state'])
# Out:
# data/state_pdfs/me-alpha.pdf
# ME
# data/state_pdfs/al-alpha.pdf
# AL
# data/state_pdfs/la-alpha.pdf
# LA
# data/state_pdfs/nm-alpha.pdf
# NM
# data/state_pdfs/ks-alpha.pdf
# KS
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-f83b9f0227e5> in <module>
#      10     #print(place_holder)
#      11
# ---> 12     data = prep_for_df(place_holder, state)
#      13
#      14     pd.DataFrame(data, columns = ['name', 'service', 'rank_rate', 'birthdate', 'home_city', 'home_county', 'incident_death', 'body_rec', 'state'])
#
# <ipython-input-17-96c37da1f4dc> in prep_for_df(data_in_list, state)
#       6
#       7     while counter > 0:
# ----> 8         if big_long_list[1] not in military:
#       9
#      10             big_long_list[0] = big_long_list[0] + ' ' + big_long_list[1]
#
# IndexError: list index out of range

# %% [markdown]
# There seems to be an issue with the KS records, so going to investigate that.

# %%
ks_data = scrape_pdf('data/state_pdfs/ks-alpha.pdf')

# %%
print(len(ks_data))
ks_data[:34]

# %%
prep_for_df(ks_data, 'KS')

# %% [markdown]
# My prep function is not working as intended. I am going to make a trouble shooting one that I will add print statesments enable to troubleshoot.

# %%
def TS_prep_for_df(data_in_list, state):  #Takes in a list and the state, as a string. It will return a list of lists.
    
    big_long_list = data_in_list.copy()    #Making a deep copy, so I don't effect the underlying list. 
    
    output = []
    
    counter = len(big_long_list)

    while counter > 0:
        
        if big_long_list[1] not in military:

            big_long_list[0] = big_long_list[0] + ' ' + big_long_list[1]
            big_long_list.remove(big_long_list[1])

        place_holder = big_long_list[:8]
        place_holder.append(state)
        
        output.append(place_holder)
        
        print(place_holder)
        
        del big_long_list[:8]
        counter = len(big_long_list)
    
    #return(output)

# %%
TS_prep_for_df(ks_data, 'KS')
# Out:
# ['ACHESON CHARLES  RALPH', 'ARMY', 'PFC', '19470120', 'PALCO', 'ROOKS', '19671121', 'Y', 'KS']
# ['ACOSTA JOSE FRANCISCO', 'MARINE CORPS', 'CPL', '19470525', 'WICHITA', 'SEDGWICK', '19671001', 'Y', 'KS']
# ['ADAM JOHN QUINCY', 'AIR FORCE', 'SMSGT', '19471222', 'BETHEL', 'WYANDOTTE', '19680522', 'N', 'KS']
# ['ADAMS THOMAS  EDWARD', 'NAVY', 'SN', '19451105', 'TOPEKA', 'SHAWNEE', '19690227', 'Y', 'KS']
# ['ADAMS WILLIAM CARL', 'MARINE CORPS', 'SGT', '19451002', 'JUNCTION CITY', 'GEARY', '19690823', 'Y', 'KS']
# ['ALDERMAN ANDREW  ALBERT', 'NAVY', 'PO3', '19440512', 'COFFEYVILLE', 'MONTGOMERY', '19670317', 'Y', 'KS']
# ['ALLENDORF MICHAEL  GEORGE', 'ARMY', 'CPL', '19480702', 'TOPEKA', 'SHAWNEE', '19690311', 'Y', 'KS']
# ['ALLGOOD FRANKIE  EUGENE', 'MARINE CORPS', 'LTCOL', '19300501', 'FT SCOTT', 'BOURBON', '19680326', 'N', 'KS']
# ['ALVORD RONNIE EUGENE', 'ARMY', 'PFC', '19470111', 'HUTCHINSON', 'RENO', '19680305', 'Y', 'KS']
# ['AMERINE KENT L', 'ARMY', 'SP4', '19430404', 'GREAT BEND', 'BARTON', '19660802', 'Y', 'KS']
# ['AMMANN ALBERT FRANK', 'ARMY', '1LT', '19440110', 'ARGONIA', 'SUMNER', '19700915', 'Y', 'KS']
# ['ANDERSON ALFRED EARL', 'MARINE CORPS', 'LCPL', '19480207', 'SUNFLOWER', 'JOHNSON', '19671106', 'Y', 'KS']
# ['ANDERSON DENIS LEON', 'NAVY', 'LTJG', '19421024', 'HOPE', 'DICKINSON', '19680111', 'Y', 'KS']
# ['ANDERSON JAMES  RICHMOND', 'ARMY', 'SSG', '19430807', 'SCRANTON', 'OSAGE', '19680209', 'Y', 'KS']
# ['ANDERSON LANNIE RAY', 'ARMY', 'PFC', '19500719', 'LINCOLN', 'LINCOLN', '19700211', 'Y', 'KS']
# ['APPLEGATE NEWELL F SR', 'ARMY', 'SGM', '19290728', 'EUREKA', 'GREENWOOD', '19710410', 'Y', 'KS']
# ['ARB FRANCIS LOREN', 'ARMY', 'PFC', '19430116', 'MELVERN', 'OSAGE', '19670601', 'Y', 'KS']
# ['ARBUTHNOT JAMES  MALCOLM', 'ARMY', 'SP4', '19461105', 'PRAIRIE ', 'VILLAGE', 'JOHNSON', '19660330', 'KS']
# ['Y ARNETT JAMES DOUGLAS', 'ARMY', 'PFC', '19490124', 'WICHITA', 'SEDGWICK', '19680915', 'Y', 'KS']
# ['ARNOLD RICHARD EARL', 'ARMY', 'SP4', '19410722', 'LARNED', 'PAWNEE', '19660129', 'Y', 'KS']
# ['AST STEVEN VINCENT', 'ARMY', 'CPL', '19500209', 'EMPORIA', 'LYON', '19710302', 'Y', 'KS']
# ['ATKINS JAMES', 'MARINE CORPS', 'LCPL', '19470610', 'WICHITA', 'SEDGWICK', '19691005', 'Y', 'KS']
# ['AVILA THOMAS ROBERT', 'MARINE CORPS', 'CPL', '19471221', 'WICHITA', 'SEDGWICK', '19680107', 'Y', 'KS']
# ['BADWAY VICTOR WOLF  JR', 'MARINE CORPS', 'LCPL', '19500925', 'WICHITA', 'SEDGWICK', '19700221', 'Y', 'KS']
# ['BAILEY CHARLES  CLIFFORD', 'ARMY', 'PFC', '19470424', 'EUREKA', 'GREENWOOD', '19680602', 'Y', 'KS']
# ['BALENTINE ROLAND JR', 'ARMY', 'PFC', '19480424', 'KANSAS CITY', 'WYANDOTTE', '19671003', 'Y', 'KS']
# ['BALES CHARLES ROBERT', 'ARMY', 'SP4', '19471117', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680822', 'KS']
# ['Y BALL MERLIN EUGENE', 'ARMY', 'PFC', '19470101', 'GARDEN CITY', 'FINNEY', '19670314', 'Y', 'KS']
# ['BANNON GARY CLIFFORD', 'ARMY', 'PFC', '19451009', 'LEON', 'BUTLER', '19670520', 'Y', 'KS']
# ['BARKSDALE JERRY DEAN', 'MARINE CORPS', 'LCPL', '19460514', 'BERRYTON', 'SHAWNEE', '19680131', 'Y', 'KS']
# ['BARNETT GARY JOE', 'ARMY', 'CPT', '19460513', 'MISSION', 'JOHNSON', '19700321', 'Y', 'KS']
# ['BARR TERRY LEE', 'ARMY', 'SP4', '19460522', 'KANSAS CITY', 'WYANDOTTE', '19690817', 'Y', 'KS']
# ['BARRETT GEORGE  DWAYNE', 'ARMY', 'PFC', '19440618', 'READING', 'LYON', '19680320', 'Y', 'KS']
# ['BAUER LAWRENCE  EDWARD', 'ARMY', 'CPL', '19460416', 'LOUISBURG', 'MIAMI', '19690430', 'Y', 'KS']
# ['BAUGHMAN JOHN OLIVER', 'ARMY', 'SGT', '19490513', 'JUNCTION CITY', 'GEARY', '19690419', 'Y', 'KS']
# ['BELDEN LARRY GENE', 'MARINE CORPS', 'PFC', '19491110', 'ESBON', 'JEWELL', '19690726', 'Y', 'KS']
# ['BELL CHARLES MARTIN', 'NAVY', 'PO3', '19421126', 'WATHENA', 'DONIPHAN', '19680103', 'Y', 'KS']
# ['BELLER WILLIAM  RUSSELL JR', 'MARINE CORPS', 'PFC', '19461027', 'SALINA', 'SALINE', '19670430', 'Y', 'KS']
# ['BENNEFELD STEVEN  HENRY', 'MARINE CORPS', 'PFC', '19471224', 'GIRARD', 'CRAWFORD', '19670729', 'N', 'KS']
# ['BERGAN MERLIN  HERMAN', 'ARMY', 'SFC', '19250826', 'JUNCTION CITY', 'GEARY', '19680812', 'Y', 'KS']
# ['BERGER GERALD DAVID', 'MARINE CORPS', 'CAPT', '19420707', 'TOPEKA', 'SHAWNEE', '19680805', 'Y', 'KS']
# ['BERRIER TOMMY JOE', 'MARINE CORPS', 'LCPL', '19500125', 'KANSAS CITY', 'WYANDOTTE', '19690816', 'Y', 'KS']
# ['BERWERT PATRICK  MICHAEL', 'MARINE CORPS', 'PFC', '19470323', 'TOPEKA', 'SHAWNEE', '19680325', 'Y', 'KS']
# ['BICKFORD RALPH NEVIN', 'ARMY', 'CPL', '19490121', 'WICHITA', 'SEDGWICK', '19690322', 'Y', 'KS']
# ['BILLINGSLY LEE WAYNE', 'ARMY', 'CPT', '19440426', 'HUTCHINSON', 'RENO', '19720722', 'Y', 'KS']
# ['BINDER GARY LEE', 'NAVY', 'CN', '19461206', 'HAYS', 'ELLIS', '19671013', 'Y', 'KS']
# ['BIRD DANNIE LEON', 'ARMY', 'SP4', '19471230', 'WEBBER', 'JEWELL', '19690114', 'Y', 'KS']
# ['BIRD SAMUEL RICHARD', 'ARMY', 'MAJ', '19400127', 'WICHITA', 'SEDGWICK', '19670127', 'Y', 'KS']
# ['BISHOP JAMES LOUIS', 'ARMY', 'SP4', '19460227', 'WICHITA', 'SEDGWICK', '19690623', 'Y', 'KS']
# ['BITTLE DOUGLAS ROBERT', 'ARMY', 'SP4', '19431004', 'ARKANSAS ', 'CITY', 'COWLEY', '19690621', 'KS']
# ['Y BLAND ISAAC', 'ARMY', 'PFC', '19421229', 'WICHITA', 'SEDGWICK', '19680320', 'Y', 'KS']
# ['BLANSCET MICHAEL  JOHN', 'ARMY', 'CPT', '19481203', 'MERRIAM', 'JOHNSON', '19700606', 'Y', 'KS']
# ['BLITCH BERNARD L', 'ARMY', 'SP5', '19320418', 'JUNCTION CITY', 'GEARY', '19660916', 'Y', 'KS']
# ['BOESE ROBERT LEE', 'ARMY', 'CPL', '19461229', 'MARION', 'MARION', '19690523', 'Y', 'KS']
# ['BOOLIN CLARENCE  HENRY', 'ARMY', 'SP4', '19480317', 'OVERLAND ', 'PARK', 'JOHNSON', '19690322', 'KS']
# ['Y BORDERS DARELD ', 'NORVAL', 'ARMY', 'SGT', '19470210', 'MISSION', 'JOHNSON', '19680702', 'KS']
# ['Y BOWLES HARRY OWEN', 'ARMY', 'SP4', '19530413', 'DOWNS', 'OSBORNE', '19711017', 'Y', 'KS']
# ['BOWLING JOSEPH PERRY', 'ARMY', 'SGT', '19440127', 'WICHITA', 'SEDGWICK', '19680211', 'Y', 'KS']
# ['BOWMAN DONALD  ROBERT', 'ARMY', 'PFC', '19471124', 'LAWRENCE', 'DOUGLAS', '19680208', 'Y', 'KS']
# ['BOYD RICHARD EUGENE', 'NAVY', 'SN', '19440723', 'LAWRENCE', 'DOUGLAS', '19680325', 'Y', 'KS']
# ['BRACK HARRY HUBERT  JR', 'ARMY', 'PFC', '19501204', 'LEOTI', 'WICHITA', '19711022', 'Y', 'KS']
# ['BRADBURY STEVEN  WAYNE', 'ARMY', 'SP4', '19490119', 'WICHITA', 'SEDGWICK', '19690713', 'Y', 'KS']
# ['BRADFORD ALLEN ROYAL', 'ARMY', 'CPL', '19470101', 'LIBERAL', 'SEWARD', '19680507', 'Y', 'KS']
# ['BRANDT GEAROLD LEE', 'ARMY', 'PFC', '19500508', 'SALINA', 'SALINE', '19690610', 'Y', 'KS']
# ['BRAY RALPH OSCAR JR', 'ARMY', 'CPT', '19420612', 'OLATHE', 'JOHNSON', '19690712', 'Y', 'KS']
# ['BREEDING MICHAEL  HUGH', 'MARINE CORPS', '1STLT', '19450319', 'BLUE RAPIDS', 'MARSHALL', '19700212', 'N', 'KS']
# ['BRENNER DAVID ALDEN', 'ARMY', 'SSG', '19460402', 'PARSONS', 'LABETTE', '19680401', 'Y', 'KS']
# ['BRENNER DAVID GEORGE', 'AIR FORCE', 'MAJ', '19330926', 'MANHATTAN', 'RILEY', '19680613', 'Y', 'KS']
# ['BRENNER KENNETH  JAMES', 'ARMY', 'CPL', '19480615', 'HOPE', 'DICKINSON', '19690329', 'Y', 'KS']
# ['BRESHEARS ALAN  WAYNE', 'NAVY', 'PO3', '19481010', 'FT SCOTT', 'BOURBON', '19690812', 'Y', 'KS']
# ['BROOKS BARTON W', 'ARMY', 'SP4', '19470118', 'CLAYTON', 'DECATUR', '19680225', 'Y', 'KS']
# ['BROWN KENNETH  LAVERN', 'ARMY', 'SP5', '19500111', 'FT SCOTT', 'BOURBON', '19701102', 'Y', 'KS']
# ['BROWNING GARY LEE', 'ARMY', 'SP4', '19480909', 'HUTCHINSON', 'RENO', '19680918', 'Y', 'KS']
# ['BROWNING RAYMOND  VENSON', 'ARMY', 'CPL', '19460806', 'LAWRENCE', 'DOUGLAS', '19671012', 'Y', 'KS']
# ['BRULL MICHAEL JOSEPH', 'ARMY', 'SGT', '19471016', 'ATCHISON', 'ATCHISON', '19690508', 'Y', 'KS']
# ['BRYANT BOBBY RAY', 'ARMY', 'PFC', '19470517', 'WICHITA', 'SEDGWICK', '19661002', 'Y', 'KS']
# ['BUCHANAN JACK LYNN', 'MARINE CORPS', 'CPL', '19471009', 'WICHITA', 'SEDGWICK', '19670901', 'Y', 'KS']
# ['BUCKRIDGE MARVIN  DOUGLAS', 'ARMY', 'SP4', '19480105', 'EMPORIA', 'LYON', '19670818', 'Y', 'KS']
# ['BUNCH JAMES GEORGE JR', 'ARMY', 'SGT', '19480428', 'TOPEKA', 'SHAWNEE', '19690409', 'Y', 'KS']
# ['BURGESS LAWRENCE  DEAN', 'ARMY', 'SGT', '19491228', 'OTTAWA', 'FRANKLIN', '19700606', 'Y', 'KS']
# ['BURKETT CLOYCE ORAL  JR', 'AIR FORCE', 'TSGT', '19301104', 'KANSAS CITY', 'WYANDOTTE', '19671008', 'Y', 'KS']
# ['BURNAM STEVEN WAYNE', 'ARMY', 'SP4', '19480414', 'WICHITA', 'SEDGWICK', '19681104', 'Y', 'KS']
# ['BUSH EDWARD L', 'ARMY', 'WO1', '19430312', 'WICHITA', 'SEDGWICK', '19670320', 'Y', 'KS']
# ['BUTTS DARRELL WAYNE', 'ARMY', 'PFC', '19480327', 'WICHITA', 'SEDGWICK', '19670622', 'Y', 'KS']
# ['CALVIN STANLEY DEAN', 'ARMY', 'SP4', '19490404', 'EL DORADO', 'BUTLER', '19700221', 'Y', 'KS']
# ['CAMDEN JOHNNIE ROGER', 'MARINE CORPS', 'PFC', '19500410', 'WICHITA', 'SEDGWICK', '19680714', 'Y', 'KS']
# ['CANADY TROY VERNAL', 'ARMY', 'SP4', '19510102', 'KANSAS CITY', 'WYANDOTTE', '19700413', 'Y', 'KS']
# ['CANFIELD BOYD', 'ARMY', 'CPL', '19480530', 'TOPEKA', 'SHAWNEE', '19680828', 'Y', 'KS']
# ['CAREY BARTON  WAINWRIGHT', 'ARMY', 'PFC', '19460426', 'MANHATTAN', 'RILEY', '19680326', 'Y', 'KS']
# ['CARLEY TIMOTHY LYNN', 'ARMY', 'SP4', '19490330', 'EMPORIA', 'LYON', '19690326', 'Y', 'KS']
# ['CARTER OTIS', 'ARMY', 'PFC', '19500615', 'INDEPENDENCE', 'MONTGOMERY', '19700930', 'Y', 'KS']
# ['CASE DANIEL CHARLES', 'NAVY', 'SN', '19450712', 'WICHITA', 'SEDGWICK', '19700411', 'Y', 'KS']
# ['CASTOR JAMES WILLIAM', 'MARINE CORPS', 'CPL', '19480924', 'NATOMA', 'OSBORNE', '19690813', 'Y', 'KS']
# ['CHADWICK BILLY  RAYMOND', 'ARMY', 'SP4', '19480903', 'MANHATTAN', 'RILEY', '19690617', 'Y', 'KS']
# ['CHAPMAN KURTIS NOLAN', 'MARINE CORPS', 'LCPL', '19471202', 'OVERLAND ', 'PARK', 'JOHNSON', '19680509', 'KS']
# ['Y CHRISTESON LEONARD ', 'WAYNE', 'ARMY', 'PFC', '19490227', 'DURHAM', 'MARION', '19680812', 'KS']
# ['Y CHRISTIAN DAVID ', 'MARION', 'NAVY', 'LTJG', '19410115', 'LANE', 'FRANKLIN', '19650602', 'KS']
# ['Y CLAFLIN RICHARD AMES', 'AIR FORCE', 'MAJ', '19390702', 'KANSAS CITY', 'WYANDOTTE', '19670726', 'N', 'KS']
# ['CLARK LARRY RAY', 'ARMY', 'SP5', '19420518', 'WICHITA', 'SEDGWICK', '19690619', 'Y', 'KS']
# ['CLARK RONNIE LEE', 'ARMY', 'CPL', '19480217', 'HUGOTON', 'STEVENS', '19680225', 'Y', 'KS']
# ['CLARK TIMOTHY  RICHARD', 'ARMY', 'PFC', '19460325', 'KANSAS CITY', 'WYANDOTTE', '19670608', 'Y', 'KS']
# ['COE KENNETH EUGENE', 'ARMY', 'SP4', '19451215', 'ANTHONY', 'HARPER', '19670702', 'Y', 'KS']
# ['COLLINS GARY DEAN', 'NAVY', 'SN', '19480817', 'JAMESTOWN', 'CLOUD', '19680928', 'Y', 'KS']
# ['COMER WILLIAM  MARVIN JR', 'NAVY', 'PO2', '19421210', 'LARNED', 'PAWNEE', '19680201', 'Y', 'KS']
# ['CONRARDY RICHARD  JOHN', 'ARMY', 'PFC', '19510505', 'WRIGHT', 'FORD', '19700702', 'Y', 'KS']
# ['CONROY RONALD LEE', 'ARMY', 'WO1', '19471103', 'TOPEKA', 'SHAWNEE', '19681003', 'Y', 'KS']
# ['COOMBS DAN L F III', 'ARMY', '1LT', '19470401', 'OVERLAND ', 'PARK', 'JOHNSON', '19701219', 'KS']
# ['Y COON KEITH DAVID ED ', 'WILL', 'MARINE CORPS', 'PFC', '19490316', 'TOPEKA', 'SHAWNEE', '19680216', 'KS']
# ['Y COOPER CHARLES ', 'EDWARD', 'ARMY', 'SGT', '19380217', 'BELLE PLAINE', 'SUMNER', '19660415', 'KS']
# ['Y COOPER JAMES ', 'RAYMOND', 'MARINE CORPS', 'PFC', '19470801', 'LAWRENCE', 'DOUGLAS', '19670510', 'KS']
# ['Y COPELAND WILLIAM E II', 'MARINE CORPS', 'LCPL', '19461114', 'ESKRIDGE', 'WABAUNSEE', '19660325', 'Y', 'KS']
# ['CORCORAN BRUCE  ANTHONY', 'ARMY', 'PFC', '19470611', 'OBERLIN', 'DECATUR', '19670319', 'Y', 'KS']
# ['CORR CLIFFORD WAYNE', 'ARMY', 'SGT', '19491005', 'VIOLA', 'SEDGWICK', '19710328', 'Y', 'KS']
# ['COSTELLO LAWRENCE R', 'ARMY', 'SGT', '19410312', 'KANSAS CITY', 'WYANDOTTE', '19661101', 'Y', 'KS']
# ['COURTNEY JAMES IRA', 'ARMY', 'SSG', '19240310', 'KANSAS CITY', 'WYANDOTTE', '19660608', 'Y', 'KS']
# ['COWAN SAMUEL PAIGE JR', 'ARMY', 'SP4', '19470912', 'KANSAS CITY', 'WYANDOTTE', '19680418', 'Y', 'KS']
# ['COX GARY DEAN', 'MARINE CORPS', 'PFC', '19480501', 'KANSAS CITY', 'WYANDOTTE', '19681117', 'Y', 'KS']
# ['CRAIG EDWARD LEE', 'ARMY', 'SP4', '19490120', 'LIBERAL', 'SEWARD', '19700201', 'Y', 'KS']
# ['CRAIG JIMMY LEON', 'MARINE CORPS', 'LCPL', '19490403', 'MULVANE', 'MULTIPLE', '19670929', 'Y', 'KS']
# ['CRAIG REX LEE', 'MARINE CORPS', 'CAPT', '19421010', 'KANSAS CITY', 'WYANDOTTE', '19670405', 'Y', 'KS']
# ['CRAWSHAW STEEVE  ALEXANDER', 'ARMY', 'SSG', '19461229', 'WILLIAMSTOW', 'N', 'JEFFERSON', '19690506', 'KS']
# ['Y CRIST KENNETH ROY', 'AIR FORCE', 'CAPT', '19440825', 'BREWSTER', 'THOMAS', '19681217', 'Y', 'KS']
# ['CRUSE GEORGE LARRY', 'ARMY', 'PFC', '19471005', 'LIBERAL', 'SEWARD', '19680502', 'Y', 'KS']
# ['CUNNINGHAM CARL  EDWIN', 'MARINE CORPS', 'PFC', '19441209', 'NEOSHO ', 'RAPIDS', 'LYON', '19690716', 'KS']
# ['Y DANIELS JAMES MICHAEL', 'MARINE CORPS', 'LCPL', '19460328', 'WICHITA', 'SEDGWICK', '19670907', 'Y', 'KS']
# ['DARTY OMER GENE', 'ARMY', 'PSG', '19280514', 'FT RILEY', 'MULTIPLE', '19651210', 'Y', 'KS']
# ['DAVENPORT JOHN  JUNIOR', 'ARMY', 'SP4', '19400602', 'JUNCTION CITY', 'GEARY', '19650731', 'Y', 'KS']
# ['DAVIS CHARLES EUGENE', 'MARINE CORPS', 'CPL', '19471022', 'WICHITA', 'SEDGWICK', '19680428', 'Y', 'KS']
# ['DAVIS EMMETT RAY', 'MARINE CORPS', 'PFC', '19480419', 'KANSAS CITY', 'WYANDOTTE', '19661122', 'Y', 'KS']
# ['DAVIS JAMES THOMAS', 'AIR FORCE', 'CAPT', '19370824', 'HUGOTON', 'STEVENS', '19670708', 'Y', 'KS']
# ['DAVIS JOHN LAWRENCE', 'MARINE CORPS', 'LCPL', '19481128', 'PLEASANTON', 'LINN', '19680829', 'Y', 'KS']
# ['DAVIS YALE REZIN JR', 'AIR FORCE', 'MAJ', '19331220', 'SALINA', 'SALINE', '19681119', 'Y', 'KS']
# ['DECOW MELVIN DALE', 'MARINE CORPS', 'LCPL', '19431005', 'DENNIS', 'LABETTE', '19680525', 'Y', 'KS']
# ['DELAUGHDER DAVID LEE', 'MARINE CORPS', 'PFC', '19490219', 'AUGUSTA', 'BUTLER', '19670420', 'Y', 'KS']
# ['DENNIS WILLIAM R III', 'NAVY', 'SA', '19460707', 'LAWRENCE', 'DOUGLAS', '19670318', 'Y', 'KS']
# ['DENTON DENNIS ALAN', 'MARINE CORPS', 'PFC', '19500131', 'HOLTON', 'JACKSON', '19690917', 'Y', 'KS']
# ['DERRITT EDDIE RAY', 'MARINE CORPS', 'CPL', '19450720', 'LEAVENWORTH', 'LEAVENWORTH', '19660503', 'Y', 'KS']
# ['DICKEY DERREL KEITH', 'ARMY', 'SGT', '19500211', 'ARCADIA', 'CRAWFORD', '19700723', 'Y', 'KS']
# ['DICKEY GARY LYNN', 'MARINE CORPS', 'LCPL', '19431107', 'WICHITA', 'SEDGWICK', '19650723', 'Y', 'KS']
# ['DICKINSON DANIEL  ALBERT', 'ARMY', 'SP4', '19440811', 'WICHITA', 'SEDGWICK', '19651206', 'Y', 'KS']
# ['DIEDERICH JOHN LEO', 'ARMY', 'SGT', '19480129', 'JENNINGS', 'DECATUR', '19680823', 'Y', 'KS']
# ['DILLON DONALD EUGENE', 'MARINE CORPS', 'SSGT', '19340812', 'LAWRENCE', 'DOUGLAS', '19670706', 'Y', 'KS']
# ['DILORENZO RAYMOND  JOHN', 'ARMY', '1LT', '19440727', 'EDNA', 'LABETTE', '19700207', 'Y', 'KS']
# ['DIMITT ROBERT VICTOR', 'ARMY', 'SP4', '19470827', 'JOHNSON', 'STANTON', '19681024', 'Y', 'KS']
# ['DODGE WARD KENT', 'AIR FORCE', 'COL', '19290314', 'DIGHTON', 'LANE', '19670705', 'Y', 'KS']
# ['DODSON ERNEST DEAN', 'ARMY', 'SP4', '19460716', 'WICHITA', 'SEDGWICK', '19690103', 'Y', 'KS']
# ['DONOVAN MICHAEL LEO', 'AIR FORCE', 'CAPT', '19441109', 'NORTON', 'NORTON', '19710930', 'N', 'KS']
# ['DOORNBOS DON  MICHAEL', 'MARINE CORPS', 'CPL', '19460218', 'WICHITA', 'SEDGWICK', '19680214', 'Y', 'KS']
# ['DORNON CHARLES  WILLIAM', 'ARMY', 'SP4', '19460826', 'WICHITA', 'SEDGWICK', '19690618', 'Y', 'KS']
# ['DORSEY LEWIS R G', 'ARMY', 'PFC', '19471109', 'EMPORIA', 'LYON', '19680312', 'Y', 'KS']
# ['DOTTER EDWIN EARL', 'ARMY', 'SGT', '19421029', 'WICHITA', 'SEDGWICK', '19690530', 'Y', 'KS']
# ['DROUHARD PETER  AUGUST', 'ARMY', 'SP4', '19480115', 'WICHITA', 'SEDGWICK', '19690714', 'Y', 'KS']
# ['DUDLEY GARY WILLIAM', 'MARINE CORPS', 'PFC', '19500524', 'TOPEKA', 'SHAWNEE', '19690114', 'Y', 'KS']
# ['DUKELOW CORNELIOUS  P II', 'ARMY', 'PFC', '19460510', 'KANSAS CITY', 'WYANDOTTE', '19690122', 'Y', 'KS']
# ['ECKELL JOHN W', 'ARMY', 'SP4', '19450325', 'ISABEL', 'BARBER', '19680505', 'Y', 'KS']
# ['ECKHART RUSS EUGENE', 'MARINE CORPS', 'LCPL', '19470108', 'NORCATUR', 'DECATUR', '19670529', 'Y', 'KS']
# ['EISENHOUR JAMES  DOYLE', 'ARMY', 'WO1', '19451010', 'LA CROSSE', 'RUSH', '19680818', 'Y', 'KS']
# ['EITEL JACK ORVAL', 'MARINE CORPS', '1STLT', '19410727', 'SCOTT CITY', 'SCOTT', '19650708', 'Y', 'KS']
# ['ELDRIDGE JAMES WILBUR', 'ARMY', 'PFC', '19461202', 'NICKERSON', 'RENO', '19670519', 'Y', 'KS']
# ['ELGAARD ROBERT JAMES', 'MARINE CORPS', 'CAPT', '19350529', 'WICHITA', 'SEDGWICK', '19670205', 'Y', 'KS']
# ['ELLIOTT ROBERT JOE', 'ARMY', 'CW2', '19500125', 'WELLINGTON', 'SUMNER', '19710908', 'Y', 'KS']
# ['ELSENRATH JOHN JOE', 'ARMY', 'SGT', '19431207', 'WICHITA', 'SEDGWICK', '19690329', 'Y', 'KS']
# ['EMBREY RALPH CURTIS II', 'ARMY', 'CW2', '19461019', 'VIRGIL', 'GREENWOOD', '19700413', 'Y', 'KS']
# ['EMERY JOE LOUIS', 'ARMY', 'PFC', '19490607', 'LEAVENWORTH', 'LEAVENWORTH', '19681227', 'Y', 'KS']
# ['ENLOW PHILIP JAMES', 'ARMY', 'SP5', '19500228', 'MANHATTAN', 'RILEY', '19691101', 'Y', 'KS']
# ['EVANS DONALD ALLEN', 'ARMY', 'CPT', '19341020', 'AUGUSTA', 'BUTLER', '19680130', 'Y', 'KS']
# ['EVANS GERALD BRUCE', 'ARMY', 'SGT', '19300927', 'JUNCTION CITY', 'GEARY', '19651117', 'Y', 'KS']
# ['EVANS JAMES JOSEPH', 'NAVY', 'CDR', '19300509', 'VALLEY FALLS', 'JEFFERSON', '19650402', 'Y', 'KS']
# ['EVERHART WILLIAM  JOSEPH', 'ARMY', 'SFC', '19310724', 'CANTON', 'MCPHERSON', '19631108', 'Y', 'KS']
# ['FEARNO JOSEPH  BARNETT', 'AIR FORCE', 'MAJ', '19320717', 'COOLIDGE', 'HAMILTON', '19660321', 'Y', 'KS']
# ['FEW SAMUEL ARTHUR', 'ARMY', '1LT', '19440818', 'KANSAS CITY', 'WYANDOTTE', '19680820', 'Y', 'KS']
# ['FIFFE RICHARD LEE', 'ARMY', 'CPL', '19490419', 'CONCORDIA', 'CLOUD', '19690320', 'Y', 'KS']
# ['FINCH JOHN WEBSTER', 'ARMY', 'SP4', '19450911', 'ARKANSAS ', 'CITY', 'COWLEY', '19650630', 'KS']
# ['Y FISHER HENRY LEE', 'ARMY', 'PFC', '19470531', 'HAVEN', 'RENO', '19670618', 'Y', 'KS']
# ['FONSECA MICHAEL  JEROME', 'MARINE CORPS', 'PFC', '19470608', 'GARDNER', 'JOHNSON', '19671027', 'Y', 'KS']
# ['FORD JOSEPH AVERLL III', 'MARINE CORPS', 'LCPL', '19430831', 'PARSONS', 'LABETTE', '19650824', 'Y', 'KS']
# ['FORREST MONTE WAYNE', 'ARMY', 'CPL', '19481106', 'ARGONIA', 'SUMNER', '19700805', 'Y', 'KS']
# ['FOUNDS GERALD DEAN', 'ARMY', 'SP5', '19290325', 'FRANKFORT', 'MARSHALL', '19650207', 'Y', 'KS']
# ['FOWLER JAMES ISIAH JR', 'ARMY', 'SGT', '19391027', 'WHITE CITY', 'MORRIS', '19680804', 'Y', 'KS']
# ['FRY ROLLAND KEITH', 'ARMY', 'SP4', '19490225', 'HUTCHINSON', 'RENO', '19690502', 'Y', 'KS']
# ['FUQUA HARRY IVAN JR', 'ARMY', 'PFC', '19470701', 'LEAVENWORTH', 'LEAVENWORTH', '19680229', 'Y', 'KS']
# ['GADSON EDDIE DEAN', 'MARINE CORPS', 'PFC', '19490309', 'SALINA', 'SALINE', '19680508', 'Y', 'KS']
# ['GANDY MICHAEL LEE', 'ARMY', '2LT', '19451015', 'DEXTER', 'COWLEY', '19680329', 'Y', 'KS']
# ['GARDNER SAMUEL RAY', 'ARMY', '1LT', '19430507', 'WICHITA', 'SEDGWICK', '19680505', 'Y', 'KS']
# ['GARRETT JAMES  MICHAEL', 'NAVY', 'PO3', '19470816', 'TOPEKA', 'SHAWNEE', '19691129', 'Y', 'KS']
# ['GENTRY HENRY JR', 'ARMY', 'PFC', '19390930', 'WICHITA', 'SEDGWICK', '19651205', 'Y', 'KS']
# ['GERBER MICHAEL  EUGENE', 'ARMY', 'SP4', '19480916', 'CONWAY ', 'SPRINGS', 'SUMNER', '19690527', 'KS']
# ['Y GFELLER JOHN HERBERT', 'ARMY', 'PSG', '19330214', 'ABILENE', 'DICKINSON', '19680219', 'Y', 'KS']
# ['GIBSON DAVID PARKER', 'ARMY', 'CPT', '19390220', 'LAWRENCE', 'DOUGLAS', '19670408', 'Y', 'KS']
# ['GILLASPIE PAUL THOMAS', 'ARMY', 'SGT', '19500501', 'TOPEKA', 'SHAWNEE', '19701127', 'Y', 'KS']
# ['GILLEN THOMAS ELDON', 'AIR FORCE', 'COL', '19330508', 'KINGMAN', 'KINGMAN', '19700218', 'N', 'KS']
# ['GIRDNER ROBERT ORAL', 'ARMY', 'PFC', '19460416', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680404', 'KS']
# ['Y GLADDEN JAMES ', 'TAYLOR JR', 'NAVY', 'PO2', '19400606', 'WATHENA', 'DONIPHAN', '19700612', 'KS']
# ['Y GLAZE KENNETH LEE', 'MARINE CORPS', 'SSGT', '19330131', 'HUTCHINSON', 'RENO', '19660823', 'Y', 'KS']
# ['GLYNN DENNIS WAYNE', 'MARINE CORPS', 'PFC', '19490820', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680912', 'KS']
# ['Y GODSEY JAMES ', 'FREDERICK', 'ARMY', '1LT', '19420815', 'HUMBOLDT', 'ALLEN', '19670824', 'KS']
# ['Y GOOCH WESLEY LEE', 'ARMY', 'PFC', '19470428', 'LEAVENWORTH', 'LEAVENWORTH', '19680112', 'Y', 'KS']
# ['GOODE JACK DEE', 'ARMY', 'SP4', '19470217', 'TOPEKA', 'SHAWNEE', '19680421', 'Y', 'KS']
# ['GOODNER ROBERT  EUGENE', 'ARMY', 'PFC', '19491208', 'IOLA', 'ALLEN', '19690521', 'Y', 'KS']
# ['GOODWIN BOB JACK', 'ARMY', 'CPL', '19480116', 'WICHITA', 'SEDGWICK', '19670903', 'Y', 'KS']
# ['GORDON JOHN SWAIN', 'ARMY', 'SP4', '19470606', 'NORTH ', 'WICHITA', 'SEDGWICK', '19671115', 'KS']
# ['Y GORMAN EDWARD ', 'THEODORE III', 'MARINE CORPS', 'CPL', '19460902', 'MANHATTAN', 'RILEY', '19680516', 'KS']
# ['Y GOSSELIN PHILIP LYN', 'MARINE CORPS', 'CPL', '19490622', 'TOPEKA', 'SHAWNEE', '19680728', 'Y', 'KS']
# ['GOUDY RICHARD LEE', 'AIR FORCE', 'CAPT', '19380314', 'SHARON ', 'SPRINGS', 'WALLACE', '19650809', 'KS']
# ['Y GRABER JOHN ALLEN JR', 'MARINE CORPS', 'PFC', '19480620', 'WICHITA', 'SEDGWICK', '19670316', 'Y', 'KS']
# ['GRACE MARTIN JOSEPH  JR', 'MARINE CORPS', 'PFC', '19480314', 'TOPEKA', 'SHAWNEE', '19680526', 'Y', 'KS']
# ['GRAHAM DENNIS LEE', 'AIR FORCE', 'CAPT', '19410511', 'GREENSBURG', 'KIOWA', '19680328', 'N', 'KS']
# ['GREATHOUSE ROBERT  CHARLES', 'ARMY', 'PFC', '19490916', 'HUTCHINSON', 'RENO', '19691012', 'Y', 'KS']
# ['GREEN DENNIS BLAINE', 'NAVY', 'SA', '19490113', 'HUTCHINSON', 'RENO', '19690119', 'Y', 'KS']
# ['GREEN LUTHER JR', 'ARMY', 'PFC', '19460917', 'PARSONS', 'LABETTE', '19701212', 'Y', 'KS']
# ['GREER CHARLES ROBERT', 'ARMY', 'PFC', '19451023', 'THAYER', 'NEOSHO', '19670321', 'Y', 'KS']
# ['GRETENCORD DEAN LEE', 'ARMY', 'PFC', '19410811', 'RICHMOND', 'FRANKLIN', '19670926', 'Y', 'KS']
# ['GRIFFIN KEITH D', 'ARMY', 'SGT', '19360927', 'HUTCHINSON', 'RENO', '19670316', 'Y', 'KS']
# ['GRIFFIN PATRICK JOSEPH', 'NAVY', 'PO3', '19461025', 'TOPEKA', 'SHAWNEE', '19680818', 'Y', 'KS']
# ['GROTHAUS ROBERT  JOHN II', 'ARMY', 'PFC', '19470323', 'PRAIRIE ', 'VILLAGE', 'JOHNSON', '19680514', 'KS']
# ['Y GUILLEN JOHN DAVID', 'ARMY', 'CPL', '19480823', 'WICHITA', 'SEDGWICK', '19700202', 'Y', 'KS']
# ['GURTLER CHARLES  RONALD', 'MARINE CORPS', 'LCPL', '19451213', 'WICHITA', 'SEDGWICK', '19660421', 'Y', 'KS']
# ['GUYER ALBERT  MARSHALL', 'ARMY', '1LT', '19420824', 'KANSAS CITY', 'WYANDOTTE', '19670408', 'Y', 'KS']
# ['HADLEY LEO LARRY', 'ARMY', '1LT', '19431009', 'MANHATTAN', 'RILEY', '19680814', 'Y', 'KS']
# ['HAGEMAN JOEL THOMAS', 'ARMY', 'CPT', '19461021', 'WICHITA', 'SEDGWICK', '19710312', 'Y', 'KS']
# ['HALBOWER HARLOW  KENNETH', 'AIR FORCE', 'CAPT', '19361224', 'ANTHONY', 'HARPER', '19660102', 'Y', 'KS']
# ['HALE VICTOR', 'MARINE CORPS', 'LCPL', '19421027', 'TOPEKA', 'SHAWNEE', '19681208', 'Y', 'KS']
# ['HANDSHUMAKER LLOYD  E JR', 'ARMY', 'PFC', '19471013', 'COFFEYVILLE', 'MONTGOMERY', '19690517', 'Y', 'KS']
# ['HARBOUR DEXTER  DUANE', 'ARMY', 'SP4', '19500827', 'ULYSSES', 'GRANT', '19700220', 'Y', 'KS']
# ['HARRIS JOHN JAMES', 'MARINE CORPS', 'CPL', '19480703', 'IOLA', 'ALLEN', '19680317', 'Y', 'KS']
# ['HARRIS ROBERT LEE', 'ARMY', 'SFC', '19271007', 'JUNCTION CITY', 'GEARY', '19690904', 'Y', 'KS']
# ['HARRISON JIMMY KEN', 'ARMY', 'SP5', '19481231', 'WICHITA', 'SEDGWICK', '19691101', 'Y', 'KS']
# ['HARROLD PATRICK  KENDAL', 'AIR FORCE', 'CAPT', '19441217', 'FT ', 'LEAVENWORTH', 'LEAVENWORTH', '19691205', 'KS']
# ['Y HARVEY LARRY WAYNE', 'ARMY', 'SSG', '19430629', 'INDEPENDENCE', 'MONTGOMERY', '19720321', 'Y', 'KS']
# ['HASSETT JAMES PETER', 'ARMY', 'SSG', '19490503', 'SHAWNEE', 'JOHNSON', '19700605', 'Y', 'KS']
# ['HAUG RONALD LEE', 'ARMY', 'SSG', '19481021', 'WICHITA', 'SEDGWICK', '19700213', 'Y', 'KS']
# ['HAWTHORNE WILLIAM  ALLEN', 'ARMY', 'PFC', '19470116', 'EUREKA', 'GREENWOOD', '19671120', 'Y', 'KS']
# ['HAYES GEORGE E', 'ARMY', 'SGT', '19410328', 'WILLIAMSTOW', 'N', 'JEFFERSON', '19660214', 'KS']
# ['Y HAYS CLIFTON WALTER', 'ARMY', 'SP5', '19200808', 'WALDO', 'RUSSELL', '19651110', 'Y', 'KS']
# ['HAYWOOD JAZREAL  LEVITE', 'ARMY', 'PSG', '19330510', 'JUNCTION CITY', 'GEARY', '19680305', 'Y', 'KS']
# ['HAZELWOOD JOHN  EDWARD', 'MARINE CORPS', 'CPL', '19440209', 'GYPSUM', 'SALINE', '19680528', 'Y', 'KS']
# ['HEAD DAVID NEIL', 'ARMY', 'CPT', '19450111', 'ARKANSAS ', 'CITY', 'COWLEY', '19710220', 'KS']
# ['Y HEFFNER STEVEN ', 'CLINTON', 'ARMY', 'SP4', '19490823', 'WINFIELD', 'COWLEY', '19680426', 'KS']
# ['Y HEMMINGWAY CHARLES ', 'LYNN', 'ARMY', '1LT', '19430225', 'DODGE CITY', 'FORD', '19670613', 'KS']
# ['Y HENDRICKSON GARY ', 'ARLAND', 'MARINE CORPS', 'PFC', '19470804', 'OTTAWA', 'FRANKLIN', '19670301', 'KS']
# ['Y HENDRICKSON GAYLORD ', 'BLAIN', 'ARMY', 'PSG', '19320617', 'MISSION', 'JOHNSON', '19680605', 'KS']
# ['Y HENDRIX JERRY WAYNE', 'MARINE CORPS', 'SSGT', '19421227', 'WICHITA', 'SEDGWICK', '19720711', 'Y', 'KS']
# ['HERRIMAN RONNIE LEE', 'ARMY', 'SP4', '19420118', 'MARQUETTE', 'MCPHERSON', '19690725', 'Y', 'KS']
# ['HESKETT JAMES EARL', 'ARMY', 'SP4', '19440209', 'HAYS', 'ELLIS', '19680107', 'Y', 'KS']
# ['HESS KERRY EUGENE', 'ARMY', '1LT', '19450607', 'TOPEKA', 'SHAWNEE', '19690605', 'Y', 'KS']
# ['HEWITT THOMAS  THEODORE', 'ARMY', 'CPT', '19450421', 'TOPEKA', 'SHAWNEE', '19700702', 'Y', 'KS']
# ['HIEBERT JOHN MICHAEL', 'ARMY', 'WO1', '19480124', 'HESSTON', 'HARVEY', '19711202', 'Y', 'KS']
# ['HIGLEY LYNNFORD  HARLOW', 'ARMY', '1LT', '19460522', 'LAWRENCE', 'DOUGLAS', '19690109', 'Y', 'KS']
# ['HILMES STEVEN LEE', 'ARMY', 'PFC', '19480331', 'RANSOM', 'NESS', '19680902', 'Y', 'KS']
# ['HINES PHILIP BLAINE', 'MARINE CORPS', '1STLT', '19420618', 'GALENA', 'CHEROKEE', '19660706', 'Y', 'KS']
# ['HINES PHILLIP MASON', 'NAVY', 'PO3', '19450921', 'DODGE CITY', 'FORD', '19670519', 'Y', 'KS']
# ['HINTON RODNEY GENE', 'NAVY', 'HN', '19481210', 'TOPEKA', 'SHAWNEE', '19680207', 'Y', 'KS']
# ['HLADIK HAROLD  HERBERT', 'ARMY', 'SP4', '19471014', 'WICHITA', 'SEDGWICK', '19690217', 'Y', 'KS']
# ['HOEME FORREST DEAN', 'ARMY', 'PFC', '19440923', 'PRESTON', 'PRATT', '19670311', 'Y', 'KS']
# ['HOFFMAN WILLIAM  DAVID', 'MARINE CORPS', 'PFC', '19490907', 'RUSSELL', 'RUSSELL', '19680406', 'Y', 'KS']
# ['HOLCOMB REBEL LEE', 'ARMY', 'SGT', '19270809', 'WICHITA', 'SEDGWICK', '19651108', 'Y', 'KS']
# ['HOLMES JACK EUGENE', 'ARMY', 'SP5', '19510518', 'ABILENE', 'DICKINSON', '19691227', 'Y', 'KS']
# ['HOLROYD JAMES  LAWRENCE', 'ARMY', 'PFC', '19480811', 'ROELAND PARK', 'JOHNSON', '19670409', 'Y', 'KS']
# ['HOLT ALLEN LEE', 'ARMY', 'CW2', '19320410', 'TOPEKA', 'SHAWNEE', '19650705', 'Y', 'KS']
# ['HOLTOM MARK RICHARD', 'ARMY', 'WO1', '19490326', 'BALDWIN CITY', 'DOUGLAS', '19700926', 'Y', 'KS']
# ['HONEYCUTT BLAINE  LEROY', 'ARMY', 'SFC', '19300207', 'ARKANSAS ', 'CITY', 'COWLEY', '19690309', 'KS']
# ['Y HORINEK DONALD ', 'EDWARD', 'ARMY', 'SGT', '19461110', 'WICHITA', 'SEDGWICK', '19680823', 'KS']
# ['Y HOSKINS CHARLES LEE', 'AIR FORCE', 'CAPT', '19440805', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19710216', 'KS']
# ['N HOUSEHOLTER TERRY ', 'AUGUST', 'MARINE CORPS', 'LCPL', '19480917', 'CONCORDIA', 'CLOUD', '19690623', 'KS']
# ['Y HOWARD CHARLES ', 'EMORY', 'NAVY', 'PO3', '19421111', 'ERIE', 'NEOSHO', '19680701', 'KS']
# ['Y HOWARD STEVEN DALE', 'ARMY', 'CPT', '19410323', 'EL DORADO', 'BUTLER', '19721031', 'Y', 'KS']
# ['HUBERT MICHAEL NEIL', 'ARMY', 'SSG', '19421108', 'EMPORIA', 'LYON', '19690224', 'Y', 'KS']
# ['HUMPHREY JAMES  GILBERT', 'ARMY', 'SGT', '19470329', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19681111', 'KS']
# ['Y HURST QUENTIN FOXX', 'ARMY', '1LT', '19441116', 'VALLEY FALLS', 'JEFFERSON', '19680927', 'Y', 'KS']
# ['HUTTIE FREDERICK E III', 'ARMY', 'SSG', '19451116', 'PRAIRIE ', 'VILLAGE', 'JOHNSON', '19700815', 'KS']
# ['Y HUTTON EARL DEWITT', 'ARMY', 'PFC', '19460710', 'LA HARPE', 'ALLEN', '19661105', 'Y', 'KS']
# ['INGRUM JOSEPH HENRY', 'NAVY', 'PO2', '19461212', 'ABILENE', 'DICKINSON', '19680512', 'Y', 'KS']
# ['ISHMAN HUEY LEE', 'MARINE CORPS', 'PVT', '19481016', 'TOPEKA', 'SHAWNEE', '19691119', 'Y', 'KS']
# ['JACKSON GARY RAY', 'ARMY', 'SP4', '19510731', 'SHAWNEE', 'JOHNSON', '19690908', 'Y', 'KS']
# ['JAMESON RODGER LEE', 'ARMY', 'PFC', '19500616', 'SALINA', 'SALINE', '19690827', 'Y', 'KS']
# ['JANKE THEODORE JR', 'MARINE CORPS', 'SGT', '19461005', 'SALINA', 'SALINE', '19680519', 'Y', 'KS']
# ['JANTZ ROBERT WAYNE', 'ARMY', 'WO1', '19470624', 'SYRACUSE', 'HAMILTON', '19690102', 'Y', 'KS']
# ['JARVIS RONALD ALAN', 'ARMY', 'PFC', '19481107', 'NESS CITY', 'NESS', '19681220', 'Y', 'KS']
# ['JENKINS ROBERT EARL', 'ARMY', 'SGT', '19470803', 'WICHITA', 'SEDGWICK', '19680519', 'Y', 'KS']
# ['JEWELL EUGENE  MILLARD', 'AIR FORCE', 'CAPT', '19410115', 'TOPEKA', 'SHAWNEE', '19650904', 'N', 'KS']
# ['JIM MARTIN JR', 'ARMY', 'PFC', '19510508', 'MAYETTA', 'JACKSON', '19710116', 'Y', 'KS']
# ['JIMENEZ EDUARDO', 'ARMY', 'PFC', '19490304', 'HUMBOLDT', 'ALLEN', '19680308', 'Y', 'KS']
# ['JOHNSON CHARLES  FRANKLIN', 'ARMY', 'SP4', '19400709', 'HUTCHINSON', 'RENO', '19670503', 'Y', 'KS']
# ['JOHNSON FREDERICK  PETER JR', 'ARMY', 'SGT', '19440625', 'WICHITA', 'SEDGWICK', '19690530', 'Y', 'KS']
# ['JOHNSON GARY DALE', 'ARMY', 'PFC', '19471106', 'BALDWIN CITY', 'DOUGLAS', '19680216', 'Y', 'KS']
# ['JOHNSON JIMMIE LE ROY', 'MARINE CORPS', 'LCPL', '19480814', 'OTTAWA', 'FRANKLIN', '19671006', 'Y', 'KS']
# ['JOHNSON KENNETH  DUANE', 'ARMY', 'CPL', '19490619', 'EL DORADO', 'BUTLER', '19690823', 'Y', 'KS']
# ['JOHNSON PHIL DAVID', 'ARMY', '1LT', '19421017', 'STERLING', 'RICE', '19690225', 'Y', 'KS']
# ['JOHNSON ROBERT FRED  JR', 'ARMY', 'PFC', '19440522', 'KANSAS CITY', 'WYANDOTTE', '19680203', 'Y', 'KS']
# ['JONES MERLE ELDON', 'ARMY', '2LT', '19420523', 'LINCOLN', 'LINCOLN', '19660327', 'Y', 'KS']
# ['JONES RICHARD LEE', 'ARMY', 'CPL', '19461201', 'WICHITA', 'SEDGWICK', '19680927', 'Y', 'KS']
# ['JORDAN FRANCIS  EUGENE', 'ARMY', 'PFC', '19470804', 'RUSSELL ', 'SPRINGS', 'LOGAN', '19680514', 'KS']
# ['Y JUSTICE WALTER ', 'EUGENE SR', 'ARMY', 'SFC', '19340307', 'KANSAS CITY', 'WYANDOTTE', '19690419', 'KS']
# ['Y KAEBERLE DANA JAMES', 'ARMY', 'CPL', '19470711', 'OSAGE CITY', 'OSAGE', '19690108', 'Y', 'KS']
# ['KARLIN DONALD DEAN', 'MARINE CORPS', 'CPL', '19400831', 'WICHITA', 'SEDGWICK', '19651218', 'Y', 'KS']
# ['KARST CARL FREDERICK', 'AIR FORCE', 'COL', '19301027', 'GALATIA', 'BARTON', '19681116', 'Y', 'KS']
# ['KECK WARREN EDWARD', 'ARMY', 'SP5', '19460905', 'KANSAS CITY', 'WYANDOTTE', '19670310', 'Y', 'KS']
# ['KENAGA GARY LYLE', 'ARMY', 'PFC', '19471022', 'WICHITA', 'SEDGWICK', '19670621', 'Y', 'KS']
# ['KIER CHARLES RICHARD', 'ARMY', 'PFC', '19460711', 'MOUND ', 'VALLEY', 'LABETTE', '19651227', 'KS']
# ['Y KIMMEL ROBERT GENE', 'ARMY', 'LTC', '19280817', 'TOPEKA', 'SHAWNEE', '19671114', 'Y', 'KS']
# ['KINNAMON SAMMY  EDWARD', 'ARMY', 'SP4', '19471208', 'INDEPENDENCE', 'MONTGOMERY', '19690226', 'Y', 'KS']
# ['KIRKENDOLL CLEE  ANDREW', 'ARMY', 'PFC', '19470503', 'KANSAS CITY', 'WYANDOTTE', '19680905', 'Y', 'KS']
# ['KIRKENDOLL JERRY  WAYNE', 'ARMY', 'WO1', '19471107', 'OVERLAND ', 'PARK', 'JOHNSON', '19710315', 'KS']
# ['Y KITCHEN DAVID LEE', 'MARINE CORPS', 'LCPL', '19490707', 'WAMEGO', 'POTTAWATOMI', 'E', '19690425', 'KS']
# ['Y KLAUS ARTHUR LEE', 'ARMY', 'CPL', '19480907', 'HAYS', 'ELLIS', '19690208', 'Y', 'KS']
# ['KLENDA DEAN ALBERT', 'AIR FORCE', 'MAJ', '19400820', 'MANHATTAN', 'RILEY', '19650917', 'N', 'KS']
# ['KNOWLES KENNETH  JOSEPH', 'ARMY', 'SP4', '19470731', 'ATCHISON', 'ATCHISON', '19680521', 'Y', 'KS']
# ['KRAMER KEVIN CLINTON', 'ARMY', 'CPL', '19500118', 'WICHITA', 'SEDGWICK', '19710310', 'Y', 'KS']
# ['KREHBIEL KENNETH  DILLARD', 'AIR FORCE', 'CAPT', '19390120', 'MCPHERSON', 'MCPHERSON', '19671019', 'Y', 'KS']
# ['KRIG DAVID LEE', 'NAVY', 'HN', '19470824', 'LINDSBORG', 'MCPHERSON', '19670515', 'Y', 'KS']
# ['LACEY FRANKLIN D', 'MARINE CORPS', 'PFC', '19490130', 'MERIDEN', 'JEFFERSON', '19680328', 'Y', 'KS']
# ['LACKEY JACK VERNON JR', 'MARINE CORPS', 'LCPL', '19491126', 'IUKA', 'PRATT', '19690710', 'Y', 'KS']
# ['LAFRANCE JON PATRICK', 'ARMY', 'PFC', '19440927', 'OVERLAND ', 'PARK', 'JOHNSON', '19681229', 'KS']
# ['Y LAKE LLOYD DEAN', 'MARINE CORPS', 'PFC', '19451004', 'SALINA', 'SALINE', '19660115', 'Y', 'KS']
# ['LAKIN ROGER ALAN', 'MARINE CORPS', '1STLT', '19440727', 'DERBY', 'SEDGWICK', '19700325', 'Y', 'KS']
# ['LAMON ROY ALLEN', 'ARMY', 'SGT', '19461126', 'LIBERAL', 'SEWARD', '19680426', 'Y', 'KS']
# ['LAND DAVID ALDEN', 'NAVY', 'SN', '19490405', 'WICHITA', 'SEDGWICK', '19690114', 'Y', 'KS']
# ['LAPLANT KURT ELTON', 'MARINE CORPS', 'LCPL', '19481211', 'LENEXA', 'JOHNSON', '19680606', 'N', 'KS']
# ['LARRABEE FLOYD  MICHAEL', 'MARINE CORPS', 'LCPL', '19470205', 'OLATHE', 'JOHNSON', '19670326', 'Y', 'KS']
# ['LARSON LOREN HENRY', 'ARMY', 'PFC', '19480303', 'LEONARDVILLE', 'RILEY', '19690620', 'Y', 'KS']
# ['LASKOWSKI ANTHONY  JAMES', 'ARMY', 'PFC', '19460104', 'KANSAS CITY', 'WYANDOTTE', '19681026', 'Y', 'KS']
# ['LEBOMBARB LONNIE GUY', 'ARMY', 'SGT', '19461030', 'LAWRENCE', 'DOUGLAS', '19680209', 'Y', 'KS']
# ['LEFTWICH RAYMOND  FRANCIS', 'AIR FORCE', 'TSGT', '19250920', 'FT SCOTT', 'BOURBON', '19670309', 'Y', 'KS']
# ['LEHNHOFF EDWARD  WILLIAM JR', 'AIR FORCE', 'LTCOL', '19360314', 'FT SCOTT', 'BOURBON', '19671118', 'Y', 'KS']
# ['LEIKAM NORMAN  ALEXIUS', 'ARMY', 'MAJ', '19320602', 'HAYS', 'ELLIS', '19651023', 'Y', 'KS']
# ['LEMLEY BILLY JOE', 'ARMY', 'SP4', '19340327', 'WICHITA', 'SEDGWICK', '19691026', 'Y', 'KS']
# ['LEWALLEN JACKIE LEE', 'ARMY', 'PFC', '19491206', 'KANSAS CITY', 'WYANDOTTE', '19700222', 'Y', 'KS']
# ['LEWIS CLARENCE PAUL', 'AIR FORCE', '1STLT', '19470125', 'LOUISBURG', 'MIAMI', '19720521', 'Y', 'KS']
# ['LEWIS DONALD ALLEN', 'MARINE CORPS', 'SGT', '19420406', 'EUREKA', 'GREENWOOD', '19660826', 'Y', 'KS']
# ['LEWIS JESSIE ROY', 'MARINE CORPS', 'PFC', '19501212', 'WICHITA', 'SEDGWICK', '19690716', 'Y', 'KS']
# ['LINDAHL JOHN CARL', 'NAVY', 'LT', '19410328', 'LINDSBORG', 'MCPHERSON', '19730106', 'N', 'KS']
# ['LINDHOLM DAN VICTOR', 'ARMY', 'SP4', '19480524', 'LINDSBORG', 'MCPHERSON', '19680908', 'Y', 'KS']
# ['LINDQUIST WILLIAM  FRANCIS', 'ARMY', 'SP4', '19460520', 'KANSAS CITY', 'WYANDOTTE', '19690623', 'Y', 'KS']
# ['LITTLE GARY DEAN', 'ARMY', 'SP5', '19441025', 'LEAVENWORTH', 'LEAVENWORTH', '19670708', 'Y', 'KS']
# ['LLAMAS JOSE', 'ARMY', 'CPT', '19261108', 'NEWTON', 'HARVEY', '19690819', 'Y', 'KS']
# ['LONG ELDON DALE', 'ARMY', 'PFC', '19440906', 'LIBERAL', 'SEWARD', '19660310', 'Y', 'KS']
# ['LONG GEORGE WENDELL', 'AIR FORCE', 'A1C', '19480930', 'MEDICINE ', 'LODGE', 'BARBER', '19680512', 'KS']
# ['Y LONG JEROME ALBERT', 'MARINE CORPS', 'PFC', '19470327', 'BELOIT', 'MITCHELL', '19681204', 'Y', 'KS']
# ['LONG MELVIN RAY', 'MARINE CORPS', 'PFC', '19460308', 'TOPEKA', 'SHAWNEE', '19680913', 'Y', 'KS']
# ['LOVE DARRELL STEVE', 'ARMY', 'CPL', '19440916', 'CLEARWATER', 'SEDGWICK', '19681102', 'Y', 'KS']
# ['LOVE JOHN ARTHUR', 'ARMY', 'SGT', '19480903', 'LIBERAL', 'SEWARD', '19690513', 'Y', 'KS']
# ['LOYD LONNY LEE', 'MARINE CORPS', 'PFC', '19491031', 'KANSAS CITY', 'WYANDOTTE', '19681124', 'Y', 'KS']
# ['LUKERT EDWARD ROY', 'ARMY', 'SGT', '19440924', 'FAIRVIEW', 'BROWN', '19670611', 'Y', 'KS']
# ['LUNDY MAURICE  EDWARD', 'AIR FORCE', '1STLT', '19440205', 'KANSAS CITY', 'WYANDOTTE', '19690510', 'Y', 'KS']
# ['LYONS ROBERT PAUL', 'ARMY', 'SP5', '19430810', 'WICHITA', 'SEDGWICK', '19690406', 'Y', 'KS']
# ['MACDONALD ALLAN  HERBERT', 'ARMY', 'SP4', '19460922', 'OVERLAND ', 'PARK', 'JOHNSON', '19660626', 'KS']
# ['Y MALONE CHARLES ', 'WALTER', 'ARMY', 'MAJ', '19250225', 'HAYS', 'ELLIS', '19691005', 'KS']
# ['Y MALONE ROBERT GARY', 'MARINE CORPS', 'CPL', '19430830', 'WICHITA', 'SEDGWICK', '19660728', 'Y', 'KS']
# ['MARTIN LARRY EUGENE', 'AIR FORCE', 'MAJ', '19400211', 'WAKEFIELD', 'CLAY', '19680715', 'Y', 'KS']
# ['MARTIN STEVEN LOUIS', 'ARMY', 'WO1', '19470428', 'WICHITA', 'SEDGWICK', '19690531', 'Y', 'KS']
# ['MARTIN WALTER WESLEY', 'AIR FORCE', 'MAJ', '19351016', 'OPOLIS', 'CRAWFORD', '19690117', 'Y', 'KS']
# ['MARTINEZ GEORGE  FRANCIS', 'ARMY', 'SP4', '19360509', 'NEWTON', 'HARVEY', '19690608', 'Y', 'KS']
# ['MARTINEZ PETER', 'MARINE CORPS', 'SGT', '19400321', 'ARKANSAS ', 'CITY', 'COWLEY', '19660121', 'KS']
# ['Y MASLAK JOHN JOSEPH', 'ARMY', 'SP4', '19440429', 'KANSAS CITY', 'WYANDOTTE', '19690807', 'Y', 'KS']
# ['MASON ROMAN GALE', 'ARMY', 'SGT', '19470925', 'EDWARDSVILL', 'E', 'WYANDOTTE', '19690127', 'KS']
# ['Y MATHER ALVIN EUGENE', 'AIR FORCE', 'MAJ', '19330926', 'TOPEKA', 'SHAWNEE', '19700604', 'Y', 'KS']
# ['MATTHEWS WILLIAM  CLAY', 'MARINE CORPS', 'PFC', '19500409', 'DERBY', 'SEDGWICK', '19690226', 'Y', 'KS']
# ['MCCUBBIN GLENN  DEWAYNE', 'AIR FORCE', 'MAJ', '19420821', 'ALMENA', 'NORTON', '19680519', 'Y', 'KS']
# ['MCCULLOUGH PATRICK  ELVIN', 'ARMY', 'SP4', '19491215', 'CLEARWATER', 'SEDGWICK', '19690207', 'Y', 'KS']
# ['MCDERMOTT JOHN  PATRICK', 'NAVY', 'PO2', '19451209', 'PITTSBURG', 'CRAWFORD', '19680907', 'Y', 'KS']
# ['MCDONALD DANNY LEE', 'ARMY', 'PFC', '19460328', 'EUREKA', 'GREENWOOD', '19661030', 'Y', 'KS']
# ['MCDONALD MICHAEL JAY', 'ARMY', 'PFC', '19481217', 'WICHITA', 'SEDGWICK', '19681221', 'Y', 'KS']
# ['MCGINNIS LESTER CLEO II', 'ARMY', 'SGT', '19471114', 'KANSAS CITY', 'WYANDOTTE', '19681018', 'Y', 'KS']
# ['MCGONIGLE WILLIAM  DEE', 'MARINE CORPS', 'PFC', '19481029', 'WICHITA', 'SEDGWICK', '19680510', 'Y', 'KS']
# ['MCGOVERN JEROME  GEORGE', 'ARMY', 'SGT', '19460510', 'TOPEKA', 'SHAWNEE', '19670712', 'Y', 'KS']
# ['MCINTOSH DONALD  WILLIAM', 'ARMY', 'PFC', '19510118', 'HUTCHINSON', 'RENO', '19701108', 'Y', 'KS']
# ['MCKAIN BOBBY LYN', 'ARMY', 'CW2', '19460211', 'GARDEN CITY', 'FINNEY', '19680503', 'N', 'KS']
# ['MCKAY GERALD OTTO', 'MARINE CORPS', '1STLT', '19411025', 'ST MARYS', 'MULTIPLE', '19650606', 'Y', 'KS']
# ['MCKINNELL RICHARD  LEE', 'MARINE CORPS', 'PFC', '19471113', 'WICHITA', 'SEDGWICK', '19670704', 'Y', 'KS']
# ['MCLAREN ROBERT DALE', 'ARMY', 'SP4', '19510418', 'WICHITA', 'SEDGWICK', '19720624', 'Y', 'KS']
# ['MCTEER JEFFERY CLARK', 'MARINE CORPS', 'PFC', '19480102', 'OVERLAND ', 'PARK', 'JOHNSON', '19680131', 'KS']
# ['Y MEADE JAMES ROBERT', 'ARMY', 'CW2', '19411027', 'TOPEKA', 'SHAWNEE', '19710402', 'Y', 'KS']
# ['MEANS WILLIAM  HARLEY JR', 'AIR FORCE', 'COL', '19350713', 'TOPEKA', 'SHAWNEE', '19660720', 'Y', 'KS']
# ['MEIS DONALD DAVID', 'ARMY', 'SP4', '19470602', 'WICHITA', 'SEDGWICK', '19680601', 'Y', 'KS']
# ['MERYS ROBERT KEITH', 'ARMY', 'SP4', '19480925', 'OVERLAND ', 'PARK', 'JOHNSON', '19681210', 'KS']
# ['Y METZGER GEORGE ', 'LEONARD', 'MARINE CORPS', 'LCPL', '19500320', 'KANSAS CITY', 'WYANDOTTE', '19690909', 'KS']
# ['Y MILBRADT DALE ', 'LAVERNE', 'ARMY', '1LT', '19430821', 'TOPEKA', 'SHAWNEE', '19690411', 'KS']
# ['Y MILLER KENNETH ', 'WALTER', 'ARMY', 'PFC', '19490305', 'PHILLIPSBURG', 'PHILLIPS', '19680930', 'KS']
# ['Y MILLER TIMMY LARRY', 'MARINE CORPS', 'SGT', '19470504', 'STOCKTON', 'ROOKS', '19681124', 'Y', 'KS']
# ['MISCHLER HAROLD LOUIS', 'AIR FORCE', 'CAPT', '19460109', 'OSBORNE', 'OSBORNE', '19721223', 'Y', 'KS']
# ['MITCHELL CRAIG WESLEY', 'ARMY', 'SP4', '19470210', 'EL DORADO', 'BUTLER', '19680511', 'Y', 'KS']
# ['MIZER LENTON EUGENE', 'ARMY', 'WO1', '19500210', 'EL DORADO', 'BUTLER', '19700715', 'Y', 'KS']
# ['MOHLER TIMOTHY ALLEN', 'ARMY', 'PFC', '19481127', 'QUENEMO', 'OSAGE', '19690819', 'Y', 'KS']
# ['MONTEMAYOR JAMES  MICHAEL', 'ARMY', 'PFC', '19471003', 'KANSAS CITY', 'WYANDOTTE', '19690117', 'Y', 'KS']
# ['MOORE BILLY RAY', 'MARINE CORPS', 'PFC', '19461108', 'KANSAS CITY', 'WYANDOTTE', '19660906', 'Y', 'KS']
# ['MOORE DONALD EUGENE', 'ARMY', 'SFC', '19361002', 'PRATT', 'PRATT', '19680207', 'Y', 'KS']
# ['MOORE JAMES EZRA', 'MARINE CORPS', 'PFC', '19490817', 'KANSAS CITY', 'WYANDOTTE', '19680306', 'Y', 'KS']
# ['MOORE WILLIAM RAY', 'NAVY', 'PO2', '19451221', 'PRINCETON', 'FRANKLIN', '19691002', 'N', 'KS']
# ['MORA RAYMOND  CASTILLO', 'MARINE CORPS', 'PFC', '19470721', 'KANSAS CITY', 'WYANDOTTE', '19680611', 'Y', 'KS']
# ['MORGAN LELAND RAY', 'ARMY', 'PFC', '19470121', 'WICHITA', 'SEDGWICK', '19661203', 'Y', 'KS']
# ['MORTIBOY WILLIAM  SHELTON', 'MARINE CORPS', 'CPL', '19470613', 'OVERLAND ', 'PARK', 'JOHNSON', '19670401', 'KS']
# ['Y MOTT JOHN ARTHUR', 'ARMY', 'SP4', '19440113', 'IOLA', 'ALLEN', '19670322', 'Y', 'KS']
# ['MOUNTS JERRY DUANE', 'MARINE CORPS', 'PFC', '19480509', 'WICHITA', 'SEDGWICK', '19680213', 'Y', 'KS']
# ['MOWREY RICHARD LYNN', 'NAVY', 'LTJG', '19430401', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19661214', 'KS']
# ['N MUEHLBERG RONALD ', 'LEE', 'ARMY', 'PFC', '19461215', 'SALINA', 'SALINE', '19680812', 'KS']
# ['Y MUELLER STEVEN AL', 'AIR FORCE', '1STLT', '19440907', 'SYLVAN GROVE', 'LINCOLN', '19700118', 'Y', 'KS']
# ['MULLER DANIEL SCOTT', 'NAVY', 'PO3', '19430718', 'PITTSBURG', 'CRAWFORD', '19690604', 'Y', 'KS']
# ['MUNDAY PHILLIP DEAN', 'MARINE CORPS', 'PFC', '19470429', 'WICHITA', 'SEDGWICK', '19670502', 'Y', 'KS']
# ['MUNGER RONALD  WILLIAM', 'ARMY', 'SGT', '19481106', 'BEATTIE', 'MARSHALL', '19700821', 'Y', 'KS']
# ['MURRAY CARL EUGENE', 'ARMY', 'SP4', '19490126', 'TOPEKA', 'SHAWNEE', '19671220', 'Y', 'KS']
# ['MURRAY VIRGIL ARTHUR', 'ARMY', 'SP4', '19300623', 'LARNED', 'PAWNEE', '19660317', 'Y', 'KS']
# ['MYERS GENE ALLEN', 'ARMY', 'SP4', '19480521', 'ST MARYS', 'MULTIPLE', '19690609', 'Y', 'KS']
# ['NAIL GARY DEAN', 'MARINE CORPS', 'CPL', '19450817', 'SALINA', 'SALINE', '19660403', 'Y', 'KS']
# ['NEER GERALD KING', 'MARINE CORPS', 'SSGT', '19420404', 'WINFIELD', 'COWLEY', '19690617', 'Y', 'KS']
# ['NELSON DAVID REID', 'MARINE CORPS', 'LCPL', '19461203', 'HUTCHINSON', 'RENO', '19680704', 'Y', 'KS']
# ['NETH FRED ALBERT', 'NAVY', 'LCDR', '19320317', 'FT SCOTT', 'BOURBON', '19660116', 'N', 'KS']
# ['NEUBURGER DANIEL LEO', 'ARMY', '1LT', '19450721', 'ELLIS', 'ELLIS', '19680814', 'Y', 'KS']
# ['NEVINS ELDON EUGENE', 'NAVY', 'CN', '19470822', 'OSBORNE', 'OSBORNE', '19680308', 'Y', 'KS']
# ['NEVINS FLOYD CHARLES', 'ARMY', 'SGT', '19471110', 'VALLEY FALLS', 'JEFFERSON', '19690515', 'Y', 'KS']
# ['NEWMAN JERRY LEE', 'NAVY', 'PO2', '19440516', 'AGENDA', 'REPUBLIC', '19670828', 'Y', 'KS']
# ['NICKS BENJAMIN  ARNOLD III', 'ARMY', 'SGT', '19460809', 'SHAWNEE', 'JOHNSON', '19700423', 'Y', 'KS']
# ['NORTHROP JAMES  LEEROY', 'ARMY', 'SP4', '19410717', 'NEWTON', 'HARVEY', '19660626', 'Y', 'KS']
# ['NUFER JAMES LEO', 'ARMY', 'PFC', '19471106', 'DODGE CITY', 'FORD', '19680311', 'Y', 'KS']
# ['OATNEY ALLEN EUGENE', 'ARMY', 'CPL', '19491004', 'WATERVILLE', 'MARSHALL', '19700622', 'Y', 'KS']
# ['OBRIEN PATRICK  EDWARD', 'MARINE CORPS', 'CPL', '19461204', 'LIBERAL', 'SEWARD', '19670222', 'Y', 'KS']
# ['OCONNOR GERARD  FRANCIS', 'ARMY', 'WO1', '19471020', 'HERINGTON', 'DICKINSON', '19700426', 'Y', 'KS']
# ['OGLE DAVID ROBERT', 'ARMY', 'SP4', '19480218', 'LYNDON', 'OSAGE', '19680303', 'Y', 'KS']
# ['ONEIL RILEY CHARLES JR', 'ARMY', 'CPL', '19470604', 'KANSAS CITY', 'WYANDOTTE', '19671215', 'Y', 'KS']
# ['ORNELAS CARL JOHN', 'MARINE CORPS', 'SGT', '19480521', 'WICHITA', 'SEDGWICK', '19680205', 'Y', 'KS']
# ['ORTEGA ERNEST', 'MARINE CORPS', 'SGT', '19451202', 'WICHITA', 'SEDGWICK', '19661221', 'Y', 'KS']
# ['OSENBAUGH JAMES DALE', 'ARMY', 'PFC', '19471220', 'HUTCHINSON', 'RENO', '19680104', 'Y', 'KS']
# ['OWENS TIMOTHY  EUGENE', 'MARINE CORPS', 'PFC', '19481001', 'KANSAS CITY', 'WYANDOTTE', '19680416', 'Y', 'KS']
# ['PACHECO FELIX', 'ARMY', 'PFC', '19470306', 'KANSAS CITY', 'WYANDOTTE', '19660825', 'Y', 'KS']
# ['PAPPAN BOBBY JACK', 'ARMY', 'SGT', '19471220', 'DERBY', 'SEDGWICK', '19680905', 'Y', 'KS']
# ['PARKER HARVEY R', 'ARMY', 'PVT', '19461028', 'FULTON', 'BOURBON', '19670105', 'Y', 'KS']
# ['PARRISH ROGER ALAN', 'ARMY', '1LT', '19470612', 'MANHATTAN', 'RILEY', '19690610', 'Y', 'KS']
# ['PARSONS GARY REED', 'MARINE CORPS', 'PFC', '19471117', 'TOPEKA', 'SHAWNEE', '19660926', 'Y', 'KS']
# ['PARTRIDGE NORMAN  WAYNE', 'ARMY', 'WO1', '19441212', 'TOWANDA', 'BUTLER', '19680916', 'Y', 'KS']
# ['PATRICK DARYL WAYNE', 'ARMY', 'SP4', '19481013', 'MURDOCK', 'KINGMAN', '19691215', 'Y', 'KS']
# ['PATTERSON JEROME  DEAN', 'NAVY', 'CN', '19451128', 'PLEASANTON', 'LINN', '19670828', 'Y', 'KS']
# ['PATTON WARD KARL', 'NAVY', 'PO1', '19340118', 'FONTANA', 'MIAMI', '19680727', 'N', 'KS']
# ['PAXSON STEVEN DUANE', 'ARMY', 'SGT', '19480921', 'TOPEKA', 'SHAWNEE', '19690522', 'Y', 'KS']
# ['PAYNE KENNETH RAY', 'MARINE CORPS', 'PFC', '19490808', 'WICHITA', 'SEDGWICK', '19681030', 'Y', 'KS']
# ['PAYNE RICHARD  NORMAN', 'MARINE CORPS', 'LCPL', '19450610', 'TOPEKA', 'SHAWNEE', '19660724', 'Y', 'KS']
# ['PAYNE ROBERT ELGIN', 'MARINE CORPS', 'LCPL', '19430806', 'GEUDA ', 'SPRINGS', 'SUMNER', '19670520', 'KS']
# ['Y PEEL LAWRENCE RAY', 'ARMY', 'SP4', '19511211', 'KANSAS CITY', 'WYANDOTTE', '19710428', 'Y', 'KS']
# ['PERRYMAN RONALD  GLEN', 'ARMY', '2LT', '19440402', 'WICHITA', 'SEDGWICK', '19661025', 'Y', 'KS']
# ['PETERSEN DANNY JOHN', 'ARMY', 'SP4', '19490311', 'ATCHISON', 'ATCHISON', '19700109', 'Y', 'KS']
# ['PETETT LARRY WYNN', 'ARMY', '2LT', '19440921', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680227', 'KS']
# ['Y PETTY JOHN CABLE II', 'ARMY', 'SGT', '19421230', 'LARNED', 'PAWNEE', '19660813', 'Y', 'KS']
# ['PHALP WILLIAM  ANDERSON JR', 'ARMY', 'PFC', '19481002', 'MISSION', 'JOHNSON', '19690210', 'Y', 'KS']
# ['PHILLIPS JACK WARREN', 'MARINE CORPS', 'CAPT', '19350125', 'MISSION', 'JOHNSON', '19671014', 'Y', 'KS']
# ['PHILLIPS MARLEN LE ROY', 'MARINE CORPS', 'CPL', '19360310', 'BUCKLIN', 'FORD', '19680906', 'Y', 'KS']
# ['PHILLIPS MICHAEL GENE', 'ARMY', 'SP4', '19470517', 'SALINA', 'SALINE', '19671031', 'Y', 'KS']
# ['PIERCE CLINTON DWIGHT', 'MARINE CORPS', 'PFC', '19490907', 'AUGUSTA', 'BUTLER', '19691108', 'Y', 'KS']
# ['PIKE RAYMOND HORACE  JR', 'ARMY', 'SP4', '19480303', 'LEAVENWORTH', 'LEAVENWORTH', '19680131', 'Y', 'KS']
# ['POKE DONALD MAURICE', 'ARMY', 'CPL', '19501128', 'KANSAS CITY', 'WYANDOTTE', '19710514', 'Y', 'KS']
# ['PONTING JOHN L', 'ARMY', 'SFC', '19360117', 'EMPORIA', 'LYON', '19671122', 'Y', 'KS']
# ['PORRAS JUAN', 'MARINE CORPS', 'PFC', '19490311', 'KANSAS CITY', 'WYANDOTTE', '19680910', 'Y', 'KS']
# ['PORTER JAMES HOLLAND', 'MARINE CORPS', 'CPL', '19480615', 'ENTERPRISE', 'DICKINSON', '19690121', 'Y', 'KS']
# ['POSEY CHARLES ALBERT', 'ARMY', 'SP4', '19461102', 'WICHITA', 'SEDGWICK', '19691105', 'Y', 'KS']
# ['PRIETO RUBEN', 'ARMY', 'SP4', '19460424', 'KANSAS CITY', 'WYANDOTTE', '19681221', 'Y', 'KS']
# ['PROBERTS WAYNE  DOUGLAS', 'ARMY', 'PFC', '19420419', 'GARDEN CITY', 'FINNEY', '19651112', 'Y', 'KS']
# ['PROCINO NICHOLAS  RALPH', 'ARMY', 'SP4', '19490913', 'GALENA', 'CHEROKEE', '19691108', 'Y', 'KS']
# ['PUGH DENNIS GERARD', 'AIR FORCE', 'MAJ', '19440210', 'SALINA', 'SALINE', '19700319', 'N', 'KS']
# ['PULLIAM DALE ALLAN', 'MARINE CORPS', 'LCPL', '19470313', 'WICHITA', 'SEDGWICK', '19670514', 'Y', 'KS']
# ['RAGER WILLIAM EARL', 'ARMY', 'SFC', '19300804', 'ABILENE', 'DICKINSON', '19670310', 'Y', 'KS']
# ['RAIMEY CHRISTOPHER  LAG', 'MARINE CORPS', 'PFC', '19510720', 'TOPEKA', 'SHAWNEE', '19710210', 'Y', 'KS']
# ['RAMSEY MILTON HARDIN', 'AIR FORCE', 'MAJ', '19370215', 'KANSAS CITY', 'WYANDOTTE', '19710301', 'Y', 'KS']
# ['RAY RANDY DAVID', 'ARMY', 'PFC', '19480819', 'PRAIRIE ', 'VILLAGE', 'JOHNSON', '19701205', 'KS']
# ['Y REDD BOBBY EDWARD', 'ARMY', 'SFC', '19311212', 'CHAPMAN', 'DICKINSON', '19680713', 'Y', 'KS']
# ['REDMOND RALPH  GEORGE', 'ARMY', '1LT', '19380501', 'TOPEKA', 'SHAWNEE', '19640604', 'Y', 'KS']
# ['REGIER RAYMOND DEAN', 'ARMY', 'CPL', '19490206', 'LIBERAL', 'SEWARD', '19700205', 'Y', 'KS']
# ['REID JAMES EDWARD', 'MARINE CORPS', 'PFC', '19451227', 'WICHITA', 'SEDGWICK', '19660826', 'Y', 'KS']
# ['REISSIG LARRY LEROY', 'ARMY', 'PFC', '19470624', 'ASSARIA', 'SALINE', '19670513', 'Y', 'KS']
# ['RENFRO JACK DENNIS', 'NAVY', 'LT', '19390422', 'OVERLAND ', 'PARK', 'JOHNSON', '19661107', 'KS']
# ['Y REUKAUF LEE EDWARD', 'ARMY', 'PFC', '19460308', 'KANSAS CITY', 'WYANDOTTE', '19670228', 'Y', 'KS']
# ['REYNOLDS WILLIAM  LAWRENCE', 'ARMY', '1LT', '19460925', 'WINFIELD', 'COWLEY', '19700528', 'Y', 'KS']
# ['RHODES LARRY WAYNE', 'MARINE CORPS', 'PFC', '19490218', 'WICHITA', 'SEDGWICK', '19690428', 'Y', 'KS']
# ['RICHARDSON ARLEN DEL', 'ARMY', '1LT', '19430206', 'LAWRENCE', 'DOUGLAS', '19700217', 'Y', 'KS']
# ['RICHARDSON GARY  WAYNE', 'ARMY', 'SP4', '19490817', 'WICHITA', 'SEDGWICK', '19701030', 'Y', 'KS']
# ['RIEDEL ROBERT EUGENE', 'MARINE CORPS', 'PFC', '19450121', 'HOISINGTON', 'BARTON', '19650831', 'Y', 'KS']
# ['RIGBY OLIS RAY', 'ARMY', 'SP4', '19480816', 'HAYS', 'ELLIS', '19671121', 'Y', 'KS']
# ['RING HAROLD KENNETH', 'ARMY', '1LT', '19470710', 'LEAVENWORTH', 'LEAVENWORTH', '19690223', 'Y', 'KS']
# ['ROBERTS RICHARD  STEPHEN', 'MARINE CORPS', 'LCPL', '19481010', 'KANSAS CITY', 'WYANDOTTE', '19680219', 'Y', 'KS']
# ['ROBINSON FLOYD HENRY', 'ARMY', 'SSG', '19490128', 'BURLINGTON', 'COFFEY', '19690312', 'N', 'KS']
# ['ROBINSON MICHAEL  BERNARD', 'MARINE CORPS', 'CPL', '19491005', 'WICHITA', 'SEDGWICK', '19700107', 'Y', 'KS']
# ['ROLFE GARY FAY', 'ARMY', 'SGT', '19481219', 'WICHITA', 'SEDGWICK', '19690305', 'Y', 'KS']
# ['ROMINE ALBERT W', 'ARMY', 'SGT', '19450301', 'BURLINGAME', 'OSAGE', '19680516', 'Y', 'KS']
# ['ROOT EDWARD CHARLES', 'MARINE CORPS', 'CPL', '19470730', 'BERRYTON', 'SHAWNEE', '19680425', 'Y', 'KS']
# ['ROSALES MARTIN ANGEL', 'MARINE CORPS', 'PFC', '19460802', 'BETHEL', 'WYANDOTTE', '19670910', 'Y', 'KS']
# ['ROSS DENNIS WAYNE', 'ARMY', 'SP4', '19440621', 'PARKER', 'LINN', '19691112', 'Y', 'KS']
# ['ROUCHON ALAN  MICHAEL', 'ARMY', 'SP4', '19481219', 'FT ', 'LEAVENWORTH', 'LEAVENWORTH', '19690619', 'KS']
# ['Y ROYSTON LOUIS DON JR', 'MARINE CORPS', 'PFC', '19450301', 'WICHITA', 'SEDGWICK', '19650901', 'Y', 'KS']
# ['RUCKLE CLINTON GEAN', 'MARINE CORPS', 'PFC', '19500824', 'WICHITA', 'SEDGWICK', '19700106', 'Y', 'KS']
# ['RUDISILL DAYTON  LUTHER', 'NAVY', 'PO2', '19350913', 'GREENSBURG', 'KIOWA', '19660214', 'Y', 'KS']
# ['RUNKLE ROBERT LESLIE', 'ARMY', 'LTC', '19260320', 'FT SCOTT', 'BOURBON', '19680404', 'Y', 'KS']
# ['RYAN DELBERT LEROY', 'ARMY', 'PFC', '19450415', 'LAWRENCE', 'DOUGLAS', '19660602', 'Y', 'KS']
# ['SAENZ EDWARD LLOYD', 'MARINE CORPS', 'PFC', '19480108', 'GREAT BEND', 'BARTON', '19681002', 'Y', 'KS']
# ['SAGE TERENCE  FAIRCHILD', 'ARMY', 'CPT', '19420608', 'LEAVENWORTH', 'LEAVENWORTH', '19680131', 'Y', 'KS']
# ['SALINAS PHILLIP LOUIE', 'MARINE CORPS', 'LCPL', '19460417', 'LEOTI', 'WICHITA', '19680206', 'Y', 'KS']
# ['SAMUELS GEORGE LEROY', 'MARINE CORPS', 'PFC', '19471028', 'EUREKA', 'GREENWOOD', '19660408', 'Y', 'KS']
# ['SANCHEZ FRANKIE', 'ARMY', 'SP4', '19370612', 'DODGE CITY', 'FORD', '19660223', 'Y', 'KS']
# ['SASEK RICHARD JOHN', 'MARINE CORPS', 'CAPT', '19370208', 'TOPEKA', 'SHAWNEE', '19670706', 'Y', 'KS']
# ['SCANLAN LAWRENCE  WALKER', 'ARMY', 'PFC', '19450123', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680309', 'KS']
# ['Y SCATES CHARLES ', 'EDWARD JR', 'MARINE CORPS', 'PFC', '19490901', 'NEWTON', 'HARVEY', '19680518', 'KS']
# ['Y SCHALIPP MURVIN JR', 'ARMY', 'SP4', '19420225', 'LEAVENWORTH', 'LEAVENWORTH', '19651117', 'Y', 'KS']
# ['SCHMELZLE JOHN JOSEPH', 'ARMY', 'SP4', '19490928', 'EDWARDSVILL', 'E', 'WYANDOTTE', '19690413', 'KS']
# ['Y SCHOTH WILLIAM ', 'WESLEY II', 'ARMY', 'SP5', '19480729', 'MISSION', 'JOHNSON', '19690326', 'KS']
# ['Y SCHULTZ RONALD JAMES', 'ARMY', 'SFC', '19480527', 'HILLSBORO', 'MARION', '19700721', 'N', 'KS']
# ['SCHULTZ WILLIAM LEE', 'AIR FORCE', 'CAPT', '19370319', 'CHANUTE', 'NEOSHO', '19661008', 'Y', 'KS']
# ['SCHULZ RONALD  DOUGLAS', 'ARMY', 'SP4', '19490919', 'HUNTER', 'MITCHELL', '19700414', 'Y', 'KS']
# ['SCOTT DAVE RUSSELL', 'ARMY', 'SP4', '19461119', 'JUNCTION CITY', 'GEARY', '19680124', 'Y', 'KS']
# ['SCOTT LARRY EUGENE', 'ARMY', 'SP4', '19470825', 'ATCHISON', 'ATCHISON', '19690609', 'Y', 'KS']
# ['SEGLEM RICHARD NOYCE', 'ARMY', 'PFC', '19500712', 'WICHITA', 'SEDGWICK', '19700924', 'Y', 'KS']
# ['SEVICK JOHN FRANCIS', 'ARMY', '2LT', '19421222', 'KANSAS CITY', 'WYANDOTTE', '19680201', 'Y', 'KS']
# ['SHAMBAUGH DALE K', 'MARINE CORPS', '2NDLT', '19420721', 'TOPEKA', 'SHAWNEE', '19650818', 'Y', 'KS']
# ['SHANK GARY LESLIE', 'NAVY', 'LT', '19470316', 'PRAIRIE ', 'VILLAGE', 'JOHNSON', '19720723', 'KS']
# ['Y SHANNON RICHARD ', 'DEAN JR', 'ARMY', 'CPL', '19431013', 'PIPER', 'WYANDOTTE', '19690512', 'KS']
# ['Y SHERMAN DANIEL L', 'ARMY', 'PFC', '19401226', 'OVERLAND ', 'PARK', 'JOHNSON', '19660109', 'KS']
# ['Y SHERRILL AMOS ', 'CHESTER II', 'ARMY', 'PFC', '19470619', 'STAFFORD', 'STAFFORD', '19680719', 'KS']
# ['Y SHUE RUSSELL DELMAR', 'ARMY', 'SGT', '19480205', 'OSWEGO', 'LABETTE', '19700604', 'Y', 'KS']
# ['SIDENER WESLEY MELVIN', 'MARINE CORPS', 'PFC', '19481111', 'BURNS', 'MARION', '19691122', 'Y', 'KS']
# ['SIMMONS JOHN STEPHEN', 'ARMY', '2LT', '19450506', 'HOISINGTON', 'BARTON', '19680301', 'Y', 'KS']
# ['SMALL NORMAN EUGENE', 'ARMY', 'CPL', '19460213', 'ALDEN', 'RICE', '19680405', 'Y', 'KS']
# ['SMITH AARON BRUCE', 'ARMY', 'PFC', '19461009', 'ARKANSAS ', 'CITY', 'COWLEY', '19690812', 'KS']
# ['Y SMITH KENNETH WAYNE', 'MARINE CORPS', '1STLT', '19440105', 'BETHEL', 'WYANDOTTE', '19680128', 'Y', 'KS']
# ['SMITH MAYNARD LEE', 'NAVY', 'PO3', '19461113', 'TROY', 'DONIPHAN', '19680207', 'Y', 'KS']
# ['SMITH MICHAEL JOSEPH', 'NAVY', 'SA', '19461226', 'KANSAS CITY', 'WYANDOTTE', '19670412', 'Y', 'KS']
# ['SMITH RICHARD DEAN', 'AIR FORCE', 'LTCOL', '19370816', 'WICHITA', 'SEDGWICK', '19650311', 'Y', 'KS']
# ['SMITH STEPHEN LEE', 'ARMY', 'PFC', '19510102', 'OTTAWA', 'FRANKLIN', '19710301', 'Y', 'KS']
# ['SNOW LONNIE DALE', 'MARINE CORPS', 'LCPL', '19431223', 'LAWRENCE', 'DOUGLAS', '19650730', 'Y', 'KS']
# ['SONDERMAN THOMAS  LEE', 'ARMY', 'CW2', '19501119', 'DERBY', 'SEDGWICK', '19710408', 'Y', 'KS']
# ['SORENSEN KENNETH LEE', 'ARMY', 'PFC', '19440323', 'KANSAS CITY', 'WYANDOTTE', '19651204', 'Y', 'KS']
# ['SOUTHALL JOHN GEORGE', 'MARINE CORPS', 'CPL', '19460209', 'WAMEGO', 'POTTAWATOMI', 'E', '19680616', 'KS']
# ['Y SOUTHERN EDWARD ', 'CHARLES', 'MARINE CORPS', 'PFC', '19500328', 'NEWTON', 'HARVEY', '19690226', 'KS']
# ['Y SPIESS JOHN CHARLES', 'NAVY', 'PO1', '19410825', 'WICHITA', 'SEDGWICK', '19670729', 'Y', 'KS']
# ['SPRAGINS CARROLL  WAYNE', 'ARMY', 'CPT', '19431001', 'LEAVENWORTH', 'LEAVENWORTH', '19700310', 'Y', 'KS']
# ['SPRINGER GERALD  WAYNE', 'ARMY', 'PFC', '19480427', 'PRESCOTT', 'LINN', '19680829', 'Y', 'KS']
# ['SQUIER WILLIAM  RUSSELL JR', 'ARMY', 'SSG', '19490118', 'BROWNELL', 'NESS', '19690913', 'Y', 'KS']
# ['STAHL EDWARD ARNOLD', 'ARMY', 'SP4', '19450919', 'WESTPHALIA', 'ANDERSON', '19670525', 'Y', 'KS']
# ['STANDEFORD JAMES  MICHAEL', 'ARMY', 'SGT', '19471020', 'CHETOPA', 'LABETTE', '19681201', 'Y', 'KS']
# ['STANDERWICK ROBERT L  SR', 'AIR FORCE', 'COL', '19300623', 'MANKATO', 'JEWELL', '19710203', 'N', 'KS']
# ['STANFIELD GARY KELVIN', 'ARMY', 'SP4', '19490617', 'CHANUTE', 'NEOSHO', '19690914', 'Y', 'KS']
# ['STEIMEL GREGG FRANCIS', 'ARMY', 'SGT', '19500812', 'WRIGHT', 'FORD', '19700731', 'Y', 'KS']
# ['STEPHENS LESTER AL', 'ARMY', 'SP4', '19430714', 'WICHITA', 'SEDGWICK', '19690112', 'Y', 'KS']
# ['STEWART LEONARD  KEITH', 'ARMY', 'CPL', '19460911', 'SALINA', 'SALINE', '19680721', 'Y', 'KS']
# ['STEWART MICHAEL  HENRY', 'ARMY', 'CPL', '19490526', 'WICHITA', 'SEDGWICK', '19680508', 'Y', 'KS']
# ['STEWART WILLIAM  STEVEN', 'NAVY', 'PO2', '19470904', 'TOPEKA', 'SHAWNEE', '19701215', 'Y', 'KS']
# ['STIGGINS DOUGLAS LEE', 'ARMY', 'PFC', '19490503', 'PARTRIDGE', 'RENO', '19690724', 'Y', 'KS']
# ['STONE GEORGE  DAVIDSON', 'ARMY', 'PFC', '19471102', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680414', 'KS']
# ['Y STRAUB CONRAD ', 'FRANCIS', 'ARMY', 'SP4', '19461230', 'CLAFLIN', 'BARTON', '19670227', 'KS']
# ['Y STRUBE JAMES ', 'CLARENCE', 'ARMY', 'CPL', '19470905', 'POWHATTAN', 'BROWN', '19690611', 'KS']
# ['Y STULTZ CHARLES ', 'GILBERT', 'ARMY', 'SP4', '19480213', 'QUENEMO', 'OSAGE', '19690512', 'KS']
# ['Y SULLIVAN MICHAEL ', 'JAMES', 'ARMY', 'CPL', '19460603', 'WEIR', 'CHEROKEE', '19671121', 'KS']
# ['Y SUTTER FREDERICK JOHN', 'AIR FORCE', 'CAPT', '19460226', 'LEAWOOD', 'JOHNSON', '19711231', 'N', 'KS']
# ['SWAZICK DANNY  GEORGE', 'ARMY', 'CPL', '19430125', 'KANSAS CITY', 'WYANDOTTE', '19680302', 'Y', 'KS']
# ['SWENDER JACK SHIVELY', 'MARINE CORPS', 'LCPL', '19430214', 'KANSAS CITY', 'WYANDOTTE', '19651218', 'Y', 'KS']
# ['SWINK JACKIE LEE', 'ARMY', 'PFC', '19501218', 'LIBERAL', 'SEWARD', '19691014', 'Y', 'KS']
# ['SZIJJARTO STEPHEN  JOSEPH', 'ARMY', 'SGT', '19401112', 'WAMEGO', 'POTTAWATOMI', 'E', '19661217', 'KS']
# ['Y TALBURT RAYMOND ', 'THURL', 'ARMY', 'SGT', '19441026', 'WICHITA', 'SEDGWICK', '19690607', 'KS']
# ['Y TALIAFERRO GLEN ', 'JOHNSON', 'AIR FORCE', '1STLT', '19460206', 'EL DORADO', 'BUTLER', '19710802', 'KS']
# ['Y TAYLOR WALTER LEE JR', 'ARMY', 'SP4', '19490919', 'EL DORADO', 'BUTLER', '19700414', 'Y', 'KS']
# ['THOENNES MICHAEL  WALTER', 'MARINE CORPS', '1STLT', '19440823', 'LEAWOOD', 'JOHNSON', '19670530', 'Y', 'KS']
# ['THOMAS PAUL EDWARD', 'ARMY', 'SGT', '19481230', 'ESBON', 'JEWELL', '19700405', 'Y', 'KS']
# ['THOMPSON CECIL  TRUMAN', 'AIR FORCE', 'SSGT', '19350114', 'SABETHA', 'NEMAHA', '19670109', 'Y', 'KS']
# ['THOMPSON RICHARD W', 'ARMY', '1LT', '19410310', 'ATCHISON', 'ATCHISON', '19671119', 'Y', 'KS']
# ['THOMPSON ROBERT  EUGENE', 'ARMY', 'PFC', '19470816', 'EDWARDSVILL', 'E', 'WYANDOTTE', '19660504', 'KS']
# ['Y THOMPSON WILLIAM ', 'JOSEPH', 'NAVY', 'LCDR', '19301213', 'KANSAS CITY', 'WYANDOTTE', '19680116', 'KS']
# ['N TIDERMAN JOHN MARK', 'NAVY', 'LCDR', '19340823', 'KANSAS CITY', 'WYANDOTTE', '19660321', 'N', 'KS']
# ['TINKUM ETHER ARNOLD', 'ARMY', 'PFC', '19480502', 'WICHITA', 'SEDGWICK', '19680915', 'Y', 'KS']
# ['TODD JEROME DEAN', 'ARMY', 'SP5', '19490606', 'WICHITA', 'SEDGWICK', '19710924', 'Y', 'KS']
# ['TODD JIMMIE LESTER', 'ARMY', 'MSG', '19300906', 'HERINGTON', 'DICKINSON', '19680228', 'Y', 'KS']
# ['TOOMES WILLIS ALBERT', 'ARMY', 'SGT', '19470409', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19680921', 'KS']
# ['Y TRAIN STEVE WARREN', 'AIR FORCE', '1STLT', '19451031', 'LINDSBORG', 'MCPHERSON', '19700402', 'Y', 'KS']
# ['TRAVIS MICHAEL  RICHARD', 'MARINE CORPS', 'SGT', '19470831', 'WICHITA', 'SEDGWICK', '19680302', 'Y', 'KS']
# ['TREAS RICHARD LEE', 'ARMY', 'CPT', '19350820', 'MUNCIE', 'WYANDOTTE', '19680822', 'Y', 'KS']
# ['TROWER GARY RAY', 'MARINE CORPS', 'LCPL', '19470509', 'CHAPMAN', 'DICKINSON', '19690518', 'Y', 'KS']
# ['TROXEL CHARLES  LEONARD', 'ARMY', 'PFC', '19480607', 'IOLA', 'ALLEN', '19690816', 'Y', 'KS']
# ['TRUBE DELBERT LEROY  JR', 'MARINE CORPS', 'PFC', '19470818', 'BURDICK', 'MORRIS', '19660304', 'Y', 'KS']
# ['TUCKER ROBERT EUGENE', 'MARINE CORPS', 'LCPL', '19481112', 'ABBYVILLE', 'RENO', '19701118', 'Y', 'KS']
# ['TURNER JAMES EARL', 'ARMY', 'SP4', '19470731', 'EL DORADO', 'BUTLER', '19680807', 'Y', 'KS']
# ['TURNER JOHN HAROLD', 'ARMY', 'SSG', '19420312', 'POTWIN', 'BUTLER', '19680520', 'Y', 'KS']
# ['TURNER ROBERT ELDON', 'ARMY', 'MAJ', '19270813', 'MCPHERSON', 'MCPHERSON', '19690508', 'Y', 'KS']
# ['URBAN ROBERT LEE', 'ARMY', 'PFC', '19481123', 'HAYS', 'ELLIS', '19681008', 'Y', 'KS']
# ['VANWINKLE JESS H JR', 'ARMY', 'SGT', '19500331', 'JUNCTION CITY', 'GEARY', '19690907', 'Y', 'KS']
# ['VELASQUEZ DAVID  ROBERT', 'MARINE CORPS', 'PFC', '19460305', 'GARDNER', 'JOHNSON', '19660206', 'Y', 'KS']
# ['VIEGRA LUZ', 'ARMY', 'SP4', '19421213', 'LARNED', 'PAWNEE', '19651204', 'Y', 'KS']
# ['WALKER CHARLES  BUTNER JR', 'MARINE CORPS', 'LCPL', '19480229', 'OVERLAND ', 'PARK', 'JOHNSON', '19690903', 'KS']
# ['Y WALLACE DONALD DEAN', 'ARMY', 'SP4', '19460406', 'WESKAN', 'WALLACE', '19660801', 'Y', 'KS']
# ['WALLACE LANNY JOHN', 'ARMY', '1LT', '19420916', 'SHAWNEE ', 'MISSION', 'JOHNSON', '19700721', 'KS']
# ['Y WALTERS JOHN EDMOND', 'ARMY', 'CPL', '19491025', 'PARSONS', 'LABETTE', '19690302', 'Y', 'KS']
# ['WARD RONALD RAY', 'ARMY', 'PFC', '19491211', 'HAYSVILLE', 'SEDGWICK', '19690523', 'Y', 'KS']
# ['WARDS DAN THOMAS', 'NAVY', 'HN', '19471224', 'PAOLA', 'MIAMI', '19680107', 'Y', 'KS']
# ['WARREN LARRY DEAN', 'ARMY', 'PFC', '19471031', 'LIBERAL', 'SEWARD', '19680416', 'Y', 'KS']
# ['WATTS LARRY DEAN', 'ARMY', 'PFC', '19430716', 'COFFEYVILLE', 'MONTGOMERY', '19670307', 'Y', 'KS']
# ['WEBB GARY ALAN', 'ARMY', 'SGT', '19450720', 'WA KEENEY', 'TREGO', '19670226', 'Y', 'KS']
# ['WEBB JOHNNY ROBERT', 'ARMY', 'PFC', '19440209', 'CHANUTE', 'NEOSHO', '19680418', 'Y', 'KS']
# ['WEIS KENNETH D', 'ARMY', 'MSG', '19300603', 'SALINA', 'SALINE', '19670913', 'Y', 'KS']
# ['WELCH JODIE VARNER JR', 'MARINE CORPS', 'CPL', '19470914', 'KANSAS CITY', 'WYANDOTTE', '19670324', 'Y', 'KS']
# ['WELDON ROBERT P', 'AIR FORCE', 'SGT', '19551010', 'KANSAS CITY', 'WYANDOTTE', '19750513', 'Y', 'KS']
# ['WELLS BRIAN LEE', 'MARINE CORPS', 'CPL', '19480202', 'WICHITA', 'SEDGWICK', '19690215', 'Y', 'KS']
# ['WELSCH CLARENCE  LEON JR', 'ARMY', 'CPL', '19470110', 'GARFIELD', 'PAWNEE', '19681228', 'Y', 'KS']
# ['WELSH LARRY DON', 'ARMY', 'SSG', '19470616', 'KANSAS CITY', 'WYANDOTTE', '19690107', 'N', 'KS']
# ['WEST JOHN MICHAEL', 'ARMY', 'SP4', '19470206', 'MEDICINE ', 'LODGE', 'BARBER', '19670331', 'KS']
# ['Y WEST PAUL EDWARD', 'ARMY', 'PFC', '19470610', 'SHAWNEE', 'JOHNSON', '19680302', 'Y', 'KS']
# ['WESTOVER DAVID EDWIN', 'NAVY', 'SN', '19461229', 'WINDOM', 'MCPHERSON', '19690728', 'Y', 'KS']
# ['WESTPHAL JERELD  EUGENE', 'MARINE CORPS', 'LCPL', '19450416', 'BETHEL', 'WYANDOTTE', '19670603', 'Y', 'KS']
# ['WHEELER MORRIS CRAIG', 'MARINE CORPS', 'LCPL', '19470326', 'MUNCIE', 'WYANDOTTE', '19670110', 'Y', 'KS']
# ['WHELCHEL RUSSELL  DESMOND', 'MARINE CORPS', 'LCPL', '19470719', 'LIBERAL', 'SEWARD', '19670907', 'Y', 'KS']
# ['WHINERY ROGER LEE', 'NAVY', 'HN', '19450216', 'FREDONIA', 'WILSON', '19670601', 'Y', 'KS']
# ['WHITE GLENN EARL', 'MARINE CORPS', 'PFC', '19480722', 'WICHITA', 'SEDGWICK', '19671106', 'Y', 'KS']
# ['WHITE MICHAEL ALAN', 'ARMY', 'SSG', '19490617', 'EL DORADO', 'BUTLER', '19690609', 'Y', 'KS']
# ['WHITE MICHAEL LAVERN', 'NAVY', 'PO3', '19480820', 'LENEXA', 'JOHNSON', '19690923', 'Y', 'KS']
# ['WHITEHEAD THOMAS  LEROY', 'ARMY', 'SP4', '19441029', 'WICHITA', 'SEDGWICK', '19680118', 'Y', 'KS']
# ['WHITERS DONALD  EMERY', 'MARINE CORPS', 'LCPL', '19480313', 'WICHITA', 'SEDGWICK', '19680618', 'Y', 'KS']
# ['WILLIAM RONALD  WAYNE', 'ARMY', 'SP4', '19500726', 'HOXIE', 'SHERIDAN', '19700321', 'Y', 'KS']
# ['WILLIAMS BILLIE JOE', 'MARINE CORPS', 'PFC', '19451118', 'KANSAS CITY', 'WYANDOTTE', '19660321', 'Y', 'KS']
# ['WILLIAMS JOHN CHARLES', 'ARMY', 'SP4', '19480326', 'SHAWNEE', 'JOHNSON', '19690811', 'Y', 'KS']
# ['WILLIAMS ROGER RALPH', 'ARMY', 'SP4', '19460215', 'KANSAS CITY', 'WYANDOTTE', '19670303', 'Y', 'KS']
# ['WILLIAMS THOMAS  VERNON JR', 'ARMY', 'PFC', '19480820', 'LAKIN', 'KEARNY', '19680828', 'Y', 'KS']
# ['WILSON BILLIE JOE', 'MARINE CORPS', 'SSGT', '19290121', 'VALLEY ', 'CENTER', 'SEDGWICK', '19700209', 'KS']
# ['Y WILSON JOHN LEE', 'ARMY', 'SP4', '19490127', 'BONNER ', 'SPRINGS', 'WYANDOTTE', '19700507', 'KS']
# ['Y WILSON MICHAEL LUND', 'ARMY', '2LT', '19450403', 'HUTCHINSON', 'RENO', '19680603', 'Y', 'KS']
# ['WILSON RODNEY DAVID', 'ARMY', 'PFC', '19490928', 'TOPEKA', 'SHAWNEE', '19690703', 'Y', 'KS']
# ['WINDLE PAUL RALPH', 'AIR FORCE', 'CAPT', '19341114', 'MULLINVILLE', 'KIOWA', '19650630', 'Y', 'KS']
# ['WINN DONALD DEAN', 'ARMY', 'SP4', '19440806', 'EUREKA', 'GREENWOOD', '19710101', 'Y', 'KS']
# ['WINNINGHAM CLIFTON', 'ARMY', 'PSG', '19301122', 'JUNCTION CITY', 'GEARY', '19660305', 'Y', 'KS']
# ['WINTERS JOHN EDWARD', 'NAVY', 'PO1', '19370226', 'LIBERAL', 'SEWARD', '19701030', 'Y', 'KS']
# ['WISWELL SAMMY RAY', 'ARMY', 'SSG', '19410904', 'OTTAWA', 'FRANKLIN', '19661119', 'Y', 'KS']
# ['WOLFE RICHARD OGDEN', 'NAVY', 'PO1', '19421108', 'KANSAS CITY', 'WYANDOTTE', '19691130', 'Y', 'KS']
# ['WOOD LLOYD JOSEPH SR', 'ARMY', 'SFC', '19340323', 'INDEPENDENCE', 'MONTGOMERY', '19690430', 'Y', 'KS']
# ['WOODY WILLARD  EVERETT', 'ARMY', 'SP4', '19500728', 'GARLAND', 'BOURBON', '19710109', 'Y', 'KS']
# ['WRIGHT RICHARD HUGH', 'MARINE CORPS', 'PFC', '19440814', 'HALSTEAD', 'HARVEY', '19660402', 'Y', 'KS']
# ['WYRICK MICHAEL ALLEN', 'MARINE CORPS', 'PFC', '19481122', 'EDWARDSVILL', 'E', 'WYANDOTTE', '19671021', 'KS']
# ['Y ZELLER MICHAEL ', 'CHARLES', 'ARMY', 'SP4', '19470902', 'WAMEGO', 'POTTAWATOMI', 'E', 'KS']
# ['19680225 Y', 'ZUTTERMAN JOSEPH A JR', 'MARINE CORPS', 'SGT', '19441003', 'MARYSVILLE', 'MARSHALL', '19680420', 'KS']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-11cc46f0f956> in <module>
# ----> 1 TS_prep_for_df(ks_data, 'KS')
#
# <ipython-input-28-0d8953bc2dd8> in TS_prep_for_df(data_in_list, state)
#       9     while counter > 0:
#      10
# ---> 11         if big_long_list[1] not in military:
#      12
#      13             big_long_list[0] = big_long_list[0] + ' ' + big_long_list[1]
#
# IndexError: list index out of range

# %% [markdown]
# Well I found the error. It looks like if the county or city name was too long, they also created a newline for it. It efforts to account for all this, I will alter my `scrape_pdf` function.
#
# After some delibration, I couldn't find a way to tell the difference between the records that contained a newline on the `county` record or on the `home` record. These records will have to be seperately dealt with. Since county data can be more easily grouped, I will condense on the `home` records in hopes that the county names are all one liners. I will gather lists of counties in all states to verify that data when I proceede later on.

# %%
def TS_prep_for_df(data_in_list, state):  #Takes in a list and the state, as a string. It will return a list of lists.
    
    big_long_list = data_in_list.copy()    #Making a deep copy, so I don't effect the underlying list. 
    output = []
    counter = len(big_long_list)

    while counter > 0:
        
        #This loop checks if there is newline in the name line
        
        if big_long_list[1] not in military:

            big_long_list[0] = big_long_list[0] + big_long_list[1]
            
            big_long_list.remove(big_long_list[1])
            
        #New code to account for the new lines in the home and county entries 
        #This checks the list to see if any new lines are present
        try:
            int(big_long_list[6])
            
        except ValueError:
            
            #If there are two newlines, one in home and one in county, this will be taken care of here
            try:
                int(big_long_list[7])
                
            except ValueError:
                big_long_list[5] = big_long_list[5] + big_long_list[6]
                del big_long_list[6]
                
            #If there is only one newline, this will put the middle entry into the home cell
            try:
                int(big_long_list[6])
                
            except ValueError:
                big_long_list[4] = big_long_list[4] + big_long_list[5]
                del big_long_list[5]
        
        place_holder = big_long_list[:8]
        
        
        place_holder.append(state)
        
        output.append(place_holder)
        
        del big_long_list[:8]
        counter = len(big_long_list)
    
    return(output)

# %%
to_inspect = TS_prep_for_df(ks_data, 'KS')
to_inspect[-2]
# Out:
# ['ZELLER MICHAEL CHARLES',
#  'ARMY',
#  'SP4',
#  '19470902',
#  'WAMEGOPOTTAWATOMI',
#  'E',
#  '19680225',
#  'Y',
#  'KS']

# %% [markdown]
# So it worked, mostly. The above is an example of where my solution fails. The next iteration of this function should reference the counties, per state, and verify if the name is correct. I am going to move forward at this point. I am going to formalize the `prep_for_df` function and see if I can put it altogether.

# %%
def prep_for_df(data_in_list, state):  #Takes in a list and the state, as a string. It will return a list of lists.
    
    big_long_list = data_in_list.copy()    #Making a deep copy, so I don't effect the underlying list. 
    output = []
    counter = len(big_long_list)

    while counter > 0:
        
        #This loop checks if there is newline in the name line
        
        if big_long_list[1] not in military:

            big_long_list[0] = big_long_list[0] + big_long_list[1]
            
            big_long_list.remove(big_long_list[1])
            
        #New code to account for the new lines in the home and county entries 
        #This checks the list to see if any new lines are present
        try:
            int(big_long_list[6])
            
        except ValueError:
            
            #If there are two newlines, one in home and one in county, this will be taken care of here
            try:
                int(big_long_list[7])
                
            except ValueError:
                big_long_list[5] = big_long_list[5] + big_long_list[6]
                del big_long_list[6]
                
            #If there is only one newline, this will put the middle entry into the home cell
            try:
                int(big_long_list[6])
                
            except ValueError:
                big_long_list[4] = big_long_list[4] + big_long_list[5]
                del big_long_list[5]
        
        place_holder = big_long_list[:8]
        
        
        place_holder.append(state)
        
        output.append(place_holder)
        
        del big_long_list[:8]
        counter = len(big_long_list)
    
    return(output)

# %% [markdown]
# Another trial of it all together.

# %%
df_list = []

for pdf in pdf_paths:
    
    state = str(pdf[11:13].upper())
    
    place_holder = scrape_pdf(pdf)
    
    data = prep_for_df(place_holder, state)
    
    df_list.append(pd.DataFrame(data, columns = ['name', 'service', 'rank_rate', 'birthdate', 'home_city', 'home_county', 'incident_death', 'body_rec', 'state']))

# %%
len(df_list)
# Out:
# 51

# %% [markdown]
# Now combine them all

# %%
state_records = pd.concat(df_list)

# %%
state_records.shape
# Out:
# (57646, 9)

# %%
state_records.state.value_counts()
# Out:
# CA    5572
# NY    4118
# TX    3415
# PA    3147
# OH    3093
# IL    2935
# MI    2656
# FL    1954
# NC    1612
# GA    1581
# IN    1534
# NJ    1487
# MO    1417
# MA    1331
# VA    1304
# TN    1295
# AL    1208
# WI    1160
# MN    1077
# KY    1055
# WA    1047
# MD    1013
# OK     986
# SC     895
# LA     885
# IA     851
# WV     733
# OR     710
# MS     636
# KS     627
# CO     623
# AZ     619
# CT     612
# AR     591
# NE     396
# NM     395
# UT     361
# ME     341
# HI     276
# MT     267
# DC     242
# NH     226
# ID     217
# RI     209
# ND     199
# SD     192
# NV     149
# DE     122
# WY     118
# VT     100
# AK      57
# Name: state, dtype: int64

# %%
#state_records.to_pickle('data/processed/states_df')
state_records = pd.read_pickle('data/processed/states_df')

# %%
state_records.head()
# Out:
#                      name       service rank_rate birthdate    home_city  \
# 0    ABDELLAH BRUCE ALLYN          ARMY       PVT  19521215  EAST HOLDEN
# 1   ALBERT LOUIS BASIL JR  MARINE CORPS       PFC  19480928     DANFORTH
# 2  ALBERT RICHARD PATRICK          ARMY       CPL  19480317    ST AGATHA
# 3  ALEXANDER DAVID HAROLD          ARMY       SP4  19480118      SANFORD
# 4   ALLEN KEITH DOBSON JR          ARMY       CW2  19461209    WESTFIELD
#
#   home_county incident_death body_rec state
# 0   PENOBSCOT       19711026        Y    ME
# 1  WASHINGTON       19691008        Y    ME
# 2   AROOSTOOK       19690820        Y    ME
# 3        YORK       19681216        Y    ME
# 4   AROOSTOOK       19690413        Y    ME

# %% [markdown]
# ## Additional Database

# %% [markdown]
# Another document take from the National Archives.

# %%
pdfFileObj = open('DCAS.VN08.DOC.pdf', 'rb')

pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

pdf_data = ''

for pg in list(range(2)):
    pageObj = pdfReader.getPage(pg)
    chunk = pageObj.extractText()
    pdf_data += chunk

# %%
pdf_data
# Out:
# "Vietnam Conflict and Korean War File Layout (Pipe (|) Delimited Format)#Column NamesDataTypeDataSizeCoulmn DescriptionFurther Column Description1SERVICE NOText10Service Number\n2CText1Member Component Code\n\n3PTPText1Person Type Name Code\n\n4Person Type NameText55Person Type Name\n\n5Member NameText40Member Name\n6SText1Member Service Code\nA= Army, F = Air Force,M = Marines Corps, N = Navy7Service NameText50Member Service Name\n8Rank RateText6Member Rank or Rate\n\n9PGText3Member Paygrade\n10OccText6Member Occupation Code\n\n11Occupation NameText250Member Occupation Name\n\n12Birth DtText8Member BirthdateYYYYMMDD\n\n13GText1Member's GenderM = Male, F= Female\n\n14Hor CityText50Home of Record City\n\n15Hor CountyText50Home of Record County\n\n16Hor CtryText2Home of Record Country Code\n\n17Hor STText2Home of Record State Code\n\n18State Prv NmText50State or Province Name\n\n19Marital StatusText50Marital Name\n\n20Religion NameText60Religion Short Name\n\n21LText2Religion Code\n\n22Race NameText120Race Name\n\n23Ethnic NameText80Ethnic Short Name\n\n24Race OmbText50Race OMB Name\n\n25Ethnic Group NameText50Ethnic Group Name\n\n26Cas CircumstancesText210Casualty Circumstances\n\n27Cas CityText50Casualty City\n\n28Cas STText2Casualty State or Province Code\n\n29Cas CtryText2Casualty Country/Over Water Code\n\n30Cas Region NameText50Region Name\n\n31Country Or Water NameText50Country/Over Water Name\n\n32Unit NameText100Member Unit\n\n33DText1Duty Code\n\n34Process DtText8Process DateYYYYMMDD\n\n35Death DtText8Incident or Death DateYYYYMMDD\n1Vietnam Conflict and Korean War File Layout (Pipe (|) Delimited Format)#Column NamesDataTypeDataSizeCoulmn DescriptionFurther Column Description36YearText4Year of DeathYYYY\n37WCText1War or Conflict Code\nV = Vietnam Conflict, K = Korean War38OITPText1Operation Incident Type Code\n39OI NameText50Operation/Incident Name\n\n40OI LocationText50Location Name\n\n41Close DtText8Closure DateYYYYMMDD\n\n42AircraftText10Aircraft Type\n43HText2Hostile or Non-Hostile Death Indicator\nH = Hostile, NH = Non-Hostile Death44Casualty Type NameText50Casualty Type Name\n45Casualty CategoryText50Casualty Category Name\n\n46Casualty Reason NameText50Incident Casualty Reason Name\n\n47CSNText3Casualty  Cat. Short Name\n48BodyText1Remains Recovered\nY= Body Remains Recovered , N = Body Remains Not \nRecovered49Casualty Closure NameText50Casualty Closure Name\n50WallText7Vietnam Wall Row and Panel Indicator\n\n51Incident CategoryText50Casualty Category Name\n\n52I Status DtText8Incident Casualty Category DateYYYYMMDD\n\n53I CSNText3Incident Casualty  Cat. Short Name\n\n54I HText2Incident Hostile or Incident Non-Hostile Death\n\n55I AircraftText10Incident Aircraft Type\n2"

# %%
pdf_data.splitlines()
# Out:
# ['Vietnam Conflict and Korean War File Layout (Pipe (|) Delimited Format)#Column NamesDataTypeDataSizeCoulmn DescriptionFurther Column Description1SERVICE NOText10Service Number',
#  '2CText1Member Component Code',
#  '',
#  '3PTPText1Person Type Name Code',
#  '',
#  '4Person Type NameText55Person Type Name',
#  '',
#  '5Member NameText40Member Name',
#  '6SText1Member Service Code',
#  'A= Army, F = Air Force,M = Marines Corps, N = Navy7Service NameText50Member Service Name',
#  '8Rank RateText6Member Rank or Rate',
#  '',
#  '9PGText3Member Paygrade',
#  '10OccText6Member Occupation Code',
#  '',
#  '11Occupation NameText250Member Occupation Name',
#  '',
#  '12Birth DtText8Member BirthdateYYYYMMDD',
#  '',
#  "13GText1Member's GenderM = Male, F= Female",
#  '',
#  '14Hor CityText50Home of Record City',
#  '',
#  '15Hor CountyText50Home of Record County',
#  '',
#  '16Hor CtryText2Home of Record Country Code',
#  '',
#  '17Hor STText2Home of Record State Code',
#  '',
#  '18State Prv NmText50State or Province Name',
#  '',
#  '19Marital StatusText50Marital Name',
#  '',
#  '20Religion NameText60Religion Short Name',
#  '',
#  '21LText2Religion Code',
#  '',
#  '22Race NameText120Race Name',
#  '',
#  '23Ethnic NameText80Ethnic Short Name',
#  '',
#  '24Race OmbText50Race OMB Name',
#  '',
#  '25Ethnic Group NameText50Ethnic Group Name',
#  '',
#  '26Cas CircumstancesText210Casualty Circumstances',
#  '',
#  '27Cas CityText50Casualty City',
#  '',
#  '28Cas STText2Casualty State or Province Code',
#  '',
#  '29Cas CtryText2Casualty Country/Over Water Code',
#  '',
#  '30Cas Region NameText50Region Name',
#  '',
#  '31Country Or Water NameText50Country/Over Water Name',
#  '',
#  '32Unit NameText100Member Unit',
#  '',
#  '33DText1Duty Code',
#  '',
#  '34Process DtText8Process DateYYYYMMDD',
#  '',
#  '35Death DtText8Incident or Death DateYYYYMMDD',
#  '1Vietnam Conflict and Korean War File Layout (Pipe (|) Delimited Format)#Column NamesDataTypeDataSizeCoulmn DescriptionFurther Column Description36YearText4Year of DeathYYYY',
#  '37WCText1War or Conflict Code',
#  'V = Vietnam Conflict, K = Korean War38OITPText1Operation Incident Type Code',
#  '39OI NameText50Operation/Incident Name',
#  '',
#  '40OI LocationText50Location Name',
#  '',
#  '41Close DtText8Closure DateYYYYMMDD',
#  '',
#  '42AircraftText10Aircraft Type',
#  '43HText2Hostile or Non-Hostile Death Indicator',
#  'H = Hostile, NH = Non-Hostile Death44Casualty Type NameText50Casualty Type Name',
#  '45Casualty CategoryText50Casualty Category Name',
#  '',
#  '46Casualty Reason NameText50Incident Casualty Reason Name',
#  '',
#  '47CSNText3Casualty  Cat. Short Name',
#  '48BodyText1Remains Recovered',
#  'Y= Body Remains Recovered , N = Body Remains Not ',
#  'Recovered49Casualty Closure NameText50Casualty Closure Name',
#  '50WallText7Vietnam Wall Row and Panel Indicator',
#  '',
#  '51Incident CategoryText50Casualty Category Name',
#  '',
#  '52I Status DtText8Incident Casualty Category DateYYYYMMDD',
#  '',
#  '53I CSNText3Incident Casualty  Cat. Short Name',
#  '',
#  '54I HText2Incident Hostile or Incident Non-Hostile Death',
#  '',
#  '55I AircraftText10Incident Aircraft Type',
#  '2']

# %%
to_clean = pdf_data.splitlines()
col_desc = []
for line in to_clean:
    col = re.search(".*(?=Text)", line)
    description = re.search("(?<=Text).*", line)
    try:
        col_data = col.group(0)
        desc_data = description.group(0)
        
        place_holder = col_data, desc_data
        col_desc.append(place_holder)
    except AttributeError:
        pass

# %%
col_desc[0] = col_desc[0][0][145:], col_desc[0][1]
col_desc[6] = col_desc[6][0][51:], col_desc[6][1]
col_desc[35] = col_desc[35][0][145:], col_desc[35][1]
col_desc[37] = col_desc[37][0][36:], col_desc[37][1]
col_desc[43] = col_desc[43][0][36:], col_desc[43][1]

# %%
def remove_num(list):
    
    pattern = '[0-9]'
    list = [re.sub(pattern, '', i) for i in list] 
    return list

# %%
col_names = []
for line in col_desc:
    col_names.append(remove_num(line))

# %%
col_names
# Out:
# [['SERVICE NO', 'Service Number'],
#  ['C', 'Member Component Code'],
#  ['PTP', 'Person Type Name Code'],
#  ['Person Type Name', 'Person Type Name'],
#  ['Member Name', 'Member Name'],
#  ['S', 'Member Service Code'],
#  ['Service Name', 'Member Service Name'],
#  ['Rank Rate', 'Member Rank or Rate'],
#  ['PG', 'Member Paygrade'],
#  ['Occ', 'Member Occupation Code'],
#  ['Occupation Name', 'Member Occupation Name'],
#  ['Birth Dt', 'Member BirthdateYYYYMMDD'],
#  ['G', "Member's GenderM = Male, F= Female"],
#  ['Hor City', 'Home of Record City'],
#  ['Hor County', 'Home of Record County'],
#  ['Hor Ctry', 'Home of Record Country Code'],
#  ['Hor ST', 'Home of Record State Code'],
#  ['State Prv Nm', 'State or Province Name'],
#  ['Marital Status', 'Marital Name'],
#  ['Religion Name', 'Religion Short Name'],
#  ['L', 'Religion Code'],
#  ['Race Name', 'Race Name'],
#  ['Ethnic Name', 'Ethnic Short Name'],
#  ['Race Omb', 'Race OMB Name'],
#  ['Ethnic Group Name', 'Ethnic Group Name'],
#  ['Cas Circumstances', 'Casualty Circumstances'],
#  ['Cas City', 'Casualty City'],
#  ['Cas ST', 'Casualty State or Province Code'],
#  ['Cas Ctry', 'Casualty Country/Over Water Code'],
#  ['Cas Region Name', 'Region Name'],
#  ['Country Or Water Name', 'Country/Over Water Name'],
#  ['Unit Name', 'Member Unit'],
#  ['D', 'Duty Code'],
#  ['Process Dt', 'Process DateYYYYMMDD'],
#  ['Death Dt', 'Incident or Death DateYYYYMMDD'],
#  ['Year', 'Year of DeathYYYY'],
#  ['WC', 'War or Conflict Code'],
#  ['OITP', 'Operation Incident Type Code'],
#  ['OI Name', 'Operation/Incident Name'],
#  ['OI Location', 'Location Name'],
#  ['Close Dt', 'Closure DateYYYYMMDD'],
#  ['Aircraft', 'Aircraft Type'],
#  ['H', 'Hostile or Non-Hostile Death Indicator'],
#  ['Casualty Type Name', 'Casualty Type Name'],
#  ['Casualty Category', 'Casualty Category Name'],
#  ['Casualty Reason Name', 'Incident Casualty Reason Name'],
#  ['CSN', 'Casualty  Cat. Short Name'],
#  ['Body', 'Remains Recovered'],
#  ['RecoveredCasualty Closure Name', 'Casualty Closure Name'],
#  ['Wall', 'Vietnam Wall Row and Panel Indicator'],
#  ['Incident Category', 'Casualty Category Name'],
#  ['I Status Dt', 'Incident Casualty Category DateYYYYMMDD'],
#  ['I CSN', 'Incident Casualty  Cat. Short Name'],
#  ['I H', 'Incident Hostile or Incident Non-Hostile Death'],
#  ['I Aircraft', 'Incident Aircraft Type']]

# %%
columns = []
for description in col_names:
    columns.append(description[0])

# %%
#columns = 
war_file = pd.read_csv('DCAS.VN.EXT08.DAT', delimiter = '|', engine='python', header=None, names=columns)
war_file.head()
# Out:
#   SERVICE NO  C PTP  Person Type Name             Member Name  S  \
# 0  503503584  Y   S  SELECTED SERVICE        AADLAND GERALD L  A
# 1  465720672  Y   S  SELECTED SERVICE    AALUND JAMES DOWNING  A
# 2  473635900  R   K  ACTIVE - REGULAR  AAMOLD DANIEL LAWRENCE  F
# 3    2221574  Y   S  SELECTED SERVICE     AARDE JAMES RAYMOND  M
# 4  025368444  Y   S  SELECTED SERVICE    AARON CHARLES EDWARD  A
#
#    Service Name Rank Rate   PG     Occ Occupation Name  Birth Dt  G  \
# 0          ARMY       SP4  E04     11B     INFANTRYMAN  19450329  M
# 1          ARMY       SGT  E05     11B     INFANTRYMAN  19450511  M
# 2     AIR FORCE       A1C  E03                     NaN  19510823  M
# 3  MARINE CORPS      LCPL  E03    0311        RIFLEMAN  19440608  M
# 4          ARMY       SP4  E04     11B     INFANTRYMAN  19481212  M
#
#         Hor City Hor County Hor Ctry Hor ST   State Prv Nm Marital Status  \
# 0       SISSETON    ROBERTS       US     SD   SOUTH DAKOTA  NEVER MARRIED
# 1        HOUSTON     HARRIS       US     TX          TEXAS  NEVER MARRIED
# 2       MOORHEAD       CLAY       US     MN      MINNESOTA  NEVER MARRIED
# 3           KENT       KING       US     WA     WASHINGTON        MARRIED
# 4  FORGE VILLAGE  MIDDLESEX       US     MA  MASSACHUSETTS  NEVER MARRIED
#
#                               Religion Name   L Race Name    Ethnic Name  \
# 0                         LUTHERAN CHURCHES  LL     WHITE  NOT SPECIFIED
# 1                        METHODIST CHURCHES  MM     WHITE  NOT SPECIFIED
# 2                          BAPTIST CHURCHES  BB     WHITE  NOT SPECIFIED
# 3  PROTESTANT, NO DENOMINATIONAL PREFERENCE  TN     WHITE  NOT SPECIFIED
# 4                        METHODIST CHURCHES  MM     WHITE  NOT SPECIFIED
#
#   Race Omb Ethnic Group Name Cas Circumstances    Cas City Cas ST Cas Ctry  \
# 0    WHITE           UNKNOWN               NaN      KONTUM     M2       VS
# 1    WHITE           UNKNOWN               NaN  PHUOC LONG     M3       VS
# 2    WHITE           UNKNOWN               NaN  NINH THUAN     M2       VS
# 3    WHITE           UNKNOWN               NaN   QUANG TRI     M1       VS
# 4    WHITE           UNKNOWN               NaN  BINH THUAN     M2       VS
#
#   Cas Region Name Country Or Water Name                   Unit Name  D  \
# 0            ASIA         SOUTH VIETNAM  D CO 3 BN 12 INF 4 INF DIV  Z
# 1            ASIA         SOUTH VIETNAM         1 CAV DIV AIRMOBILE  Z
# 2            ASIA         SOUTH VIETNAM                         NaN  Z
# 3            ASIA         SOUTH VIETNAM                         NaN  Z
# 4            ASIA         SOUTH VIETNAM               1 FIELD FORCE  Z
#
#    Process Dt  Death Dt  Year WC OITP           OI Name     OI Location  \
# 0    19680501  19680530  1968  V    C  VIETNAM CONFLICT  SOUTHEAST ASIA
# 1    19700301  19700228  1970  V    C  VIETNAM CONFLICT  SOUTHEAST ASIA
# 2    19700801  19700820  1970  V    C  VIETNAM CONFLICT  SOUTHEAST ASIA
# 3    19661201  19661229  1966  V    C  VIETNAM CONFLICT  SOUTHEAST ASIA
# 4    19700501  19700505  1970  V    C  VIETNAM CONFLICT  SOUTHEAST ASIA
#
#      Close Dt Aircraft   H Casualty Type Name Casualty Category  \
# 0  19680530.0      NaN   H           DECEASED  KILLED IN ACTION
# 1  19700228.0      NaN   H           DECEASED  KILLED IN ACTION
# 2  19700820.0      NaN  NH           DECEASED          ACCIDENT
# 3  19661229.0      NaN   H           DECEASED    DIED OF WOUNDS
# 4  19700505.0      NaN   H           DECEASED  KILLED IN ACTION
#
#       Casualty Reason Name  CSN Body RecoveredCasualty Closure Name     Wall  \
# 0          SMALL ARMS FIRE  NaN    Y          BURIED - UNKNOWN DISP  63W 014
# 1  ARTILLERY/MORTAR/ROCKET  NaN    Y          BURIED - UNKNOWN DISP  13W 066
# 2           OTHER ACCIDENT  NaN    Y          BURIED - UNKNOWN DISP  08W 124
# 3         EXPLOSIVE DEVICE  NaN    Y          BURIED - UNKNOWN DISP  13E 095
# 4                  GRENADE  NaN    Y          BURIED - UNKNOWN DISP  11W 098
#
#                   Incident Category  I Status Dt I CSN  I H I Aircraft
# 0                               NaN          NaN   NaN  NaN        NaN
# 1                               NaN          NaN   NaN  NaN        NaN
# 2                               NaN          NaN   NaN  NaN        NaN
# 3  WOUNDED IN ACTION (VERY SERIOUS)          0.0   WIA    H        NaN
# 4                               NaN          NaN   NaN  NaN        NaN

# %%
war_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58220 entries, 0 to 58219
# Data columns (total 55 columns):
# SERVICE NO                        58220 non-null object
# C                                 58038 non-null object
# PTP                               58220 non-null object
# Person Type Name                  58217 non-null object
# Member Name                       58220 non-null object
# S                                 58220 non-null object
# Service Name                      58220 non-null object
# Rank Rate                         58220 non-null object
# PG                                58220 non-null object
# Occ                               58192 non-null object
# Occupation Name                   54013 non-null object
# Birth Dt                          58220 non-null int64
# G                                 58220 non-null object
# Hor City                          58098 non-null object
# Hor County                        58191 non-null object
# Hor Ctry                          58220 non-null object
# Hor ST                            58103 non-null object
# State Prv Nm                      58103 non-null object
# Marital Status                    58220 non-null object
# Religion Name                     58217 non-null object
# L                                 58217 non-null object
# Race Name                         58220 non-null object
# Ethnic Name                       58220 non-null object
# Race Omb                          58220 non-null object
# Ethnic Group Name                 58220 non-null object
# Cas Circumstances                 40 non-null object
# Cas City                          49211 non-null object
# Cas ST                            49059 non-null object
# Cas Ctry                          58220 non-null object
# Cas Region Name                   58220 non-null object
# Country Or Water Name             58220 non-null object
# Unit Name                         41130 non-null object
# D                                 58220 non-null object
# Process Dt                        58220 non-null int64
# Death Dt                          58220 non-null int64
# Year                              58220 non-null int64
# WC                                58220 non-null object
# OITP                              58218 non-null object
# OI Name                           58218 non-null object
# OI Location                       58218 non-null object
# Close Dt                          56449 non-null float64
# Aircraft                          85 non-null object
# H                                 58220 non-null object
# Casualty Type Name                58220 non-null object
# Casualty Category                 58220 non-null object
# Casualty Reason Name              58212 non-null object
# CSN                               0 non-null float64
# Body                              58220 non-null object
# RecoveredCasualty Closure Name    58220 non-null object
# Wall                              58197 non-null object
# Incident Category                 6623 non-null object
# I Status Dt                       6621 non-null float64
# I CSN                             6620 non-null object
# I H                               6623 non-null object
# I Aircraft                        13 non-null object
# dtypes: float64(3), int64(4), object(48)
# memory usage: 24.4+ MB

# %%
war_file.isna().sum()
# Out:
# SERVICE NO                            0
# C                                   182
# PTP                                   0
# Person Type Name                      3
# Member Name                           0
# S                                     0
# Service Name                          0
# Rank Rate                             0
# PG                                    0
# Occ                                  28
# Occupation Name                    4207
# Birth Dt                              0
# G                                     0
# Hor City                            122
# Hor County                           29
# Hor Ctry                              0
# Hor ST                              117
# State Prv Nm                        117
# Marital Status                        0
# Religion Name                         3
# L                                     3
# Race Name                             0
# Ethnic Name                           0
# Race Omb                              0
# Ethnic Group Name                     0
# Cas Circumstances                 58180
# Cas City                           9009
# Cas ST                             9161
# Cas Ctry                              0
# Cas Region Name                       0
# Country Or Water Name                 0
# Unit Name                         17090
# D                                     0
# Process Dt                            0
# Death Dt                              0
# Year                                  0
# WC                                    0
# OITP                                  2
# OI Name                               2
# OI Location                           2
# Close Dt                           1771
# Aircraft                          58135
# H                                     0
# Casualty Type Name                    0
# Casualty Category                     0
# Casualty Reason Name                  8
# CSN                               58220
# Body                                  0
# RecoveredCasualty Closure Name        0
# Wall                                 23
# Incident Category                 51597
# I Status Dt                       51599
# I CSN                             51600
# I H                               51597
# I Aircraft                        58207
# dtype: int64

# %% [markdown]
# I am going to inspect the unique values all the columns to get a better understanding of the data.

# %%
for col in war_file.columns:
    print(f"These are the all the values in {col}")
    print(war_file[col].unique())
    print(f"TOTAL {len(war_file[col].unique())}")
    print('------------------------------------------')
# Out:
# These are the all the values in SERVICE NO
# ['503503584' '465720672' '473635900' ... '56957866' '16829253' '2351252']
# TOTAL 58220
# ------------------------------------------
# These are the all the values in C
# ['Y' 'R' 'V' nan 'G']
# TOTAL 5
# ------------------------------------------
# These are the all the values in PTP
# ['S' 'K' 'L' 'T' 'Q' 'R' 'F']
# TOTAL 7
# ------------------------------------------
# These are the all the values in Person Type Name
# ['SELECTED SERVICE' 'ACTIVE - REGULAR' 'ACTIVE - GUARD/RESERVE'
#  'TEMP/PERM DISABILITY RETIRED LIST (OVER 120 DAYS)'
#  'TEMP/PERM DISABILITY RETIRED LIST (120 DAYS OR LESS)' nan
#  'RETIRED/SEPARATED 120 DAYS OR LESS (NOT T/PDRL)']
# TOTAL 7
# ------------------------------------------
# These are the all the values in Member Name
# ['AADLAND GERALD L' 'AALUND JAMES DOWNING' 'AAMOLD DANIEL LAWRENCE' ...
#  'ZYPH JAMES LOUIS' 'ZYWICA GARY ROMAN' 'ZYWICKE DAVID LEE']
# TOTAL 57933
# ------------------------------------------
# These are the all the values in S
# ['A' 'F' 'M' 'N' 'C']
# TOTAL 5
# ------------------------------------------
# These are the all the values in Service Name
# ['ARMY' 'AIR FORCE' 'MARINE CORPS' 'NAVY' 'COAST GUARD']
# TOTAL 5
# ------------------------------------------
# These are the all the values in Rank Rate
# ['SP4' 'SGT' 'A1C' 'LCPL' 'PFC' 'PVT' 'CPT' 'CPL' 'SP5' 'SFC' 'SP6' 'CAPT'
#  '1STLT' 'MAJ' '1LT' 'SSG' 'LT' 'COL' 'WO1' 'SN' 'MSGT' 'CW2' 'SA' 'PO1'
#  'SSGT' 'HN' 'GYSGT' 'SMSGT' 'PO3' 'BG' 'FN' 'PO2' 'CW3' '2LT' 'TSGT'
#  'CMSGT' 'MSG' 'LTC' 'PSG' '2NDLT' 'LCDR' 'LTJG' 'LTCOL' 'SR' 'CPO' 'CDR'
#  'SGM' 'CW4' '1STSGT' 'AN' 'A2C' 'SCPO' 'CN' 'WO' 'SGTMAJ' 'ENS' '1SG'
#  'MGYSGT' 'AMN' 'CWO2' 'MCPO' 'HA' 'AA' 'BGEN' 'MG' 'FA' 'MAJGEN' 'CWO4'
#  'CWO3' 'CWO-4' 'WO-1' 'SPC' 'A3C' 'PV1' 'CR' 'RADM' 'CADET']
# TOTAL 77
# ------------------------------------------
# These are the all the values in PG
# ['E04' 'E05' 'E03' 'E01' 'O03' 'E02' 'E06' 'O06' 'O02' 'O04' 'E07' 'W01'
#  'W02' 'E08' 'W03' 'O01' 'E09' 'O05' 'W04' 'O07' 'O08']
# TOTAL 21
# ------------------------------------------
# These are the all the values in Occ
# ['11B' '      ' '0311' ... '1545' '5541' '1051B']
# TOTAL 1393
# ------------------------------------------
# These are the all the values in Occupation Name
# ['INFANTRYMAN' nan 'RIFLEMAN' 'ARMOR RECONNAISSANCE SPECIALIST'
#  'INTERNIST' 'CONSTRUCTION AND UTILITIES WORKER' 'AMMUNITION TECHNICIAN'
#  'CONSTRUCTION EQUIPMENT REPAIRER' 'MEDICAL SPECIALIST'
#  'UTILITY HELICOPTER REPAIRER' 'FIELD ARTILLERY BASIC' 'MACHINEGUNNER'
#  'CID SPECIAL AGENT' 'URL PILOT' 'INFANTRY OFFICER (I)'
#  'MEDICAL EQUIPMENT REPAIRER' 'AIR OBSERVATION PILOT' 'ASSAULTMAN'
#  'FIXED STATION ATTENDANT' 'FIRE SUPPORT SPECIALIST'
#  'HELICOPTER PILOT, UTILITY AND LIGHT CARGO SINGLE ROTOR'
#  'ORDNANCE OFFICER' 'TANK UNIT COMMANDER' 'CHAPLAIN ASSISTANT'
#  'ARMOR CREWMAN' 'ARMORED RECONNAISSANCE UNIT COMMANDER'
#  'PERSONNEL SPECIALIST' 'HEAVY ANTI-ARMOR WEAPONS INFANTRYMAN' 'MORTARMAN'
#  'RANGER, COMBAT ENGINEER UNIT COMMANDER'
#  'COLONEL, NAVAL AVIATOR/NAVAL FLIGHT OFFICER' 'CANNON CREWMEMBER'
#  'RADIO TELETYPE OPERATOR' 'ATTACK HELICOPTER PILOT'
#  'EXECUTIVE ADMINISTRATIVE ASSISTANT' 'INFANTRY UNIT COMMANDER' 'SEAMAN'
#  'LIGHT WHEEL VEHICLE MECHANIC' 'HEAVY VEHICLE DRIVER'
#  'GENERAL VEHICLE REPAIRMAN' 'CENTRAL OFFICE SWITCHBOARD OPERATOR'
#  'MILITARY POLICE' 'INFANTRY OPERATIONS AND INTELLIGENCE SPECIALIST'
#  'CANNON FIRE DIRECTION SPECIALIST' 'TRACK VEHICLE REPAIRER'
#  'COMBAT ENGINEER' 'FIELD COMMUNICATIONS ELECTRONICS EQUIPMENT MECHANIC'
#  'AIRCRAFT POWERTRAIN REPAIRER' "STEWARD'S MATE"
#  'AIRCRAFT MAINTENANCE APPRENTICE' 'HOSPITAL CORPSMAN'
#  'INDIRECT FIRE INFANTRYMAN' 'INFANTRY UNIT LEADER'
#  'FIELD ARTILLERY SURVEYOR' 'WEAPONS MAINTENANCE TECHNICIAN'
#  'LIGHT VEHICLE DRIVER' 'PILOT' 'ADMINISTRATIVE MAN'
#  'ASSAULT AMPHIBIOUS VEHICLE CREWMAN' 'BUILDER' 'UNIT SUPPLY SPECIALIST'
#  'ENGINEER EQUIPMENT MECHANIC' 'COMBAT ENGINEER UNIT COMMANDER'
#  'LIGHT AIR DEFENSE ARTILLERY CREWMEMBER' 'FIREMAN' 'STEELWORKER'
#  'MULTICHANNEL TRANSMISSION SYSTEMS'
#  'UTILITY/OBSERVATION HELICOPTER PILOT' 'ADMINISTRATIVE SPECIALIST'
#  'MULTI-ENGINE AIRPLANE REPAIRMAN' 'PARACHUTIST, INFANTRY UNIT COMMANDER'
#  'RANGER, ARMORED RECONNAISSANCE UNIT COMMANDER'
#  'AVIATION ORDNANCE TRAINEE' 'TACTICAL COMMUNITIONS CHIEF'
#  'PETROLEUM SUPPLY SPECIALIST' 'BRIDGE CREWMEMBER' 'FIELD RADIO OPERATOR'
#  'MECHANICAL SUPERINTENDENT' 'TEXTILE REPAIRMAN' 'INTELLIGENCE ANALYST'
#  'FIELD ARTILLERY CANNONEER' 'MEDIUM HELICOPTER REPAIRER' 'CLERK-TYPIST'
#  'TACTICAL WIRE OPERATIONS SPECIALIST' 'FOOD SERVICE HELPER'
#  'AIRCREW SURVIVAL EQUIPMENTMAN' "BOATSWAIN'S MATE"
#  'COMMUNICATIONS CENTER SPECIALIST' 'AIRCRAFT ARMAMENT REPAIRMAN'
#  'CORRECTIONS SPECIALIST' 'FIRE CONTROL TECHNICIAN (GUN FIRE CONTROL)'
#  "ELECTRICIAN'S MATE" 'MOTOR VEHICLE OPERATOR'
#  'AIRCRAFT LOADMASTER TECHNICIAN' 'BASIC INFANTRY OFFICER'
#  'AMMUNITION SUPPLY OFFICER' 'FOOD SERVICE SPECIALIST'
#  'FIXED WING AVIATION UNIT COMMANDER' 'FLIGHT OPERATIONS COORDINATOR'
#  'POWER GENERATION EQUIPMENT OPERATOR/MECHANIC' '0V-1 AIRPLANE REPAIRMAN'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, TANK UNIT COMMANDER'
#  'A/C COMMUNICATIONS/NAVIGATION SYSTEMS TECHNICIAN'
#  'AIRCRAFT MAINTENANCE SUPERINTENDENT' 'GENERAL SUPPLY SPECIALIST'
#  'OPERATIONS AND TRAINING STAFF OFFICER (G3,A3,S3)' "MACHINIST'S MATE"
#  'SUPPLY CORPS' 'NAVIGATOR'
#  'AIRBORNE ELECTRONIC COUNTERMEASURES/RECONNAISSANCE OFFICER' 'WIREMAN'
#  'ENGINEMAN' 'BULK FUEL SPECIALIST' 'DENTAL OFFICER'
#  'PILOT CH-46 QUALIFIED' 'PIONEER' 'LDO' 'OPERATING ROOM NURSE' 'WELDER'
#  'REFRIGERATION SPECIALIST' 'GRADER OPERATOR'
#  'AIRCRAFT QUALITY CONTROL SUPERVISOR'
#  'TUBINE ENGINE DRIVE/GENERATOR REPAIRER' 'FIXED WING PILOT, MULTI-ENGINE'
#  'TECHNICAL DRAFTING SPECIALIST' 'FORWARD AIR CONTROLLER'
#  'FIELD ARTILLERY FIRE CONTROL MAN'
#  'OBSERVATION/SCOUT HELICOPTER REPAIRER'
#  'MECHANICAL MAINTENANCE SUPERVISOR' 'FIELD ARTILLERY UNIT COMMANDER'
#  'WIRE SYSTEMS INSTALLER' 'PILOT HMH/M/L/A UH-1N QUALIFIED (I)'
#  'RADIO OPERATOR' 'TELECOMMUNICATIONS OPERATOR-MAINTAINER' 'PILOT VMGR'
#  'LOGISTICS/EMBARKATION SPECIALIST' 'AMMUNITION RECORDS CLERK'
#  'TANK/ASSAULT GUIDED MISSILE MAN' 'PILOT VMA A-4 QUALIFIED (I)'
#  'STEVEDORE' 'AVIONICS MECHANIC' 'AVIATION ELECTRONICS TECHNICIAN'
#  'WATER TREATMENT SPECIALIST' 'URL NO WARFARE SPECIALTY'
#  'COMMUNICATIONS ELECTRONICS MATERIEL SUPPLY SPECIALIST'
#  'BASIC ENGINEER, CONSTRUCTION, AND EQUIPMENT OFF (I)' 'PARACHUTIST'
#  'OH-13/OH-23 HELICOPTER REPAIRMAN' "AVIATION MACHINIST'S MATE"
#  'SMALL ARMS/ARTILLERY REPAIRER' 'QUARTERMASTER' 'TANK OFFICER (I)'
#  'AEROSCOUT OBSERVER'
#  'ELECTRONIC WARFARE/SIGNAL INTELLIGENCE VOICE INTERCEPTOR'
#  'SPECIAL PURPOSE MATERIEL SUPPLY SPECIALIST'
#  'PILOT CH-53 A/D QUALIFIED (I)' 'CRANE OPERATOR' 'AUTOMOTIVE MECHANIC'
#  'AIRCRAFT ELECTRONIC SYSTEMS TECHNICIAN A-4/TA-4/OA-4'
#  'CARGO HELICOPTER PILOT' 'ENGINEER EQUIPMENT ASSISTANT' 'WAREHOUSE CLERK'
#  'SIGNAL SUPPLY AND PARTS SPECIALIST' 'PILOT VMF'
#  'CH-34 HELICOPTER REPAIRMAN' 'WATERCRAFT ENGINEER'
#  'JUDGE ADVOCATE OR JUDGE ADVOCATE GENERAL'
#  'TRACKED VEHICLE REPAIRER, SELF-PROPELLED' 'INTELLIGENCE SPECIALIST'
#  "GUNNER'S MATE (GUNS)" 'SHORE PARTY SPECIALIST'
#  "AVIATION ELECTRICIAN'S MATE" 'UH-60 HELICOPTER REPAIRER'
#  'FLEET SATCOM TERMINAL OPERATOR' 'FIELD ILLUMINATION CREWMAN'
#  'AIR OPERATIONS OFFICER' 'COMMAND SERGEANT MAJOR'
#  'HEAVY CONSTRUCTION EQUIPMENT OPERATOR'
#  'PILOT VMA (AW) (I), FRS BASIC A-6' 'AIRCRAFT STRUCTURAL REPAIRER'
#  'REPAIR SHOP TECHNICIAN'
#  'RANGER, OPERATIONS AND TRAINING STAFF OFFICER (G3,A3,S3)'
#  'FREIGHT OPERATIONS CLERK' 'RADIO OPERATOR-MAINTAINER' 'PRINT JOURNALIST'
#  'O-1/U-6 AIRPLANE REPAIRMAN' 'AVIATION ORDNANCEMAN'
#  'CONSTRUCTION ELECTRICIAN' 'M60A1 TANK CREWMAN'
#  'COMBAT ENGINEER OPERATION AND INTELLIGENCE NCO'
#  'GROUND MOBILE FORCES SATCOM RADIO CHIEF'
#  'EXPLOSIVE ORDNANCE DISPOSAL SPECIALIST' 'COMMISSARYMAN'
#  'QUALIFIED A-6E BOMBARDIER/NAVIGATOR (I)' 'EQUIPMENT OPERATOR'
#  'RADIO TELEGRAPH OPERATOR' 'COMMUNICATIONS OFFICER (I)' 'PILOT HMH'
#  'FIRE CONTROL INSTRUMENT REPAIRER' 'CHEMICAL EQUIPMENT REPAIRER'
#  'SMALL ARMS REPAIRER/TECHNICIAN' 'WATERCRAFT OPERATOR'
#  'PETROLEUM STORAGE SPECIALIST' 'NUCLEAR WEAPONS SPECIALIST'
#  'AIRCRAFT PNEUDRAULICS REPAIRER'
#  'SINGLE-ENGINE AIRPLANE MAINTENANCE CHIEF'
#  'MATERIEL CONTROL AND ACCOUNTING SPECIALIST'
#  'INTELLIGENCE STAFF OFFICER (G2,A2,S2)' 'AIRPLANE TECHNICAL INSPECTOR'
#  'PARACHUTE RIGGER' 'AIRCRAFT AIRFRAME MECHANIC AV-8/TAV-8'
#  'NAVIGATOR, TANKER' 'MEDICAL CORPS' 'ENGINEER EQUIPMENT OPERATOR'
#  'AIRCRAFT MAINTENANCE SENIOR SERGEANT'
#  'AIRCRAFT COMM/NAV/RADAR SYSTEMS TECH, EA-6' 'RAILWAY SECTION FOREMAN'
#  'ENGINEER MISSILE EQUIPMENT SPECIALIST' 'INTELLIGENCE ASSISTANT'
#  'FIREFIGHTER' 'AIRCRAFT MAINTENANCE OFFICER' 'DUTY SOLDIER'
#  'MACHINERY REPAIRMAN' 'CONSTRUCTION ENGINEER'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, FA UNIT COMMANDER'
#  'AIR OPERATIONS OFFICER (G3, S3)' 'RADIOMAN'
#  'WIRE SYSTEMS EQUIPMENT REPAIRER' 'CONSTRUCTION EQUIPMENT SUPERVISOR'
#  'MILITARY POLICE OFFICER' 'QUARRYING SPECIALIST'
#  'ROUGH TERRAIN FORKLIFT AND LOADER OPERATOR' 'FIELD RADIO REPAIRER'
#  'NAVIGATOR, ELECTRONIC WARFARE OFFICER'
#  'PSYCHOLOGICAL OPERATIONS OFFICER'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, INFANTRY UNIT COMMANDER'
#  'AIR TRAFFIC CONTROL TOWER OPERATOR' 'INFANTRY SENIOR SERGEANT'
#  'AMMUNITION SPECIALIST' 'LOGISTICS OPERATIONS CLERK' 'PLUMBER'
#  'SUPPORT EQUIPMENT ASSET MANAGER' 'TELETYPWRITER REPAIRER'
#  'ADVANCED AVIONICS TECHNICIAN-TRAINEE'
#  'AIRCRAFT COMMUNICATIONS/NAVIGATION/ELECTRICAL/WEAPON SYSTEMS  TECHNICIAN - TRAIN'
#  'REDSTONE ELECTRONIC MECHANIC' 'TOWED ARTILLERY SYSTEMS TECHNICIAN'
#  'ATOMIC DEMOLITION EMPLOYMENT TECHNICIAN' 'DENTAL TECHNICIAN' 'CHAPLAIN'
#  'VEHICLE MATERIEL SUPPLY SPECIALIST'
#  'TACTICAL ELECTRONICS MAINTENANCE CHIEF' 'STILL PHOTOGRAPHIC SPECIALIST'
#  'BASIC INFANTRYMAN' 'COOK' "PHOTOGRAPHER'S MATE"
#  'MECHANICAL MAINTENANCE HELPER' 'GROUND RADAR REPAIRMAN'
#  'PARACHUTIST, FA UNIT COMMANDER' 'CLERK'
#  'CARPENTRY AND MASONRY SPECIALIST' 'HELICOPTER MECHANIC, CH-46'
#  'WHEELED TRACTOR OPERATOR' 'PILOT VME (JET)'
#  'DATA/COMMUNICATIONS MAINTENANCE OFFICER (III)'
#  'MOTOR TRANSPORT OPERATOR' 'SUPPLYMAN' 'AH-1 ATTACK HELICOPTER REPAIRER'
#  'SUPPLY ADMINISTRATIVE MAN - MANUAL ACCOUNTING'
#  'EXPLOSIVE ORDNANCE DISPOSAL TECHNICIAN'
#  'PLUMBING AND WATER SUPPLY SPECIALIST' 'AIDE-DE-CAMP'
#  'AVIATION STRUCTURAL MECH (SAFETY EQUIP)' 'POSTAL CLERK'
#  'WEAPON SYSTEMS OFFICER' 'CHEMICAL COMBAT SERVICE SUPPORT OFFICER'
#  'TACTICAL MICROWAVE SYSTEMS REPAIRER'
#  'TRANSPORTATION SUPPLY AND PARTS SPECIALIST'
#  'AVIATION PRECISION MEASUREMENT EQUIPMENT (PME) CHIEF'
#  'LANCE CREWMEMBER/MLRS SERGEANT' 'GROUND RADIO REPAIRER'
#  'COMBAT ENGINEER SENIOR SERGEANT' 'FIELD ARTILLERY RADAR CREWMEMBER'
#  'SINGLE-ENGINE SINGLE-ROTOR HELICOPTER REPAIRMAN'
#  'SUPPLY MAN, MANUAL ACCOUNT' 'BASIC FIELD ARTILLERY OFFICER (I)'
#  'AVIATION STRUCTURAL MECHANIC (HYDRAULICS)' 'FRS BASIC CH-46 PILOT (I)'
#  'IMAGERY ANALYST' 'FIRE CONTROL REPAIRER' 'SIGNALMAN'
#  'HEAVY LIFT HELICOPTER PILOT' 'CANVAS AND LEATHER REPAIRMAN'
#  'PILOT VMFA F-4S (I)' 'FIELD ARTILLERY OFFICER (I)'
#  'PERSONAL FINANCIAL RECORDS CLERK'
#  'RANGER, INTELLIGENCE STAFF OFFICER (G2,A2,S2)'
#  'ARTILLERY SCOUT OBSERVER'
#  'AIRCRAFT ELECTRICAL SYSTEMS TECHNICIAN, TRANSPORT AND HELICOPTER'
#  'COMMUNICATION CENTER OPERATOR' 'AIRCRAFT MATERIEL SUPPLY SPECIALIST'
#  'CONSTRUCTION ENGINEERING SUPERVISOR' 'HURCULES FIRE CONTROL CREWMEMBER'
#  'AIRCRAFT CRYPTOGRAPHIC SYSTEMS TECHNICIAN, IMA'
#  'ORDNANCE SUPPLY AND PART SPECIALIST' 'ARTILLERY COMMUNICATIONS CHIEF'
#  'TRACKED VEHICLE REPAIRER, ASSAULT AMPHIBIOUS VEHICLE' 'CONSTRUCTIONMAN'
#  'ARMORED AMPHIBIAN CREWMAN' 'EW/SIGINT IDENTIFIER' 'AIRMAN'
#  'TRANSLATOR-INTERPRETER' 'CONCRETE AND ASPHALT EQUIPMENT OPERATOR'
#  'MEDICAL LABORATORY SPECIALIST'
#  'FRS BASIC EA-6A/B ELECTRONIC WARFARE OFFICER (I)'
#  'AVIATION FIRE CONTROL TECHNICIAN' 'URL NAVAL FLIGHT OFFICER'
#  'VULCAN CREWMEMBER' 'NUCLEAR, BIOLOGICAL, AND CHEMICAL (NBC) SPECIALIST'
#  'INTERROGATOR' 'FLIGHT TRAINING INSTRUCTOR'
#  'RANGER, UNIT OFFICER, TRAINING CENTER' 'CONSTRUCTION MECHANIC'
#  'QUARTERMASTER HEAVY EQUIPMENT REPAIRMAN'
#  'ELECTRONICS TECHNICIAN (SUBMARINE)' 'NAVIGATOR-BOMBARDIER'
#  'FINANCE SPECIALIST' 'MATERIEL STORAGE AND HANDLING SPECIALIST'
#  'AVIATION STRUCTURAL MECH (STRUCTURES)' 'METAL WORKER' 'ELECTRICIAN'
#  'AIRCRAFT COMMUNICATION./NAVIGATION SYSTEMS TECHNICIAN'
#  'WEAPONS SUPPORT RADAR REPAIRER' 'FRS BASIC F/A-18 PILOT (I)'
#  'COMPTROLLER' 'QUARTERMASTER SUPPLY SPECIALIST'
#  'INTERROGATION/TRANSLATION SPECIALIST' 'INTELLIGENCE OFFICER'
#  'GENERAL OFFICER' 'STOREKEEPER' 'AVIATION STAFF OFFICER'
#  'COMPOSITE AVIATION UNIT COMMANDER' 'TRAFFIC MANAGEMENT COORDINATOR'
#  'U/A AIRPLANE REPAIRMAN' 'FIXED WING PILOT, SURVEILLANCE AIRCRAFT'
#  'RANGER, INFANTRY UNIT COMMANDER'
#  'AIR TRAFFIC CONTROLLER RADAR CONTROLLER' 'ELECTRONIC WARFARE OFFICER'
#  'INTERIOR COMM ELECTRICIAN' 'REFRIGERATION MECHANIC'
#  'AIRCRAFT RECOVERY SPECIALIST' 'SENIOR SUPPLY/SERVICE SERGEANT'
#  'AIRCRAFT ROTOR AND PROPELLER REPAIRMAN'
#  'AIRCRAFT RECIPROCATING ENGINE REPAIRMAN' 'AVIATION SUPPORT EQPT TECH'
#  'PROCUREMENT SERGEANT' 'HULL MAINTENANCE TECHNICIAN' 'AIR DELIVERY MAN'
#  'MEDICAL SENIOR SERGEANT' 'AUTOMOTIVE MAINTENANCE TECHNICIAN'
#  'MULTICHANNEL EQUIPMENT OPERATOR'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, INTELLIGENCE STAFF OFFICER (G2,A2,S2)'
#  'TRAINING OFFICER' 'CHAPLAIN CORPS' 'F-4S RADAR INTERCEPT OFFICER (I)'
#  'AERIAL SURVEILLANCE OFFICER' 'AIRCRAFT ELECTRICIAN'
#  'MEDICAL SUPPLY SPECIALIST' 'LAUNDRY AND BATH SPECIALIST'
#  'DISBURSING CLERK' 'RADARMAN'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, AIR OPERATIONS OFFICER (G3, S3)'
#  'SUPPLY & EVAC STAFF OFFICER (G4,A4,S4)'
#  'GENERAL CONSTRUCTION EQUIPMENT OPERATOR' 'BASIC SUPPLY SERVICES MAN'
#  'BOILERMAN' 'PHOTOGRAPHER' 'MARINE HULL REPAIRMAN'
#  'HAWK FIRE CONTROL CREWMEMBER' 'FIXED STATION TRANSMITTER REPAIRMAN'
#  'CARGO SPECIALIST' 'GENERAL WAREHOUSEMAN'
#  'PERSONNEL MANAGEMENT SPECIALIST' "SHIP'S SERVICEMAN"
#  'AIR TRAFFIC CONTROL CHIEF' 'AIRCRAFT POWER PLANTS MECHANIC, J-79'
#  'FIXED WING PILOT, SINGLE ENGINE' 'AIR COMMANDER'
#  'SPECIAL FORCES, OPERATIONS AND TRAINING STAFF OFFICER (G3,A3,S3)'
#  'RECOVERY SPECIALIST' 'RANGER' 'AVIATION ASW TECHNICIAN' 'UTILITIESMAN'
#  'TRANSPORTATION OFFICER' 'ATOMIC DEMOLITION MUNITIONS SPECIALIST'
#  'RANGER, TANK UNIT COMMANDER' 'SUPPLY HANDLER'
#  'PERSONNEL STAFF OFFICER (G1,A1,S1)' 'PERSONNELMAN'
#  'AIRCRAFT MAINTENANCE GSE REFRIGERATION MECHANIC' 'ADPS REPAIRMAN'
#  'DAIL/MANUAL CENTRAL OFFICE REPAIRER'
#  'AIRCRAFT COMMUNICATIONS/NAVIGATION SYSTEM'
#  'AVIONIC COMMUNICATIONS EQUIPMENT REPAIRER'
#  'GROUND SUPPLY OPERATIONS OFFICER (III)'
#  'AIRCRAFT COMM/NAV/ELEC SYST TECH, CH-46'
#  'DATA PROCESSING EQUIPMENT OPERATOR' 'METAL WORKING FOREMAN'
#  'SATELLITE COMMUNICATIONS SYSTEMS OPERATOR-MAINTAINER' 'SAXOPHONE PLAYER'
#  'POWERMAN' 'GROUND SURVEILLANCE RADAR CREWMAN'
#  'OPERATING ROOM SPECIALIST' 'ENGINEER OFFICER (I)'
#  'ELECTRONIC WARFARE CRYPTOLOGIC STAFF OFFICER' 'PRACTICAL NURSE'
#  'PHOTOGRAPHIC INSTRUMENTATION TECHNICIAN'
#  'CHEMICAL SUPPLY AND PARTS SPECIALIST' 'AMMUNITION HELPER'
#  'M1A1 ABRAMS TANK TURRET MECHANIC'
#  'ULS CENTRAL OFFICE OPERATOR/MAINTAINER'
#  'MULTI-ENGINE MEDIUM TRANSPORT AIRPLANE MECHANIC' 'PHARMACY SPECIALIST'
#  'GROUND SUPPLY OFFICER (I)' 'FIELD ARTILLERY SENIOR SERGEANT'
#  'COMMUNICATIONS SYSTEM CIRCUIT CONTROLLER' "GUNNER'S MATE (MISSILES)"
#  'LEGAL SPECIALIST' 'DENTAL SPECIALIST' 'FOOD SERVICE SUPERVISOR'
#  'FLIGHT STUDENT (TBS)' 'CORRECTIONAL SPECIALIST' 'DAMAGE CONTROLMAN'
#  'AIRBORNE RADIO AND FLIGHT INSPECTION TECHNICIAN'
#  'HELICOPTER PILOT, MEDIUM TRANSPORT' 'PHOTOGRAPHIC LABORATORY SPECIALIST'
#  'PILOT VMF/VMF(AW)F-8D/E' 'HEAVY LIFT HELICOPTER REPAIRER'
#  'PILOT VME (PROP)' 'ANTENNA INSTALLER SPECIALIST'
#  'ASSAULT AMPHIBIOUS VEHICLE (AAV) REPAIRER/TECHNICIAN'
#  'ASPHALT EQUIPMENT OPERATOR' 'AIRBORNE RADIO OPERATOR'
#  'LIGHT AIR DEFENSE ARTILLERY UNIT COMMANDER'
#  'SELF-PROPELLED FIELD ARTILLERY REPAIRER'
#  'RADIO AND COMMUNICATIONS SECURITY REPAIRER'
#  'ASSAULT AMPHIBIOUS VEHICLE (AAV) OFFICER (I)' 'SIGNAL SECURITY OFFICER'
#  'YEOMAN' 'PATIENT ADMINISTRATION SPECIALIST' 'SUPPLY OFFICER, GENERAL'
#  'PREVENTIVE MEDICINE SPECIALIST' 'MUNITIONS OFFICER'
#  'SUPPLY MANAGEMENT OFFICER' 'URL SURFACE WARFARE'
#  'AIRCRAFT POWERPLANT REPAIRER' 'BAKER' 'TELEPHONE & TELEGRAPH OFFICER'
#  'EXPLOSIVE ORDNANCE DISPOSAL OFFICER' 'LAUNDRY MACHINE OPERATOR' 'MATE'
#  'BASIC TANK AND ASSAULT AMPHIBIOUS VEHICLE OFFICER (I)'
#  'MECHANIZED CAVALRY UNIT COMMANDER' 'ARMAMENT REPAIRER'
#  'SHORE FIRE CONTROL PARTY MAN' 'ARTILLERY MECHANIC'
#  'CIVIL ENGINEER CORPS' 'AIRCRAFT RADAR ATTACK SYSTEMS TECHNICIAN, A6'
#  'CABLE SPLICER' 'PERSONNEL/ADMINISTRATIVE TECHNICIAN'
#  'AIRCRAFT REPAIR TECHNICIAN, ROTARY WING RATED'
#  'HELICOPTER MECHANIC, CH-53' 'TERMINAL RECEIVING SYSTEM REPAIRMAN'
#  'PILOT VMAQ/EA-6A (I)' 'AH-64 ATTACK HELICOPTER REPAIRER'
#  "AVIATION BOATSWAIN'S MATE (FUELS)"
#  'SPECIAL FORCES, AIR OPERATIONS OFFICER (G3, S3)'
#  'FILM LIBRARY SPECIALIST' 'AIRCRAFT FIREFIGHTING AND RESCUE SPECIALIST'
#  'TEXTILE AND LEATHER REPAIR ASSISTANT' 'UNIT DIARY CLERK'
#  'MOTION PICTURE SPECIALIST'
#  'COMBAT SURVEILLANCE AND TARGET ACQUISITION CREWMAN'
#  'FLIGHT ENGINEER TECHNICIAN' 'INTERROGATION-TRANSLATION OFFICER'
#  'AREA INTELLIGENCE TECHNICIAN' 'COMBAT SIGNAL UNIT COMMANDER'
#  'EW/SIGINT MORSE INTERCEPTOR' 'QUARTERMASTER SUPPLY OFFICER'
#  'SHOE REPAIRMAN' 'MORTUARY AFFAIRS SPECIALIST' 'RADIO TECHNICIAN'
#  'MAP COMPILER' 'CARDIAC SPECIALIST'
#  'AIRCRAFT ELECTRICAL SYSTEMS TECHNICIAN, TA4/A4/F8/F4/RF4'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, OPERATIONS AND TRAINING STAFF OFFICER (G3,A3,S3)'
#  'ELECTRICAL-ELECTRONIC ENGINEERING ASSISTANT' 'AERIAL SENSOR SPECIALIST'
#  'MEDICAL OFFICER, GENERAL' 'DRILL INSTRUCTOR'
#  'AIRBORNE SENSOR SPECIALIST' 'MILITARY INTELLIGENCE OFFICER'
#  'M1 ABRAMS TANK SYSTEM MECHANIC' 'INVENTORY MANAGEMENT SUPERVISOR'
#  'POSTAL OFFICER' 'CIVIL AFFAIRS OFFICER (G5, S5)'
#  'GEN SV ENGINEER UNIT COMMANDER' 'COMMUNICATIONS CENTER OFFICER'
#  'ELECTRO-OPTICAL ORDNANCE REPAIRER' 'AVIONICS MAINTENANCE CHIEF'
#  'FLIGHT ENGINEER SPECIALIST' 'NUCLEAR POWER PLANT CHIEF'
#  'BASIC ENGINEER, CONSTRUCTION, AND EQUIPMENT MARINE'
#  'SUBSISTENCE OFFICER' 'BEHAVIORAL SCIENCE SPECIALIST'
#  'AIRCRAFT MECHANIC RECIPROCATING' 'BASIC MOTOR TRANSPORT OFFICER (I)'
#  'URL SPECIAL WARFARE' 'ANIMAL CARE SPECIALIST' 'SPECIAL RADIO OPERATOR'
#  'WATCH REPAIRMAN' 'TOPOGRAPHIC SURVEYOR'
#  'MANUAL CENTRAL OFFICE REPAIRMAN' 'WEAPONS MAINTENANCE SUPERINTENDENT'
#  'PARACHUTIST, TANK UNIT COMMANDER' 'JOURNALIST'
#  'PATRIOT FIRE CONTROL ENHANCED OPERATOR/MAINTAINER'
#  'COMMUNICATIONS-ELECTRONICS MAINTENANCE CHIEF'
#  'FLIGHT ENGINEER SUPERINTENDENT' 'PIPELINE SPECIALIST'
#  'SUPPLY ADMINISTRATIVE MAN - MECHANIZED ACCOUNTING'
#  'BASIC OPERATIONAL COMMUNICATOR'
#  'DEFENSE ACQUISITION AND SURVIVAL RADAR CREWMAN'
#  'ORDNANCE VEHICLE MAINTENANCE CHIEF' 'MEAT CUTTER' 'COLONEL, GROUND'
#  'AIRCRAFT FIRE PROTECTION AND RECOVERY OFFICER (III)'
#  'AMMUNITION MAINTENANCE SPECIALIST' 'MASON' 'SERGEANT MISSILE CREWMAN'
#  'TANK MAINTENANCE & REPAIR OFFICER' 'FIELD ARTILLERY REPAIRMAN'
#  'MACHINIST' 'ECM/DF SYSTEMS REPAIRMAN' 'COUNTERINTELLIGENCE ANALYST'
#  'PROCUREMENT OFFICER' "AV BOATSWAIN'S MATE (ACFT HANDLING)"
#  'CONSTRUCTION DRAFTER' 'BRASS GROUP LEADER'
#  'INVENTORY MANAGEMENT SUPERINTENDENT' 'EW/CRYPTANLYTIC CRYPTANALYST'
#  'SELF-PROPELLED ARTILLERY (SPARTY) REPAIRER/TECHNICIAN'
#  'ADJUTANT OR ADJUTANT GENERAL'
#  'LAND COMBAT SUPPORT SYSTEM TEST SPECIALIST' 'DRILL SERGEANT'
#  'BOMB DISPOSAL OFFICER' 'EQUIPMENT MAINTENANCE CLERK'
#  'STRUCTURE SPECIALIST' 'PORTABLE BRIDGE UNIT COMMANDER'
#  'AIR TRAFFIC CONTROL OFFICER, AUTOMATED SYSTEMS' 'PROVOST MARSHAL'
#  'INFORMATION SYSTEMS OPERATOR-ANALYST' 'REDSTONE MISSILE MECHANIC'
#  'SUBSISTENCE SUPPLY SPECIALIST'
#  'NETWORK SWITCHING SYSTEMS OPERATOR-MAINTAINER'
#  'FIELD ARTILLERY ROCKET CREWMAN' 'GENERAL SURGEON'
#  'EXPLOSIVE ORDNANCE DISPOSAL TECHNICIAN (CONVENTIONAL WEAPONS)'
#  "AVIATION BOATSWAIN'S MATE (LAUNCH/RECOVERY EQ)"
#  'SERGEANT GUIDANCE REPAIRMAN'
#  'TARGET ACQUISITION SURVEILLANCE RADAR REPAIRER'
#  'AIRCRAFT MAINTENANCEMAN' 'PIANO PLAYER' "TORPEDOMAN'S MATE"
#  'AVIATION RADIO REPAIRMAN' 'PARACHUTIST, COMBAT ENGINEER UNIT COMMANDER'
#  'FLASH RANGING CREWMAN'
#  'PERSONAL COMPUTER (PC)/TACTICAL OFFICE MACHINE REPAIRER'
#  'MOTOR TRANSPORT OPERATIONS CHIEF' 'HEMATOLOGIST' 'WEAPONS DISTRIBUTION'
#  'PARACHUTIST, CIVIL AFFAIRS OFFICER (G5, S5)' 'COMMUNICATIONS TECHNICIAN'
#  'QUALIFIED EA-6A ELECTRONIC WARFARE OFFICER (I)'
#  'SPECIAL FORCES, FA UNIT COMMANDER' 'TELEPHONE TECHNICIAN'
#  'SPECIAL SERVICES OFFICER' 'COMMUNICATIONS OFFICER' 'RANGE COACH'
#  'SPECIAL BANDMEMBER' 'MILITARY INTELLIGENCE COORDINATOR'
#  'POWER GENERATION EQUIPMENT REPAIRER'
#  'PERSHING ELECTRONICS MATERIEL SPECIALIST' 'SIGNAL SECURITY SPECIALIST'
#  'HELICOPTER PILOT, UTILITY AND LIGHT CARGO TANDEM ROTOR'
#  'HELICOPTER MECHANIC, U/AH-1' 'PAY RECORDS SPECIALIST' 'DOG TRAINER'
#  'RADIO SYSTEMS OFFICER' 'PILOT HMH/M/L/A  AH-1 QUALIFIED (I)'
#  'ENGINEER EQUIPMENT OFFICER' 'COUNTERINTELLIGENCE SPECIALIST'
#  'ADMINISTRATIVE OFFICER' 'FOOD SERVICE TECHNICIAN'
#  'FINANCE SENIOR SERGEANT' 'AIR DEFENSE MISSILE UNIT COMMANDER'
#  'INFANTRY CANNON UNIT COMMANDER' 'HEALTH CARE ADMINISTRATOR'
#  'RANGER, PSYCHOLOGICAL OPERATIONS OFFICER'
#  'PARACHUTIST, FIXED WING AVIATION UNIT COMMANDER'
#  'UNIT OFFICER, NON-TACTICAL'
#  'QUALIFIED RF-4B AIRBORNE RECONNAISSANCE OFFICER (I)'
#  'GROUND RADIO COMMUNICATIONS TECHNICIAN'
#  'FUEL AND ELECTRICAL SYSTEMS REPAIRER' 'HELICOPTER REPAIRER (OH-58D)'
#  'PETROLEUM LABORATORY SPECIALIST' 'PARACHUTIST, INFORMATION OFFICER'
#  'BASIC ROTARY WING PILOT (I)' 'HELICOPTER TECHNICIAN'
#  'RADIO OPERATIONS SUPERINTENDENT'
#  'A/C ANALOG DISPLAY SYSTEM SACE TECHNICIAN' 'HIGHWAY TRANSPORT OFFICER'
#  'ENGINEER TRACKED VEHICLE CREWMAN' 'METEOROLOGICAL OBSERVER'
#  'AIR OPERATIONS OFFICER, PILOT, TACTICAL AIR CONTROL SYSTEM'
#  'TACTICAL TELECOMMUNICATIONS CENTER OPERATOR'
#  'FIELD ARTILLERY OPERATIONS MAN' 'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST'
#  'SINGLE-ENGINE AIRPLANE REPAIRMAN' 'SPECIAL FORCES, CHAPLAIN'
#  'NUCLEAR, BIOLOGICAL AND CHEMICAL DEFENSE SPECIALIST'
#  'PARACHUTIST, PETROLEUM PRODUCTS SUPPLY OFFICER'
#  'MARINE ENGINEERING TECHNICIAN' 'COMBAT PHOTOGRAPHER/MOTION MEDIA'
#  'ANTITANK ASSAULT GUIDED MISSILEMAN' 'PRIME POWER PRODUCTION SPECIALIST'
#  'WHEEL VEHICLE REPAIRER'
#  'AIRCRAFT COMMUNICATIONS/NAVIGATION/ELECTRICAL/WEAPON/DECM SYSTEMS TECHNICIAN A-4'
#  'DATA SYSTEMS TECHNICIAN' 'PILOT VMR (AW) MULTI PLACE'
#  'TELECOMMUNICATIONS OPERATIONS CHIEF' 'RANGER, FACILITIES ENGINEER'
#  'COUNTERINTELLIGENCE OFFICER' 'HURCULES MISSILE CREWMEMBER'
#  'ORDINANCE OFFICER, STAFF' 'SMOKE OPERATIONS SPECIALIST'
#  'KW-7 CRYPTOGRAPHIC TECHNICIAN' 'PHYSICAL ACTIVITIES SPECIALIST'
#  'FLYING SAFETY OFFICER' 'ARTILLERY METEOROLOGICAL MAN'
#  'MEDICAL ASSISTANT' 'BASIC ADMINISTRATIVE MARINE' 'DIVER'
#  'PETROLEUM PRODUCTS SUPPLY OFFICER'
#  'COMMUNICATIONS SYSTEMS/CIRCUIT CONTROLLER' 'LOCOMOTIVE REPAIRER'
#  'AUTOMATED FIRE SUPPORT SYSTEMS SPECIALIST' 'BASIC LOGISTICS MARINE'
#  'ENGINEER EQUIPMENT CHIEF' 'RECONNAISSANCE AND SURVEY OFFICER'
#  'COMPUTER SYSTEMS OPERATOR' 'PARACHUTIST, AIR OBSERVATION PILOT'
#  'MEDICAL SERVICE TECHNICIAN' 'QUARTERMASTER EQUIPMENT MAINTENANCE SENIOR'
#  'UNIT OFFICER, TRAINING CENTER' 'RANGER, AIR OPERATIONS OFFICER (G3, S3)'
#  'SPECIAL FORCES, PSYCHOLOGICAL OPERATIONS OFFICER' 'ASSISTANT ENGINEER'
#  'FABRIC REPAIR SPECIALIST' 'FIELD ARTILLERY NUCLEAR PROJECTILEMAN'
#  'DENTAL CORPS' 'INFANTRY UNIT COMMANDER (MECHANIZED)' 'AUDIT SPECIALIST'
#  'HOSPITAL FOOD SERVICE SPECIALIST'
#  'AIRCRAFT ELECTRICAL SYSTEMS TECHNICIAN' 'HEADQUARTERS COMPANY COMMANDER'
#  'UTILITY AIRPLANE REPAIRER' 'BOMBARDIER' 'PILOT VMR (AW) SINGLE PLACE'
#  'PILOT VMO/OV-10 (I)'
#  'ELECTRONIC WARFARE/INTERCEPT EQUIPMENT REPAIR TECHNICIAN'
#  'AIRFIELD COMMANDER' 'SURVEILLANCE RADAR REPAIRER' 'FLIGHT NURSE'
#  'INSTRUMENT REPAIR TECHNICIAN' 'FIELD ARTILLERY RADAR OPERATOR'
#  'PERFORMING ARTS SPECIALIST' 'HAWK MISSILE CREWMEMBER' 'CHIEF OF STAFF'
#  'CONSTRUCTION SURVEYOR' 'MEDICAL-SURGICAL NURSE' 'WIRE CHIEF'
#  'FIRE CONTROL TECHNICIAN (MISSILE FIRE CONTROL)' 'BROADCAST JOURNALIST'
#  'AIRCRAFT ELECTRICAL SYSTEMS TECHNICIAN - TRAINEE'
#  'AVIATION MAINT ADMINISTRATIONMAN' 'PHOTOGRAPHIC EQUIPMENT REPAIR CHIEF'
#  'LOGISTICS OFFICER' 'RANGER, AIR OBSERVATION PILOT'
#  'IMAGE INTERPRETATION TECHNICIAN'
#  'AIRCRAFT NAVIGATION SYS TECH, IFF/RADAR/TACAN, IMA'
#  'DEFENSIVE FIRE CONTROL SYSTEMS OPERATOR/SUPERINTENDENT'
#  'FIELD ARTILLERY TARGET ACQUISITION SPECIALIST'
#  'TELEPHONE INSTALLER-REPAIRMAN' 'DOG HANDLING OFFICER'
#  'MATERIALS QUALITY SPECIALISTS' 'PERSHING ELECTRONIC REPAIRER'
#  'WEAPONS REPAIR OFFICER' 'AIRCRAFT COMPONENTS REPAIR APPRENTICE'
#  'CRYPTOGRAPHIC CENTER SPECIALIST'
#  'PARACHUTIST, COMMUNICATIONS & ELECTRONICS STAFF OFFICER'
#  'AMPHIBIAN ENGINEER' 'FACILITIES ENGINEER' 'RADIOLOGY SPECIALIST'
#  'GENERAL SERVICE MARINE' 'HELICOPTER POWER PLANTS MECHANIC, T-64'
#  'PHOTO AND LAYOUT SPECIALIST' 'PETROLEUM ENGINEER' 'SPECIAL FORCES'
#  'EXPERT LINGUIST' 'MUSICIAN, FRENCH HORN'
#  'FIXED CRYPTOGRAPHIC EQUIPMENT REPAIRER' 'CANVAS REPAIRMAN'
#  'CHEMICAL DEMOLITIONS SPECIALIST'
#  'RAILWAY MAINTENANCE AND OPERATIONS APPRENTICE'
#  'REFRIGERATION AND AIR CONDITIONING TECH'
#  'COMMUNICATIONS & ELECTRONICS STAFF OFFICER'
#  'IMAGERY INTERPRETATION SPECIALIST' 'PILOT VMFP/RF-4B (I)'
#  'AIR OPERATIONS STAFF OFFICER, NAVIGATOR-OBSERVER'
#  'SOCIAL WORK SPECIALIST' 'AVIATION SUPPLY OFFICER'
#  'HELICOPTER MAINTENANCE CHIEF' 'HAWK MISSILE SYSTEM MECHANIC'
#  'CHILD NEUROLOGIST' 'RANGER, SUPPLY & EVAC STAFF OFFICER (G4,A4,S4)'
#  'NUCLEAR WEAPONS EMPLOYMENT SPECIALIST, FIXED WING AVIATION UNIT COMMANDER'
#  'SPECIAL FORCES, INTELLIGENCE STAFF OFFICER (G2,A2,S2)'
#  'ELECTRONICS ENGINEER' 'ARMORED ENGINEER UNIT COMMANDER'
#  'FLUTE OR PICCOLO PLAYER' 'NURSE ANESTHETIST' 'RODMAN AND TAPEMAN'
#  'UNMANNED AERIAL VEHICLE (UAV) MECHANIC' 'FIXED PLANT CARRIER REPAIRMAN'
#  'AERIAL NAVIGATOR - TRAINEE' 'LAV ASSAULTMAN' 'AIRBRAKE REPAIRER'
#  'GENERAL DRAFTSMAN' 'SIGNAL INTELLIGENCE ANALYST (LINGUIST)'
#  'MEDICAL SERVICE SPECIALIST' 'CAVALRY SCOUT'
#  'ELECTRONIC/WARFARE/AIRBORNE RECONNAISSANCE OFFICER'
#  'ARMAMENT MAINTENANCE APPRENTICE' 'INSPECTOR GENERAL'
#  'AIRCRAFT SAFETY EQUIPMENT MECHANIC, A-4/TA-4'
#  'MULTI-CHANNEL EQUIPMENT REPAIRER' 'FIRE DISTRIBUTION SYSTEMS CREWMAN'
#  'ACCOUNTING OFFICER' 'REAL ESTATE OFFICER'
#  'MISSILE AND ROCKET EXPLOSIVE SPECIALIST'
#  'AIRBORNE SURVEILLANCE RADAR REPAIRER' 'AMMUNITION SUPERVISOR'
#  'TRANSPORTATION MOVEMENTS OFFICER' 'PSYCHOLOGICAL ASSISTANT'
#  'PERSONNEL CLERK' 'PARACHUTIST, QUARTERMASTER SUPPLY OFFICER'
#  'INFORMATION OFFICER' 'GENERAL SUPPLY TECHNICIAN'
#  'NAF AUDITING OFFICER (II, III)'
#  'AERIAL CAMERA SYSTEMS TECHNICIAN, TRAINEE' 'ENTOMOLOGIST'
#  'AMPHIBIAN TRUCK OFFICER' 'MUSICIAN, CLARINET'
#  'PRINTING AND BINDERY SPECIALIST'
#  'QUARTERMASTER AND CHEMICAL EQUIPMENT REPAIRER'
#  'EAR, NOSE, AND THROAT SPECIALIST'
#  'TACTICAL SUPPORT ELECTRICAL EQUIPMENT REPAIRMAN'
#  'AREA INTELLIGENCE SPECIALIST' 'BALLISTIC MISSILE REPAIR APPRENTICE'
#  'CHEMICAL OPERATIONS SPECIALIST' 'MECHANICAL ENGINEER' 'BASIC TRAINEE'
#  'AIRCRAFT ELECTRONIC SYSTEMS TECHNICIAN CH-46'
#  'UTILITIES ENGINEERING SUPERVISOR'
#  'BASIC TANK AND ASSAULT AMPHIBIOUS VEHICLE CREWMAN'
#  'AUTOMATIC DATA TELECOMMUNICATIONS CENTER OPERATOR'
#  'ARMORED COMBAT COMMAND COMMANDER' 'AIRCRAFT ARMAMENT SUBSYSTEM MECHANIC'
#  'OFFICE MACHINE REPAIRER' 'PROVOST MARSHAL, FIELD'
#  'HELICOPTER POWER PLANTS MECHANIC, T-58' 'AIR DEFENSE CONTROL OFFICER'
#  'DATA COMMUNICATIONS TERMINAL SPECIALIST'
#  'BASIC AIR TRAFFIC CONTROL OFFICER (I)'
#  'PURCHASING AND CONTRACTING SPECIALIST' 'CWO' 'AVIATION SAFETY OFFICER'
#  'BOOKKEEPER, NONAPPROPRIATED FUNDS' 'BASIC MOTOR TRANSPORT MARINE'
#  'PILOT, OH-6' 'AIRCRAFT RADAR SYSTEMS TECHNICIAN, A-6E/'
#  'KC-130 AIRCRAFT COMMANDER (I)' 'SUPPLY RESEARCH & DEVELOPMENT OFFICER'
#  'CAST SPECIALIST' 'FIELD ARTILLERY METEOROLOGICAL CREWMEMBER'
#  'SMALL CRAFT MECHANIC' 'WEAPONS MECHANIC' 'ARMAMENT REPAIR TECHNICIAN'
#  'ENGINEERING AID' 'CHEMICAL LABORATORY SPECIALIST' 'MUSICIAN, TROMBONE'
#  'PARACHUTIST, CHEMICAL COMBAT SERVICE SUPPORT OFFICER'
#  'AIRCRAFT FIRE CONTROL REPAIRMAN' 'AVIONIC MECHANIC'
#  'ELECTRICAL ENGINEER' 'UTILITIES EQUIPMENT REPAIRER'
#  'FORWARD AREA ALERTING RADAR OPERATOR' 'MOTOR TRANSPORT OFFICER (I)'
#  'FINANCE DISBURSING OFFICER' 'STRATEGIC MICROWAVE SYSTEMS REPAIRER'
#  'GENERAL DENTIST' 'ENGINEER EQUIPMENT REPAIR TECHNICIAN'
#  'METAL WORKING ASSISTANT' 'SONAR TECHNICIAN' 'SCOUT-SNIPER'
#  'AUTOMOTIVE REPAIR TECHNICIAN' 'EW/SIGINT NON-MORSE INTERCEPTOR'
#  'MOTOR TRANSPORT OFFICER' 'TRACKED VEHICLE MAINTENANCE OFFICER'
#  'UTILITIES CHIEF' 'AIRCRAFT COMM/NAV SYSTEMS TECH, KC-130'
#  'AVIONIC EQUIPMENT MAINTENANCE SUPERVISOR'
#  'AVIATION OPERATIONS SPECIALIST' 'SPECIAL COMMUNICATION OPERATOR'
#  'AVIATION MECHANIC' 'AIRCRAFT MECHANIC, OV-10'
#  'GROUND CONTROL APPROACH RADAR REPAIRER' 'BASIC OFFICER'
#  'AIRCRAFT NAVIGATION SYSTEMS TECHNICIAN, RADAR, IMA' 'ENLISTED AIDE'
#  'M60A1/A3 TANK SYSTEM MECHANIC' 'AVIATION RADAR MAINTENANCE OFFICER'
#  'PARACHUTIST, CHAPLAIN' 'AEROSPACE RESEARCH FLIGHT TEST OFFICER'
#  'PERSHING MISSILE CREWMEMBER'
#  'PARACHUTIST, INTELLIGENCE STAFF OFFICER (G2,A2,S2)'
#  'AIRCRAFT/ARMAMENT/MISSILE SYSTEMS REPAIRER' 'AMPHIBIAN OPERATOR'
#  'CARTOGRAPHER' 'SPECIAL FORCES, TANK UNIT COMMANDER'
#  'AVIATION ENGINEER UNIT COMMANDER'
#  'BASIC SUPPLY ADMIN AND OPERATIONS OFF'
#  'PARACHUTIST, OPERATIONS AND TRAINING STAFF OFFICER (G3,A3,S3)'
#  'RADIO CHIEF' 'HELICOPTER DYNAMIC COMPONENTS MECHANIC'
#  'CARBON DIOXIDE-HYDROGEN PRODUCTION SPECIALIST'
#  'AIRCRAFT COMMUNICATIONS/NAVIGATION SYSTEMS TECHNICIAN-TRAINEE IMA'
#  'MEDICAL OFFICER, COMMAND' 'MASTER OR MATE' 'CHEMICAL OFFICER'
#  'FLIGHT EQUIPMENT MARINE' 'MUSICIAN, CORNET/TRUMPET']
# TOTAL 863
# ------------------------------------------
# These are the all the values in Birth Dt
# [19450329 19450511 19510823 ... 19370624 19360326 19341229]
# TOTAL 8619
# ------------------------------------------
# These are the all the values in G
# ['M' 'F']
# TOTAL 2
# ------------------------------------------
# These are the all the values in Hor City
# ['SISSETON' 'HOUSTON' 'MOORHEAD' ... 'GRASSY BUTTE' 'UBLY' 'ABBOTSFORD']
# TOTAL 9442
# ------------------------------------------
# These are the all the values in Hor County
# ['ROBERTS' 'HARRIS' 'CLAY' ... 'REAGAN' 'CRANE' 'HAAKON']
# TOTAL 1811
# ------------------------------------------
# These are the all the values in Hor Ctry
# ['US' 'RP' 'JA' 'SZ' 'CA' 'BR' 'IT' 'NZ' 'CS' 'PM' 'EI' 'UK' 'GM' 'MX'
#  'BF' 'FR' 'PE' 'AS' 'CO' 'JM' 'BL']
# TOTAL 21
# ------------------------------------------
# These are the all the values in Hor ST
# ['SD' 'TX' 'MN' 'WA' 'MA' 'FL' 'DC' 'PA' 'NJ' 'IL' 'NY' 'MO' 'CA' 'TN'
#  'VA' 'CO' 'IN' 'LA' 'WI' 'NH' 'ME' 'KY' 'NC' 'MD' 'NM' 'IA' 'OK' 'WV'
#  'MI' 'AL' 'OR' 'SC' 'OH' 'AR' 'UT' 'KS' 'GA' 'HI' 'PR' 'NV' nan 'AZ' 'ID'
#  'MS' 'RI' 'DE' 'NE' 'GU' 'CT' 'ND' 'WY' 'MT' 'AK' 'VT' 'VI' 'FR' 'AS'
#  'ON' 'CZ']
# TOTAL 59
# ------------------------------------------
# These are the all the values in State Prv Nm
# ['SOUTH DAKOTA' 'TEXAS' 'MINNESOTA' 'WASHINGTON' 'MASSACHUSETTS' 'FLORIDA'
#  'DISTRICT OF COLUMBIA' 'PENNSYLVANIA' 'NEW JERSEY' 'ILLINOIS' 'NEW YORK'
#  'MISSOURI' 'CALIFORNIA' 'TENNESSEE' 'VIRGINIA' 'COLORADO' 'INDIANA'
#  'LOUISIANA' 'WISCONSIN' 'NEW HAMPSHIRE' 'MAINE' 'KENTUCKY'
#  'NORTH CAROLINA' 'MARYLAND' 'NEW MEXICO' 'IOWA' 'OKLAHOMA'
#  'WEST VIRGINIA' 'MICHIGAN' 'ALABAMA' 'OREGON' 'SOUTH CAROLINA' 'OHIO'
#  'ARKANSAS' 'UTAH' 'KANSAS' 'GEORGIA' 'HAWAII' 'PUERTO RICO' 'NEVADA' nan
#  'ARIZONA' 'IDAHO' 'MISSISSIPPI' 'RHODE ISLAND' 'DELAWARE' 'NEBRASKA'
#  'GUAM' 'CONNECTICUT' 'NORTH DAKOTA' 'WYOMING' 'MONTANA' 'ALASKA'
#  'VERMONT' 'VIRGIN ISLANDS' 'FOREIGN' 'AMERICAN SAMOA' 'ONTARIO'
#  'CANAL ZONE']
# TOTAL 59
# ------------------------------------------
# These are the all the values in Marital Status
# ['NEVER MARRIED' 'MARRIED' 'UNKNOWN' 'DIVORCED' 'WIDOWED']
# TOTAL 5
# ------------------------------------------
# These are the all the values in Religion Name
# ['LUTHERAN CHURCHES' 'METHODIST CHURCHES' 'BAPTIST CHURCHES'
#  'PROTESTANT, NO DENOMINATIONAL PREFERENCE' 'SOUTHERN BAPTIST CONVENTION'
#  'ROMAN CATHOLIC CHURCH' 'JUDAISM (JEWISH)' 'NO RELIGIOUS PREFERENCE'
#  'EPISCOPAL CHURCH' 'PROTESTANT, OTHER CHURCHES'
#  'CHURCH OF GOD (ANDERSON, IN)' 'ISLAM' 'PRESBYTERIAN CHURCH (USA)'
#  'SEVENTH DAY ADVENTIST'
#  'CHURCH OF JESUS CHRIST OF LATTER DAY SAINTS (MORMON)' 'CHURCH OF CHRIST'
#  'UNCLASSIFIED RELIGIONS' 'BUDDHISM' 'ASSEMBLIES OF GOD'
#  'CHRISTIAN CHURCH' 'FRIENDS (QUAKERS)' 'PENTECOSTAL CHURCHES'
#  'BRETHREN CHURCHES' 'UNITARIAN UNIVERSALIST' 'UNITED CHURCH OF CHRIST'
#  'CHURCH OF THE NAZARENE'
#  'FIRST CHURCH OF CHRIST, SCIENTIST (CHRISTIAN SCIENCE)'
#  'REFORMED CHURCH IN AMERICA' "JEHOVAH'S WITNESSES"
#  'CONGREGATIONAL CHURCHES' 'CHRISTIAN, NO DENOMINATIONAL PREFERENCE' nan
#  'AMERICAN BAPTIST CHURCHES IN THE USA'
#  'CATHOLIC CHURCHES (EXCLUDES ROMAN CATHOLIC CHURCH)']
# TOTAL 34
# ------------------------------------------
# These are the all the values in L
# ['LL' 'MM' 'BB' 'TN' 'BC' 'CR' 'JJ' 'NO' 'EC' 'TO' 'HA' 'II' 'RP' 'AS'
#  'DL' 'GX' 'XX' 'KB' 'PA' 'GE' 'QF' 'PP' 'QB' 'UU' 'RU' 'HN' 'SC' 'RF'
#  'AJ' 'RC' 'NC' nan 'BA' 'CC']
# TOTAL 34
# ------------------------------------------
# These are the all the values in Race Name
# ['WHITE' 'BLACK OR AFRICAN AMERICAN'
#  'AMERICAN INDIAN/ALASKA NATIVE, ASIAN, BLACK OR AFRICAN AMERICAN, NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER, WHITE'
#  'ASIAN  (ALL BUT USAR INCLUDE PACIFIC ISLANDER IN THIS CODE)'
#  'AMERICAN INDIAN/ALASKA NATIVE'
#  'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER  (USAR SUBMITS F FOR PACIFIC ISLANDER)']
# TOTAL 6
# ------------------------------------------
# These are the all the values in Ethnic Name
# ['NOT SPECIFIED' 'PUERTO RICAN' 'HISPANIC OR LATINO']
# TOTAL 3
# ------------------------------------------
# These are the all the values in Race Omb
# ['WHITE' 'BLACK OR AFRICAN AMERICAN' 'NON-HISPANIC MORE THAN ONE RACE'
#  'HISPANIC ONE RACE' 'ASIAN' 'AMERICAN INDIAN/ALASKA NATIVE'
#  'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER']
# TOTAL 7
# ------------------------------------------
# These are the all the values in Ethnic Group Name
# ['UNKNOWN' 'HISPANIC']
# TOTAL 2
# ------------------------------------------
# These are the all the values in Cas Circumstances
# [nan
#  'THE AIRCRAFT WAS FLYING A NIGHT FLARE DROP MISSION.  NO CONTACT WAS MADE WITH AIRCRAFT AFTER 2055 LOCAL'
#  'MULTIPLE FRAGMENT INJURIES TO ONE EYE AND HEAD.'
#  'DURING A SEARCH AND RESCUE OPERATION THEY WERE HIT BY A MISSILE FIRED BY A MIG AIRCRAFT CAUSING THE HELICOPTER TO EXPLORE IN FLIGHT AND BREAK INTO SERVERAL PIECES'
#  'HEAD INJURIES' 'MORTAR SHARPNEL TO THE HEAD'
#  'GUNSHOT WOUNDS TO THE CHEST, THORACIC, AND SPINE AREA'
#  'SEVERE WOUNDS (PHYSICAL, PSYCHOLOGICAL, TORTURE) WHILE HELD CAPTIVE (POW) IN NORTH VIETNAM'
#  'SUSTAINED SEVERE INJURIES FROM A LANDMINE EXPLOSION TO HIS SPINAL CORD'
#  'AIRCRAFT STALLED AND CRASHED AFTER ATTEMPTING IN INFIGHT PICKUP FROM A TALL BAMBOO POLE'
#  'INJURY TO SPINAL CORD' 'GUNSHOT WOUND TO THE SPINE'
#  'MULTIPLE GUNSHOT WOUNDS'
#  'MACHINE GUN BULLETS TO SPINAL CORD AND GRENADE INJURIES TO LEFT LEG DURING COMBAT'
#  'SEVERE INJURIES FROM GUN SHOT WOUND TO THORAX AND SPINE AREA'
#  'INJURIES FROM MACHINE GUN BULLETS TO HIP AND BACK AREA'
#  'SEPSIS INFECTION TO HIS ABDOMINAL AREAS'
#  'PENETRATING MISSILE INJURY TO THE HEAD.  PARALYSIS IN ALL FOUR EXTREMITIES.'
#  'ACCIDENT DISCHARGE OF A WEAPON BY ANOTHER WATCH STANDER'
#  'SECOND AND THIRD DEGREE BURNS OVER 80% OF HIS BODY, WHILE DISPOSING OF CONTAMINATED GASOLINE THAT SUBSEQUENTLY EXPLODED.'
#  'MISSILE WOUND TO NECK WITH SPINAL CORD INJURY'
#  'STRUCK BY ROCKET-PROPELLED GRENADE AND SUFFERED EXTENSIVE INJURY TO LEFT LEG,  BLADDER AND STOMACH WHILE IN COMBAT'
#  'CRUSHED LOWER LEFT LEG AND FRACTURE OF LEFT TIBIA'
#  ' REMOTE GUNSHOT WOUND'
#  'ON SUPPLY RUN OF A CH-47 HELICOPTER THAT CRASHED'
#  'THE AIRCRAFT WAS ON A RECONNAISSANCE MISSION AND FAIALED TO RETURN AS SCHEDULED'
#  'SHRAPNEL WOUND TO HIS ABDOMEN'
#  'MULTIPLE FRAGEMENT WOUNDS TO THE SKULL AND LOWER EXTREMITY'
#  'HELICOPTER SHOT DOWN BY HOSTILE ENEMY FIRE.'
#  'B CO 3 BTN 21 INF AMERICAL DIV 196 LIGHT INF BDE'
#  'HEAD WOUND ON BASE CAMP UNDER ATTACKED BY ENEMY'
#  'A M577 CP TRACK MOVING DOWN ROAD AT NIGHT, TRACK WENT DOWN AN EMBANKMENT AND THOMPSON WAS THROWN OFF'
#  'STRUCK BY PROPELLER OF AN E1-B TRACER AIRCRAFT DURING FLIGHT OPERATIONS'
#  'THE AIRCRAFT WAS ON A RECONNAISSANCE MISSION AND FAILED TO RETURN AS SCHEDULED']
# TOTAL 34
# ------------------------------------------
# These are the all the values in Cas City
# ['KONTUM' 'PHUOC LONG' 'NINH THUAN' 'QUANG TRI' 'BINH THUAN' 'BINH DINH'
#  'THUA THIEN' 'QUANG TIN' 'KIEN HOA' 'QUANG NAM' nan 'BINH DUONG'
#  'TAY NINH' 'HUA NGHIA' 'BIEN HOA' 'PHONG DINH' 'DARLAC' 'LONG KHANH'
#  'QUANG DUC' 'QUANG NGAI' 'BA XUGEN' 'GIA DINH' 'PLEIKU' 'OFFSHORE'
#  'LONG AN' 'UNKNOWN' 'BINH LONG' 'DINH TUONG' 'PHUOC TUY' 'PHU YEN'
#  'TUYEN DUC' 'VINH LONG' 'KHANH HOA' 'KIEN TUONG' 'BAC LIEU' 'KIEN GIANG'
#  'CHAU DOC' 'AN XUGEN' 'KIEN PHONG' 'AN GIANG' 'BINH THUY' 'CHUONG THIEN'
#  'GO CONG' 'LAM DONG' 'VINH BINH' 'SA DEC' 'PHU BON' 'ANXUYEN' 'BONG SON'
#  'CON SON ISLAND' 'HAU NGHIA' 'PHU QUOC ISLAND']
# TOTAL 52
# ------------------------------------------
# These are the all the values in Cas ST
# ['M2' 'M3' 'M1' 'M4' nan]
# TOTAL 5
# ------------------------------------------
# These are the all the values in Cas Ctry
# ['VS' 'CB' 'VN' 'TH' 'LA' 'CH']
# TOTAL 6
# ------------------------------------------
# These are the all the values in Cas Region Name
# ['ASIA']
# TOTAL 1
# ------------------------------------------
# These are the all the values in Country Or Water Name
# ['SOUTH VIETNAM' 'CAMBODIA' 'NORTH VIETNAM' 'THAILAND' 'LAOS' 'CHINA']
# TOTAL 6
# ------------------------------------------
# These are the all the values in Unit Name
# ['D CO 3 BN 12 INF 4 INF DIV' '1 CAV DIV AIRMOBILE' nan ...
#  'VMFA 542 MAG 11 1 MAW FMFPAC' 'HHB 108 ARTY GRP' '388 TFW KORAT']
# TOTAL 2454
# ------------------------------------------
# These are the all the values in D
# ['Z' 'Y']
# TOTAL 2
# ------------------------------------------
# These are the all the values in Process Dt
# [19680501 19700301 19700801 19661201 19700501 19700901 19680801 19710201
#  19690601 19710101 19670801 19680201 19670401 19980701 19680901 19661001
#  19691101 20010419 19690201 19700401 19690401 19740501 19690501 19671001
#  19651201 19661101 19711001 19680101 19670601 19681101 19680301 19710301
#  19670701 19660301 19680601 19650901 19671101 19670501 19671201 19690101
#  19660701 19681001 19690801 19710401 19640701 19670101 20001030 19970701
#  19691001 19660801 20030623 19830701 19680401 19660501 19670301 19690301
#  19660401 19680701 19660901 20030618 19700101 19691201 19670201 19781001
#  20020221 19650301 19690901 19721001 19690701 20030616 19990201 19650501
#  19951001 19750701 20020812 19640401 19650801 19710601 19701101 19681201
#  19660201 19640101 19980101 19660601 19720501 19710701 20020807 19700701
#  19930801 19730701 19660101 19650601 19870501 19700601 19780501 19710501
#  19701001 19670901 19720701 19651101 19750401 19720901 19720401 19700201
#  19940301 19990601 19780301 19641101 19790601 20000328 19860501 19721201
#  19650201 19781201 19980801 19651001 19960601 19780701 19720101 19980501
#  19920401 19701201 19890701 19971101 19741101 19720601 19631201 19650701
#  19720801 19860401 19790401 19740701 20000801 20020327 19711101 19790201
#  20000201 19890101 19730901 19981001 19720301 19621001 19771201 19910201
#  19870801 19840801 19890301 19710801 20010711 19951101 19710901 19640601
#  19880401 19790301 19741201 19740601 19641001 19830301 19610601 19780801
#  19940101 19760901 19890901 19751101 19740401 19780601 19750601 19740901
#  19941101 20080213 19641201 19900601 19840201 19640901 19740101 19630701
#  19930601 19610301 19960301 20050726 19981201 19790801 19881201 19711201
#  19910601 19880501 19650401 19630201 19740201 19920901 19620401 19980901
#  19730601 19890501 19630801 19890801 19760201 19850601 19960501 19921201
#  19830401 19950401 20001231 19621101 19730501 19621201 20041020 19640301
#  19620101 19730201 19761101 19870901 19610401 20000701 19900101 19650101
#  19961201 19900401 19770601 19730101 19800301 19900201 19880801 19970501
#  19821001 20010301 19990701 19740801 19980401 19781101 19750101 19901001
#  19731101 19721101 19631001 19790101 19951201 19780401 19640801 20010716
#  19720201 19940501 19630101 19731001 19741001 19990401 19760401 19631101
#  19630501 20040303 19930101 19990101 19890401 19770301 19860901 20040615
#  19901101 20020312 19880301 19731201 20010327 19620701 19740301 19881101
#  19891101 19760501 19911201 19730401 19630401 20020703 19770401 19850201
#  19751001 19760301 20020923 19950701 19640501 19950901 19950601 19950801
#  19800101 19970601 19790501 19820601 19620501 19620201 19920601 19870701
#  20010220 19960401 19630901 19791201 19840101 19770901 19930401 19970101
#  19880901 19971201 19630301 19870401 19611201 19771101 19810201 20020528
#  19851201 19890201 19961101 19811201 19630601 19900801 19960701 19790701
#  19960901 19940801 20020927 19900301 20010507 19750301 19750901 19871201
#  19750501 19730801 19640201 19850501 19761201 20020708 19981101 19800801
#  19930201 19910101 19730301 19620601 19891201 20060407 20021001 20071120
#  19920701 19760601 19920501 20050817 19860601 19750201 20011030 20070905
#  19860801 20021114 19800701 20020718 19750801 19980601 19751201 19921001
#  19940701 19880601 19841001 19820701 19901201 19791001 19970201 20030226
#  20031103 19920201 19770201 19910901 19770501 19861201 19790901 20020408
#  20020522 19940401 20011024 20021007 19931001 19890601 19830601 20010831
#  19760101 20070221 19800601 19821201 20020224 19870601 20020905 20060131
#  19761001 19820201 19850301 20020227 20020415 19940201 19891001 19770801
#  19881001 19820901 20030530 19941001 19860701 19620801 19800201 19970301
#  19840301 19840901 20010322 19970401 19960801 19970901 19930701 19900701
#  19900501 19980301 20070222 19880701 19830801 20020822 20020422 19911001
#  19830901 20030211 20020318 19870101 19870301 20010717 20080320 19850801
#  19940901 19860101 19980201 19960201 19850701 20070716 20010910 19880201
#  20040628 19870201 19810801 19971001 19900901 19991201 20010820 19921101
#  19920301 20040505 20080416 20021119 20010509]
# TOTAL 445
# ------------------------------------------
# These are the all the values in Death Dt
# [19680530 19700228 19700820 ... 19720504 19650514 19730716]
# TOTAL 2965
# ------------------------------------------
# These are the all the values in Year
# [1968 1970 1966 1971 1969 1967 1965 1964 1972 1975 1960 1963 1962 1961
#  1973 1959 1957 1956 2004 1987 2006 2005 1990 1974]
# TOTAL 24
# ------------------------------------------
# These are the all the values in WC
# ['V']
# TOTAL 1
# ------------------------------------------
# These are the all the values in OITP
# ['C' nan]
# TOTAL 2
# ------------------------------------------
# These are the all the values in OI Name
# ['VIETNAM CONFLICT' 'AIRPLANE CRASH HONG KONG TO DANANG VS'
#  'USS MAYAGUEZ CAPTURE' nan]
# TOTAL 4
# ------------------------------------------
# These are the all the values in OI Location
# ['SOUTHEAST ASIA' 'SOUTH VIETNAM' 'CAMBODIA' nan]
# TOTAL 4
# ------------------------------------------
# These are the all the values in Close Dt
# [19680530. 19700228. 19700820. ... 19720627. 19620714. 19990908.]
# TOTAL 3096
# ------------------------------------------
# These are the all the values in Aircraft
# [nan 'C-130' 'C-123B' 'HH-53B' 'CH-53' 'A-1H' 'RF-4C' 'CH53']
# TOTAL 8
# ------------------------------------------
# These are the all the values in H
# ['H' 'NH']
# TOTAL 2
# ------------------------------------------
# These are the all the values in Casualty Type Name
# ['DECEASED']
# TOTAL 1
# ------------------------------------------
# These are the all the values in Casualty Category
# ['KILLED IN ACTION' 'ACCIDENT' 'DIED OF WOUNDS' 'HOMICIDE' 'DECLARED DEAD'
#  'ILLNESS' 'PRESUMED DEAD' 'SELF-INFLICTED']
# TOTAL 8
# ------------------------------------------
# These are the all the values in Casualty Reason Name
# ['SMALL ARMS FIRE' 'ARTILLERY/MORTAR/ROCKET' 'OTHER ACCIDENT'
#  'EXPLOSIVE DEVICE' 'GRENADE' 'UNKNOWN'
#  'HELICOPTER CRASH -- PASSENGER (MC)' 'HELICOPTER CRASH -- CREW (MC)'
#  'AIRCRAFT CRASH -- CREW (MC)' 'DROWNING' 'INFECTIOUS DISEASE'
#  'BURNS/SMOKE INHALATION' 'VEHICLE CRASH (MC)' 'OTHER WEAPONS'
#  'HEART RELATED' 'AIRCRAFT CRASH -- PASSENGER (MC)' 'STROKE'
#  'SHIP/SUBMARINE ACCIDENT AT SEA (MC)' 'BLUNT FORCE' 'GUNSHOT' nan
#  'MISSILE' 'LAND MINE' 'CANCER']
# TOTAL 24
# ------------------------------------------
# These are the all the values in CSN
# [nan]
# TOTAL 1
# ------------------------------------------
# These are the all the values in Body
# ['Y' 'N']
# TOTAL 2
# ------------------------------------------
# These are the all the values in RecoveredCasualty Closure Name
# ['BURIED - UNKNOWN DISP' 'REMAINS ACCEPTED - UNKNOWN DISP'
#  'NO REMAINS FOUND' 'REMAINS ACCEPTED - CIV CEMETERY'
#  'BURIED - CIVILIAN CEMETERY' 'REMAINS ACCEPTED - MIL CEMETERY'
#  'BURIED - MILITARY CEMETERY']
# TOTAL 7
# ------------------------------------------
# These are the all the values in Wall
# ['63W 014' '13W 066' '08W 124' ... '36E 063' '13W 039' '36E 044']
# TOTAL 11602
# ------------------------------------------
# These are the all the values in Incident Category
# [nan 'WOUNDED IN ACTION (VERY SERIOUS)' 'CAPTURED' 'MISSING IN ACTION'
#  'MISSING' 'WOUNDED IN ACTION (SERIOUS)' 'INJURY (VERY SERIOUS)'
#  'INJURY (VERY SERIOUS-COMBAT SUPPORT)']
# TOTAL 8
# ------------------------------------------
# These are the all the values in I Status Dt
# [      nan        0. 19681204. 19660420. 19671125. 19710220. 19680822.
#  19700422. 19720512. 19680522. 19671108. 19710109. 19651031. 19661018.
#  19680202. 19690513. 19660531. 19681213. 19700629. 19691104. 19661211.
#  19670824. 19681221. 19680214. 19700326. 19670731. 19700110. 19721222.
#  19660812. 19711123. 19670227. 19720420. 19670721. 19721006. 19660426.
#  19660304. 19661005. 19680201. 19680306. 19670201. 19670608. 19671016.
#  19671007. 19710307. 19690317. 19671109. 19661118. 19690324. 19680829.
#  19670512. 19661208. 19670812. 19680612. 19670424. 19660421. 19670319.
#  19680503. 19700416. 19660828. 19670827. 19670522. 19680729. 19650407.
#  19691124. 19660515. 19690712. 19700413. 19690508. 19660918. 19670727.
#  19690316. 19720523. 19660314. 19681218. 19700728. 19710810. 19660921.
#  19710317. 19700707. 19721221. 19700324. 19690809. 19720518. 19670611.
#  19670814. 19661205. 19720819. 19671231. 19660923. 19641229. 19690523.
#  19680408. 19680823. 19711126. 19680730. 19690519. 19670129. 19680108.
#  19671111. 19690506. 19710510. 19681115. 19670127. 19700429. 19670804.
#  19700415. 19720510. 19670130. 19680319. 19680419. 19700724. 19690625.
#  19691112. 19670603. 19690302. 19720402. 19710930. 19680623. 19691016.
#  19660124. 19720924. 19680428. 19720929. 19660729. 19660429. 19661202.
#  19681220. 19651117. 19680328. 19650708. 19660817. 19660928. 19720329.
#  19670726. 19671126. 19721120. 19681020. 19680105. 19690206. 19661104.
#  19680801. 19680309. 19700102. 19700730. 19680212. 19650618. 19721107.
#  19720717. 19660203. 19691103. 19720425. 19671118. 19690218. 19670821.
#  19660521. 19720917. 19660613. 19661019. 19671225. 19690731. 19680705.
#  19730108. 19680724. 19700320. 19661111. 19691026. 19690109. 19700701.
#  19680327. 19680721. 19680311. 19670518. 19690129. 19671117. 19670428.
#  19700825. 19670417. 19710706. 19670105. 19691102. 19630412. 19651212.
#  19710424. 19690905. 19670321. 19701013. 19721227. 19720403. 19720413.
#  19660301. 19651224. 19680330. 19671229. 19651215. 19691205. 19721224.
#  19671024. 19730110. 19721010. 19690918. 19690118. 19680121. 19680527.
#  19671105. 19700617. 19680512. 19680112. 19670630. 19690306. 19670204.
#  19680317. 19680617. 19691122. 19690127. 19660715. 19670521. 19661105.
#  19681028. 19720507. 19641231. 19691021. 19671110. 19680422. 19680228.
#  19721219. 19660424. 19681116. 19720826. 19730616. 19710910. 19690107.
#  19670704. 19670308. 19710105. 19680421. 19710313. 19610106. 19710319.
#  19710516. 19671202. 19680717. 19680425. 19680516. 19630902. 19691003.
#  19690929. 19670126. 19660925. 19681123. 19720703. 19690327. 19700214.
#  19690417. 19650609. 19680718. 19701005. 19680519. 19660318. 19690818.
#  19680917. 19720614. 19660313. 19690320. 19641106. 19701103. 19650918.
#  19660517. 19680906. 19690713. 19680101. 19660719. 19671012. 19690412.
#  19660813. 19660509. 19680702. 19671107. 19680326. 19670517. 19670705.
#  19650519. 19671022. 19651122. 19670905. 19720825. 19691009. 19701212.
#  19670426. 19670627. 19700404. 19711231. 19661006. 19691202. 19720406.
#  19680126. 19660423. 19680219. 19700423. 19661021. 19660814. 19690113.
#  19691105. 19661003. 19690403. 19680205. 19681027. 19661020. 19660121.
#  19650705. 19661012. 19700609. 19680103. 19690418. 19660624. 19670324.
#  19680502. 19710518. 19680316. 19690310. 19671119. 19680313. 19650402.
#  19690704. 19671031. 19691230. 19661008. 19680320. 19690117. 19680930.
#  19720330. 19680914. 19681021. 19701124. 19711224. 19660801. 19680925.
#  19670531. 19671017. 19690819. 19680510. 19640923. 19671124. 19680611.
#  19660122. 19671222. 19720606. 19681125. 19690427. 19651207. 19670315.
#  19650525. 19700115. 19680727. 19660703. 19681211. 19650713. 19660406.
#  19700409. 19680531. 19691031. 19680116. 19670926. 19680208. 19720908.
#  19680501. 19680627. 19661007. 19680518. 19660222. 19660412. 19651222.
#  19650908. 20040924. 19670401. 19690614. 19691115. 19721017. 19650711.
#  19670504. 19720710. 19680109. 19720902. 19640607. 19651228. 19670519.
#  19700502. 19670917. 19660126. 19680430. 19660518. 19670618. 19671106.
#  19721228. 19650802. 19750515. 19730127. 19721028. 19690721. 19660131.
#  19670419. 19670421. 19680314. 19681010. 19680207. 19690813. 19700702.
#  19720314. 19680229. 19660612. 19681029. 19670718. 19681126. 19670719.
#  19721128. 19710115. 19660416. 19700905. 19670912. 19680417. 19690123.
#  19720524. 19690325. 19691027. 19680321. 19690329. 19660706. 19690224.
#  19660323. 19680815. 19700630. 19660129. 19700107. 19660723. 19680406.
#  19670121. 19710201. 19710103. 19650612. 19680120. 19660315. 19711230.
#  19680110. 19710216. 19720307. 19650518. 19720712. 19710306. 19660528.
#  19700820. 19670922. 19681013. 19690223. 19660210. 19670605. 19710611.
#  19710530. 19690921. 19730418. 19670725. 19710312. 19680628. 19680203.
#  19650610. 19660608. 19680119. 19690217. 19690119. 19720416. 19680715.
#  19670921. 19671227. 19670311. 19661115. 19690301. 19670806. 19691222.
#  19710816. 19720409. 19700506. 19720618. 19681225. 19660514. 19680901.
#  19660714. 19660101. 19650917. 19661022. 19661102. 19660808. 19710925.
#  19650727. 19671025. 19690211. 19710427. 19660603. 19680505. 19680923.
#  19680131. 19680824. 19650905. 19670823. 19680523. 19690104. 19680301.
#  19690330. 19680220. 19670710. 19640619. 19670709. 19660917. 19710425.
#  19721220. 19720820. 19660525. 19671004. 19710409. 19720906. 19710129.
#  19700530. 19660201. 19660411. 19710724. 19720407. 19690201. 19680322.
#  19700205. 19690801. 19690222. 19670520. 19700420. 19680315. 19691111.
#  19660504. 19660625. 19650920. 19690502. 19651001. 19660215. 19691010.
#  19651017. 19651105. 19720503. 19680816. 19721218. 19700907. 19720414.
#  19650209. 19680407. 19660720. 19681009. 19650813. 19670102. 19680415.
#  19670223. 19660820. 19680227. 19700913. 19671129. 19680104. 19610422.
#  19670903. 19670228. 19690216. 19700218. 19661026. 19700901. 19720529.
#  19671102. 19720910. 19681230. 20060105. 19670510. 19660226. 19660901.
#  19671210. 19651220. 19670410. 19680926. 19701008. 19680629. 19670607.
#  19660307. 19670327. 19680725. 19680424. 19641222. 19620714. 19660919.
#  19681219. 19721012. 19700623. 19720817. 19660309. 19691001. 19690413.
#  19661116. 19720323. 19700911. 19670610. 19651005. 19680818. 19691125.
#  19670429. 19690715. 19690402. 19700130. 19680908. 19710325. 19700319.
#  19690303. 19670309. 19651018. 19660507. 19711020. 19680618. 19680318.
#  19691113. 19670913. 19681208. 19680403. 19670106. 19651208. 19721225.
#  19680520. 19660916. 19720707. 19690312. 19660616. 19670215. 19670701.
#  19670602. 19681214. 19631124. 19700305. 19680827. 19660218. 19660905.
#  19671205. 19671103. 19710331. 19701230. 19680828. 19681229. 19670712.
#  19660109. 19680609. 19680825. 19651015. 19700721. 19650616. 19680215.
#  19670409. 19700312. 19671221. 19670703. 19720723. 19680912. 19650429.
#  19670624. 19721202. 19690424. 19720625. 19700207. 19690126. 19680115.
#  19670306. 19631108. 19660627. 19650403. 19660701. 19680530. 19650311.
#  19660622. 19680927. 19710310. 19710517. 19690617. 19660927. 19680708.
#  19710203. 19680325. 19690214. 19700117. 19710629. 19691025. 19650428.
#  19701018. 19701130. 19720511. 19710622. 19720525. 19650506. 19691020.
#  19721029. 19660621. 19670615. 19681031. 19680606. 19671230. 19641211.
#  19660910. 19660505. 19690202. 19660721. 19720611. 19680222. 19681130.
#  19670711. 19641022. 19720813. 19690916. 19660417. 19660903. 19680107.
#  19700113. 19681024. 19660316. 19680911. 19660519. 19660327. 19631029.
#  19720721. 19650523. 19690215. 19690613. 19661213. 19670820. 19670116.
#  19680303. 19680129. 19640326. 19690323. 19661002. 19720506. 19691006.
#  19680117. 19660711. 19641024. 19661122. 19701019. 19670702. 19670801.
#  19650509. 19720327. 19700613. 19660116. 19651019. 19720401. 19670117.
#  19670221. 19660422. 19670119. 19711021. 19680517. 19710301. 19680630.]
# TOTAL 756
# ------------------------------------------
# These are the all the values in I CSN
# [nan 'WIA' 'POW' 'MIA' 'MSG']
# TOTAL 5
# ------------------------------------------
# These are the all the values in I H
# [nan 'H' 'NH']
# TOTAL 3
# ------------------------------------------
# These are the all the values in I Aircraft
# [nan 'C-130' 'UH-1H' 'A-1H' 'UHIH']
# TOTAL 5
# ------------------------------------------

# %% [markdown]
# ___
# # TIME ____to____ CLEAN

# %%
war_file.isna().sum()
# Out:
# SERVICE NO                            0
# C                                   182
# PTP                                   0
# Person Type Name                      3
# name                                  0
# S                                     0
# Service Name                          0
# Rank Rate                             0
# PG                                    0
# Occ                                  28
# Occupation Name                    4207
# Birth Dt                              0
# G                                     0
# Hor City                            122
# Hor County                           29
# Hor Ctry                              0
# Hor ST                              117
# State Prv Nm                        117
# Marital Status                        0
# Religion Name                         3
# L                                     3
# Race Name                             0
# Ethnic Name                           0
# Race Omb                              0
# Ethnic Group Name                     0
# Cas Circumstances                 58180
# Cas City                           9009
# Cas ST                             9161
# Cas Ctry                              0
# Cas Region Name                       0
# Country Or Water Name                 0
# Unit Name                         17090
# D                                     0
# Process Dt                            0
# Death Dt                              0
# Year                                  0
# WC                                    0
# OITP                                  2
# OI Name                               2
# OI Location                           2
# Close Dt                           1771
# Aircraft                          58135
# H                                     0
# Casualty Type Name                    0
# Casualty Category                     0
# Casualty Reason Name                  8
# CSN                               58220
# Body                                  0
# RecoveredCasualty Closure Name        0
# Wall                                 23
# Incident Category                 51597
# I Status Dt                       51599
# I CSN                             51600
# I H                               51597
# I Aircraft                        58207
# dtype: int64

# %%
to_drop = ['Hor City', 'SERVICE NO','C', 'S', 'Occ', 'Hor City', 
           'Religion Name', 'L', 'Race Name', 'Ethnic Name', 
           'Race Omb', 'Ethnic Group Name', 'I Status Dt', 'Close Dt',
           'I CSN', 'I H', 'I Aircraft', 'Cas Region Name', 'Unit Name', 
           'D', 'WC', 'OITP', 'OI Name', 'Aircraft', 'H', 'Casualty Type Name',
           'CSN', 'Incident Category', 'Cas Circumstances', 'Cas ST', 'OI Location']

# %%
war_file = war_file.drop(to_drop, axis=1)

# %%
war_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58220 entries, 0 to 58219
# Data columns (total 25 columns):
# PTP                               58220 non-null object
# Person Type Name                  58217 non-null object
# Member Name                       58220 non-null object
# Service Name                      58220 non-null object
# Rank Rate                         58220 non-null object
# PG                                58220 non-null object
# Occupation Name                   54013 non-null object
# Birth Dt                          58220 non-null int64
# G                                 58220 non-null object
# Hor County                        58191 non-null object
# Hor Ctry                          58220 non-null object
# Hor ST                            58103 non-null object
# State Prv Nm                      58103 non-null object
# Marital Status                    58220 non-null object
# Cas City                          49211 non-null object
# Cas Ctry                          58220 non-null object
# Country Or Water Name             58220 non-null object
# Process Dt                        58220 non-null int64
# Death Dt                          58220 non-null int64
# Year                              58220 non-null int64
# Casualty Category                 58220 non-null object
# Casualty Reason Name              58212 non-null object
# Body                              58220 non-null object
# RecoveredCasualty Closure Name    58220 non-null object
# Wall                              58197 non-null object
# dtypes: int64(4), object(21)
# memory usage: 11.1+ MB

# %%
war_file.isna().sum()
# Out:
# PTP                                  0
# Person Type Name                     3
# Member Name                          0
# Service Name                         0
# Rank Rate                            0
# PG                                   0
# Occupation Name                   4207
# Birth Dt                             0
# G                                    0
# Hor County                          29
# Hor Ctry                             0
# Hor ST                             117
# State Prv Nm                       117
# Marital Status                       0
# Cas City                          9009
# Cas Ctry                             0
# Country Or Water Name                0
# Process Dt                           0
# Death Dt                             0
# Year                                 0
# Casualty Category                    0
# Casualty Reason Name                 8
# Body                                 0
# RecoveredCasualty Closure Name       0
# Wall                                23
# dtype: int64

# %%
# war_file['Occupation Name'].fillna('Unknown', inplace=True)
# war_file['Person Type Name'].fillna('ACTIVE - REGULAR', inplace=True)
# war_file['Hor County'].fillna('MULTIPLE', inplace=True)
# war_file['State Prv Nm'].fillna('FORIEGN', inplace=True)
# war_file['Hor ST'].fillna('FORIEGN', inplace=True)

# %% [markdown]
# - Cleaning Cas City

# %%
war_file['Cas City'].value_counts()
# Out:
# QUANG NAM          8090
# QUANG TRI          7540
# THUA THIEN         4289
# QUANG TIN          2987
# QUANG NGAI         2981
# BINH DUONG         2766
# TAY NINH           2683
# BINH DINH          2418
# KONTUM             1691
# HUA NGHIA          1442
# BIEN HOA           1334
# GIA DINH           1318
# PLEIKU             1092
# LONG AN            1020
# BINH LONG           947
# DINH TUONG          835
# PHUOC LONG          695
# LONG KHANH          577
# KIEN HOA            462
# KHANH HOA           449
# OFFSHORE            329
# PHU YEN             326
# BINH THUAN          302
# PHUOC TUY           238
# PHONG DINH          198
# BINH THUY           195
# DARLAC              192
# NINH THUAN          189
# QUANG DUC           180
# VINH LONG           169
# LAM DONG            167
# KIEN TUONG          158
# UNKNOWN             136
# KIEN GIANG          124
# CHAU DOC             84
# BA XUGEN             82
# TUYEN DUC            80
# KIEN PHONG           79
# GO CONG              71
# VINH BINH            71
# AN XUGEN             70
# CHUONG THIEN         39
# PHU BON              32
# SA DEC               32
# AN GIANG             29
# BAC LIEU             18
# HAU NGHIA             1
# PHU QUOC ISLAND       1
# BONG SON              1
# ANXUYEN               1
# CON SON ISLAND        1
# Name: Cas City, dtype: int64

# %% [markdown]
# A good portion of these names are the same as the Proviences they are in. We have 9009 missing this value. I will cross reference the `operations_df` to see if there is any possible Operations that these soliders could have fallen in. As it stands, there is already a input for "Unknown" but I will use that as my last resort.

# %%
ops_df = pd.read_csv('data/raw/operations_db.csv')

# %%
ops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 7 columns):
# op_name       255 non-null object
# start_date    255 non-null int64
# end_date      255 non-null int64
# location_1    255 non-null object
# location_2    72 non-null object
# location_3    20 non-null object
# location_4    9 non-null object
# dtypes: int64(2), object(5)
# memory usage: 14.0+ KB

# %%
ops_df.start_date = pd.to_datetime(ops_df.start_date, format='%Y%m%d')
ops_df.end_date = pd.to_datetime(ops_df.end_date, format='%Y%m%d')

# %% [markdown]
# Review `.apply` with functions in Python

# %%
def removing_years(string_to_process):
    if re.search(r".*(?=,)", str(string_to_process)):
        thing = re.search(r".*(?=,)", str(string_to_process))
        return thing.group(0)

# %%
removing_years(ops_df.op_name[2])
# Out:
# 'Operation Adams'

# %%
ops_df.op_name = ops_df.op_name.apply(lambda x :removing_years(x))

# %%
ops_df
# Out:
#                         op_name start_date   end_date  \
# 0             Operation Abilene 1966-04-07 1966-04-10
# 1         Operation Adairsville 1968-01-31 1968-03-08
# 2               Operation Adams 1966-10-26 1967-03-30
# 3               Operation Ahina 1967-05-13 1967-05-18
# 4                Operation Aiea 1966-08-08 1966-09-01
# 5           Operation Akron III 1967-09-26 1967-10-21
# 6               Operation Akron 1967-06-09 1967-06-29
# 7           Operation Ala Moana 1966-12-01 1967-05-14
# 8              Operation Allons 1968-04-22 1968-04-26
# 9             Operation Altoona 1968-01-13 1968-01-23
# 10          Operation Arc Light 1965-06-18 1973-08-14
# 11      Operation Arkansas City 1967-09-18 1967-10-09
# 12            Operation Ashland 1967-05-18 1967-06-08
# 13            Operation Atlanta 1966-10-20 1966-12-08
# 14            Operation Atlanta 1967-12-23 1967-12-23
# 15        Operation Atlas Wedge 1969-03-18 1969-04-02
# 16          Operation Attleboro 1966-09-14 1966-11-24
# 17          Operation Aurora II 1966-07-17 1966-08-03
# 18          Operation Austin VI 1966-05-01 1966-05-18
# 19       Operation Badger Catch 1968-01-23 1968-01-26
# 20       Operation Beau Diddley 1967-04-22 1968-04-22
# 21        Operation Beaver Cage 1967-04-30 1967-05-12
# 22             Operation Benton 1967-08-12 1967-09-01
# 23         Operation Big Spring 1967-01-29 1967-02-16
# 24           Operation Billings 1967-06-12 1967-06-26
# 25         Operation Birmingham 1966-04-24 1966-05-17
# 26            Operation Bismark 1966-11-25 1966-12-09
# 27        Operation Black Horse 1966-03-01 1966-03-05
# 28       Operation Blackjack 25 1967-04-15 1967-05-26
# 29           Operation Blue Jay 1966-08-30 1966-09-29
# ..                          ...        ...        ...
# 225    Operation Tiger Coronado 1967-08-23 1967-08-23
# 226     Operation Toan Thang 43 1970-05-01 1970-06-30
# 227     Operation Toan Thang II 1968-06-01 1969-02-16
# 228    Operation Toan Thang III 1969-02-16 1969-10-31
# 229            Operation Toledo 1966-08-09 1966-09-07
# 230  Operation Truong Cong Dinh 1968-03-01 1968-05-21
# 231            Operation Tucson 1967-02-14 1967-02-21
# 232             Operation Tulsa 1966-10-08 1966-10-16
# 233         Operation Utah Mesa 1969-06-11 1969-07-09
# 234          Operation Valdosta 1967-09-01 1967-09-06
# 235         Operation Van Buren 1966-01-17 1966-02-21
# 236      Operation Vance Canyon 1968-06-20 1968-07-02
# 237     Operation Vernon Lake I 1968-10-25 1968-11-02
# 238    Operation Vernon Lake II 1968-11-02 1969-02-28
# 239           Operation Vin Loc 1968-09-10 1968-09-20
# 240              Operation Waco 1966-11-24 1966-12-02
# 241           Operation Wahiawa 1966-05-16 1966-05-27
# 242            Operation Walker 1968-01-16 1969-01-31
# 243           Operation Wallowa 1968-11-11 1968-11-11
# 244      Operation Wasco Rapids 1971-03-12 1971-03-27
# 245  Operation Washington Green 1969-04-15 1970-12-31
# 246          Operation Waycross 1966-03-12 1966-03-25
# 247           Operation Wheeler 1967-09-11 1967-11-25
# 248        Operation Winchester 1966-10-08 1966-12-04
# 249             Operation Worth 1968-03-12 1968-03-26
# 250       Operation Yellowstone 1967-12-07 1968-02-24
# 251       Operation York Market 1970-01-30 1970-04-16
# 252          Operation Yorktown 1966-06-23 1966-07-09
# 253    Battle of Quang Tri City 1968-01-31 1968-02-01
# 254    Battle of Que Son Valley 1967-04-19 1967-09-15
#
#                    location_1         location_2  location_3  location_4
# 0                   Phuoc Tuy                NaN         NaN         NaN
# 1                    Bien Hoa                NaN         NaN         NaN
# 2                     Phu Yen                NaN         NaN         NaN
# 3                  Binh Duong           Tay Ninh         NaN         NaN
# 4                   Hau Nghia                NaN         NaN         NaN
# 5                    Bien Hoa                NaN         NaN         NaN
# 6                   Phuoc Tuy           Bien Hoa         NaN         NaN
# 7                  Binh Duong          Hau Nghai    Tay Ninh         NaN
# 8                    Dong Nai                NaN         NaN         NaN
# 9                    Bien Hoa                NaN         NaN         NaN
# 10              South Vietnam                NaN         NaN         NaN
# 11                  Phuoc Tuy                NaN         NaN         NaN
# 12                   Bien Hoa         Long Khanh         NaN         NaN
# 13                 Long Khanh          Phuoc Tuy   Hau Nghia  Binh Duong
# 14                 Binh Duong          Hau Nghia         NaN         NaN
# 15           Ho Chi Minh City                NaN         NaN         NaN
# 16                   Tay Ninh          Binh Long  Binh Duong         NaN
# 17                 Phuong Lam                NaN         NaN         NaN
# 18                  Quang Duc         Phuoc Long         NaN         NaN
# 19                  Quang Tri                NaN         NaN         NaN
# 20                    Unknown                NaN         NaN         NaN
# 21                  Quang Nam          Quang Tin         NaN         NaN
# 22                  Quang Tin                NaN         NaN         NaN
# 23                 War Zone D                NaN         NaN         NaN
# 24                  Binh Long         Phuoc Long  Binh Duong  War Zone D
# 25                   Tay Ninh         War Zone C         NaN         NaN
# 26                 Binh Duong                NaN         NaN         NaN
# 27                  Binh Dinh                NaN         NaN         NaN
# 28    Combat Tactical Zone II                NaN         NaN         NaN
# 29   Combat Tactical Zone III  Tay Ninh Province         NaN         NaN
# ..                        ...                ...         ...         ...
# 225                   Long An                NaN         NaN         NaN
# 226                  Tay Ninh          Binh Long  Phuoc Long         NaN
# 227                Binh Duong           Gia Dinh   Hau Nghia     Long An
# 228                  Tay Ninh         Binh Duong    Gia Dinh   Hau Nghia
# 229                  Binh Tuy          Phuoc Tuy         NaN         NaN
# 230                   Long An         Dinh Tuong         NaN         NaN
# 231                 Binh Long                NaN         NaN         NaN
# 232                Binh Duong          Binh Long         NaN         NaN
# 233                 Quang Tri                NaN         NaN         NaN
# 234                Long Khanh                NaN         NaN         NaN
# 235                   Phu Yen                NaN         NaN         NaN
# 236                Quang Ngai                NaN         NaN         NaN
# 237                Quang Ngai                NaN         NaN         NaN
# 238                Quang Ngai                NaN         NaN         NaN
# 239                Thua Thien                NaN         NaN         NaN
# 240                  Bien Hoa                NaN         NaN         NaN
# 241                 Hau Nghia                NaN         NaN         NaN
# 242                 Binh Dinh             Pleiku         NaN         NaN
# 243                 Quang Nam          Quang Tin         NaN         NaN
# 244                Quang Ngai                NaN         NaN         NaN
# 245                 Binh Dinh                NaN         NaN         NaN
# 246                Binh Duong                NaN         NaN         NaN
# 247                 Quang Tin                NaN         NaN         NaN
# 248                 Quang Nam            Da Nang         NaN         NaN
# 249                 Quang Nam                NaN         NaN         NaN
# 250                  Tay Ninh                NaN         NaN         NaN
# 251                 Quang Tri                NaN         NaN         NaN
# 252                  Xuan Loc                NaN         NaN         NaN
# 253                 Quang Tri                NaN         NaN         NaN
# 254                 Quang Nam          Quang Tin         NaN         NaN
#
# [255 rows x 7 columns]

# %%
"Battle of Que Son Valley, 092", "Battle of Quang Tri City, 180"

# %% [markdown]
# - Cleaning State Prv Nm and State Prv Nm column

# %%
msno.heatmap(war_file)

# %% [markdown]
# As we can see, with the help of my dandy library `missingno`, there is 1:1 correlation with the columns `State Prv Nm` and `Hor ST`. Lets explore what is going on here.

# %%
war_file[war_file['State Prv Nm'].isna() == True]['Hor Ctry'].value_counts()
# Out:
# CA    56
# RP    26
# GM     7
# MX     5
# UK     3
# FR     2
# NZ     2
# AS     2
# JM     2
# JA     2
# PM     2
# BR     1
# EI     1
# CS     1
# PE     1
# BF     1
# IT     1
# BL     1
# SZ     1
# Name: Hor Ctry, dtype: int64

# %% [markdown]
# My best guess is these soliders were foriegn nationals fighting in our war. It isn't unheard of it. So I will make their "State Prv Nm" to "FOREIGN".

# %% [markdown]
# - Cleaning Hor County column

# %%
war_file['Hor County'].isna().sum()
# Out:
# 29

# %%
war_file['Hor County'].value_counts()[:10]
# Out:
# LOS ANGELES     1877
# MULTIPLE        1737
# KINGS           1391
# COOK            1350
# WAYNE            993
# JEFFERSON        787
# PHILADELPHIA     620
# MONTGOMERY       577
# ORANGE           546
# MARION           438
# Name: Hor County, dtype: int64

# %%
war_file[war_file['Hor County'] == 'MULTIPLE'].head()
# Out:
#     PTP        Person Type Name                    name  Service Name  \
# 23    S        SELECTED SERVICE     ABBOTT JAMES EDWARD          ARMY
# 68    L  ACTIVE - GUARD/RESERVE        ABRAMS JOHN ALAN  MARINE CORPS
# 88    K        ACTIVE - REGULAR        JENKINS MORRIS E          ARMY
# 91    K        ACTIVE - REGULAR     JENKINS RANDALL LEE  MARINE CORPS
# 132   L  ACTIVE - GUARD/RESERVE  ACEVEDO-RECHANI RAFAEL          ARMY
#
#     Rank Rate   PG            Occupation Name  Birth Dt  G Hor County  \
# 23        PVT  E02                INFANTRYMAN  19490220  M   MULTIPLE
# 68       LCPL  E03                   RIFLEMAN  19460220  M   MULTIPLE
# 88        SP5  E05  GENERAL VEHICLE REPAIRMAN  19411129  M   MULTIPLE
# 91       LCPL  E03                   RIFLEMAN  19500419  M   MULTIPLE
# 132       MAJ  O04                        NaN  19270127  M   MULTIPLE
#
#     Hor Ctry Hor ST State Prv Nm Marital Status    Cas City Cas Ctry  \
# 23        US     LA    LOUISIANA  NEVER MARRIED  BINH DUONG       VS
# 68        US     IL     ILLINOIS        MARRIED  THUA THIEN       VS
# 88        US     OH         OHIO  NEVER MARRIED         NaN       VS
# 91        US     OH         OHIO  NEVER MARRIED   QUANG NAM       VS
# 132       US     PR  PUERTO RICO  NEVER MARRIED         NaN       VS
#
#     Country Or Water Name  Process Dt  Death Dt  Year     OI Location  \
# 23          SOUTH VIETNAM    19700401  19700409  1970  SOUTHEAST ASIA
# 68          SOUTH VIETNAM    19670101  19670109  1967  SOUTHEAST ASIA
# 88          SOUTH VIETNAM    19651201  19651202  1965  SOUTHEAST ASIA
# 91          SOUTH VIETNAM    19690201  19690202  1969  SOUTHEAST ASIA
# 132         SOUTH VIETNAM    20020221  19651203  1965  SOUTHEAST ASIA
#
#        Close Dt Casualty Category Casualty Reason Name Body  \
# 23   19700409.0  KILLED IN ACTION      SMALL ARMS FIRE    Y
# 68   19670109.0          ACCIDENT       OTHER ACCIDENT    Y
# 88   19651202.0  KILLED IN ACTION     EXPLOSIVE DEVICE    Y
# 91   19690202.0          ACCIDENT             DROWNING    Y
# 132  19651203.0           ILLNESS   INFECTIOUS DISEASE    Y
#
#     RecoveredCasualty Closure Name     Wall
# 23           BURIED - UNKNOWN DISP  12W 110
# 68           BURIED - UNKNOWN DISP  13E 129
# 88           BURIED - UNKNOWN DISP  03E 120
# 91           BURIED - UNKNOWN DISP  33W 041
# 132          BURIED - UNKNOWN DISP  03E 121

# %%
state_records[state_records['name'] == "JENKINS MORRIS E"]
# Out:
#                    name service rank_rate birthdate home_city home_county  \
# 23546  JENKINS MORRIS E    ARMY       SP5  19411129  COLUMBUS    MULTIPLE
#
#       incident_death body_rec state
# 23546       19651202        Y    OH

# %% [markdown]
# There are 29 missing missing values in county and there are 1737 that report "MULTIPLE" as their counties. I will fill the 29 that have empty values. I am making note that I have to figure out a way to account for the multiple county values when doing the mapping.
#
# ___
# End of cleaning
# ___

# %% [markdown]
# https://www.archives.gov/research/military/vietnam-war/casualty-lists/state-level-alpha.html for state by state
#
# https://catalog.archives.gov/id/2240992 for the `.dat` file. Contains a lot of the big stuff.
#
# https://amaral.northwestern.edu/blog/step-step-how-plot-map-slider-represent-time-evolu for the cholorplot slider
#
# https://catalog.archives.gov/id/10643608 list and just year of operation
# http://id.loc.gov/authorities/subjects/sh85143280.html

# %% [markdown]
# ## Link1

# %% [markdown]
# ## Link2

# %% [markdown]
# ## Link3

# %% [markdown]
# ## Link4

# %% [markdown]
# ## Link5

# %% [markdown]
# Testing

# %%
huh = ['asf', 'asd','pqiwr', '452', 'fuck ', ' off', 'no', 'way!', '239', 'lsdf']
what = ['asf', 'asd','pqiwr', '452', 'will', 'this', 'work', '918364', 'kjsfd']
where = ['asf', 'asd','pqiwr', '452', 'NO', 'MOVEMENT', '918364', 'uhas']

# %%
batch = [huh,what,where]

for trial in batch:
    
    try: 
        int(trial[6])
    
    except ValueError:
        try:
            int(trial[7])
        except ValueError:
            print('this is the error' + ' ' + trial[7])
            trial[5] = trial[5] + trial[6]
            del trial[6]
    
        try:
            int(trial[6])
        except ValueError:
            print('this is the error' + ' ' + trial[6])
            trial[4] = trial[4] + trial[5]
            del trial[5]

batch
