# %% [markdown]
# https://github.com/calremmel/burlington-real-estate-dash/blob/master/notebooks/final_project.ipynb
# https://vallandingham.me/shapefile_to_geojson.html
# http://code.highcharts.com/mapdata/

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ops_df = pd.read_csv('data/processed/ops_cleaned.csv')
records_df = pd.read_csv('data/processed/war_records_clean.csv')

# %%
ops_df.head()
# Out:
#    Unnamed: 0                op_name  start_date    end_date  location_1  \
# 0           0      Operation Abilene  1966-04-07  1966-04-10   Phuoc Tuy
# 1           1  Operation Adairsville  1968-01-31  1968-03-08    Bien Hoa
# 2           2        Operation Adams  1966-10-26  1967-03-30     Phu Yen
# 3           3        Operation Ahina  1967-05-13  1967-05-18  Binh Duong
# 4           4         Operation Aiea  1966-08-08  1966-09-01   Hau Nghia
#
#   location_2 location_3 location_4
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3   Tay Ninh        NaN        NaN
# 4        NaN        NaN        NaN

# %%
records_df.head()
# Out:
#    Unnamed: 0 PTP  Person Type Name             Member Name  Service Name  \
# 0           0   S  SELECTED SERVICE        AADLAND GERALD L          ARMY
# 1           1   S  SELECTED SERVICE    AALUND JAMES DOWNING          ARMY
# 2           2   K  ACTIVE - REGULAR  AAMOLD DANIEL LAWRENCE     AIR FORCE
# 3           3   S  SELECTED SERVICE     AARDE JAMES RAYMOND  MARINE CORPS
# 4           4   S  SELECTED SERVICE    AARON CHARLES EDWARD          ARMY
#
#   Rank Rate   PG Occupation Name    Birth Dt  G  ... Marital Status  \
# 0       SP4  E04     INFANTRYMAN  1945-03-29  M  ...  NEVER MARRIED
# 1       SGT  E05     INFANTRYMAN  1945-05-11  M  ...  NEVER MARRIED
# 2       A1C  E03         Unknown  1951-08-23  M  ...  NEVER MARRIED
# 3      LCPL  E03        RIFLEMAN  1944-06-08  M  ...        MARRIED
# 4       SP4  E04     INFANTRYMAN  1948-12-12  M  ...  NEVER MARRIED
#
#      Cas City Cas Ctry Country Or Water Name    Death Dt Casualty Category  \
# ...
